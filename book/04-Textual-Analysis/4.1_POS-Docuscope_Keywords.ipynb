# %% [markdown]
# # 4. Part-of-Speech Tagging &amp; Docuscope's Rhetorical Tagging

# %% [markdown]
# **Goal**: Learn about the textual analysis method called speech tagging.
#
# Speech-tagging methods can help us humans computationally parse, sort, and filter sentences in a large corpus, so we can retroactively also better understand any words of interest in their contexts of use.
#
# We will be working with the English-language `docuscospacy` model in this lesson—a LLM developed by rhetoricians at Carnegie Mellon University. I'd like to thank them for providing users their helpful documentation, which I have modified to use in this lesson.
#
# In this lesson, we are limited to the English language. Yet, feel free to check out Melanie Walsh's and Quinn Dombrowski's curated tutorials to work with other languages:
#
# - [Chinese POS Tagging](Multilingual/Chinese/03-POS-Keywords-Chinese)
# - [Danish POS Tagging](Multilingual/Danish/03-POS-Keywords-Danish)
# - [Portuguese POS Tagging](Multilingual/Portuguese/03-POS-Keywords-Portuguese)
# - [Russian POS Tagging](Multilingual/Russian/03-POS-Keywords-Russian)
# - [Spanish POS Tagging](Multilingual/Spanish/03-POS-Keywords-Spanish)

# %% [markdown]
# ## 4.1 What are Part-of-Speech &amp; DocuScope Tagging?

# %% [markdown]
# ### 4.1.1 Part-of-Speech tagging

# %% [markdown]
# Part-of-speech (POS) tagging, also called grammatical tagging, is the culmination of decades of work and labor to annotate lexicons by their typical syntactical role(s) by manual and probablistic/computational means. (See [Lancaster U's summary](https://ucrel.lancs.ac.uk/annotation.html#POS) of their original process for more information about POS tagging.)
#
# If you have ever diagrammed a sentence, like below, then you have a sense about POS. Note how the parts-of-speech have been tagged in the sentence. Lookup those tags in the [Lancaster's table of POS](https://ucrel.lancs.ac.uk/annotation.html#POS).
#
# <img src="../images/pos-tagging-example.png" alt="">
#
# You may currently feel as though these syntactical relations are very dense to understand and use at first. That's normal! Eventually, with some practice, POS tagging can help you explore and surface interesting language patterns used in a particular context and domain worth reporting.

# %% [markdown]
# ### 4.1.2 DocuScope's *Categorical* Tagging

# %% [markdown]
# In addition to POS tags, Docuscope's creators — David Kaufer, Suguru Ishizaki, and Kerry Ishizaki — have been developing a LLM for over 20 years that tag texts for a variety of experiences a writer can create for readers in a text. Docuscope can detect variations of word tokens, based on its token context. For instance, consider the following variations of rhetorical patterns of "I":
#
# - "I" = self-reference
# - "I know" = self-confidence
# - "I have to do chores today" = self-reluctance
# - "I get to do chores today" = eagerness
#
# As the example above demonstrates, Docuscope's rhetorical approach to language assumes that meaning is isolated better in "streams of words," i.e., co-occurrences, rather than individual words. *In other words*, single words, when accompanied by different words, can be interpreted differently. Take the word "sick" below.
#
# - I'm feeling as sick as a dog. = I am feeling very ill.
# - That was so sick! = I thought something was really cool.
# - I'm sick of talking about AI! = I don't want to talk about AI.
#
# As of 2019, DS's database included 44,000 semantic stream classes and over 70 million unique English language patterns. The result? DocuScope's LLM offers people **categorical tags** to pair with POS tagging.
#
# Categorical tags isolate potential rhetorical patterns within the corpus. To understand what I mean by rhetorical patterns, let's consider DS's categorical tags of `Reasoning` and `Character`. `Reasoning` isolates words or streams of words that are associated with reasoning statements, such as "because," "therefore," "even if," etc., while `Character` isolates multiple dimensions of a person. For example, depending on the word's company, the name "Pauline" might be tagged in relation to work-related characteristics or other domain-specific contextual information.
#
# So, if you decide to filter your corpus by the co-occurence of Reasoning tagged words with Character words, you could analyze the top and bottom relationships between the *who* is represented in the corpus (or not!) and words related to how they *reason*. From there, you can perhaps begin to imagine how you could conduct an EDA to ask questions of the patterns.

# %% [markdown]
# #### How DS tags categories

# %% [markdown]
# According to [DS's creators](https://docuscospacy.readthedocs.io/en/latest/docuscope.html), DS "consists of an enormous lexicon organized into a 3-level taxonomy. An analogue would be the lexicons typically used in sentiment analysis." A sentiment analysis typically cateogrizes words and phrases into either positive or negative sentiments. DS works similarily, but it "organizes its strings into many more categories and is orders of magnitude larger. A typical sentiment lexicon may match 3-5 thousand strings. DocuScope matches 100s of millions."
#
# Let's walk through an example sentence and what categorical tags offer in addition to POS tags:
#
# > Jaws is a shrewd cinematic equation which not only gives you one or two very nasty turns when you least expect them but, possibly more important, knows when to make you think another is coming without actually providing it.
#
# When this sentence is analyzed by the DS, it yields the following table (headers are as follows: `tag`==POS tag, `ent`==Named Entity tag; `ent_type`==DS categorical tag).
#
# Note how in addition to POS tagging, DS categorical tags offer a helpful rhetorical and contextual dimension to the token. DS tags offer numerous other categorical tags:

# %% [markdown]
# ##### *Categorical tag* results from the "Jaws is a shrewd ..." sentence above.

# %% [markdown]
# | **** | **text**  | **tag\_** | **ent\_** | **ent\_type\_**       |
# |------|-----------|-----------|-----------|-----------------------|
# | 0    | Jaws      | NN1       | B         | Character             |
# | 1    | is        | VBZ       | B         | InformationStates     |
# | 2    | a         | AT1       | I         | InformationStates     |
# | 3    | shrewd    | JJ        | B         | Strategic             |
# | 4    | cinematic | JJ        | B         | PublicTerms           |
# | 5    | equation  | NN1       | B         | AcademicTerms         |
# | 6    | which     | DDQ       | B         | SyntacticComplexity   |
# | 7    | not       | XX        | B         | ForceStressed         |
# | 8    | only      | RR        | I         | ForceStressed         |
# | 9    | gives     | VVZ       | B         | Interactive           |
# | 10   | you       | PPY       | I         | Interactive           |
# | 11   | one       | MC1       | O         |                       |
# | 12   | or        | CC        | B         | MetadiscourseCohesive |
# | 13   | two       | MC        | B         | InformationExposition |
# | 14   | very      | RG        | B         | ConfidenceHigh        |
# | 15   | nasty     | JJ        | B         | Negative              |
# | 16   | turns     | NN2       | O         |                       |
# | 17   | when      | RRQ       | B         | Narrative             |
# | 18   | you       | PPY       | I         | Narrative             |
# | 19   | least     | RRT       | B         | InformationExposition |
# | 20   | expect    | VV0       | B         | Future                |
# | 21   | them      | PPHO2     | B         | Narrative             |
# | 22   | but       | CCB       | B         | MetadiscourseCohesive |
# | 23   | ,         | Y         | B         | Contingent            |
# | 24   | possibly  | RR        | I         | Contingent            |
# | 25   | more      | RGR       | B         | InformationExposition |
# | 26   | important | JJ        | I         | InformationExposition |
# | 27   | ,         | Y         | O         |                       |
# | 28   | knows     | VVZ       | B         | ConfidenceHigh        |
# | 29   | when      | RRQ       | I         | ConfidenceHigh        |
# | 30   | to        | TO        | O         |                       |
# | 31   | make      | VVI       | B         | Interactive           |
# | 32   | you       | PPY       | I         | Interactive           |
# | 33   | think     | VVI       | B         | Character             |
# | 34   | another   | DD1       | B         | MetadiscourseCohesive |
# | 35   | is        | VBZ       | B         | InformationStates     |
# | 36   | coming    | VVG       | O         |                       |
# | 37   | without   | IW        | O         |                       |
# | 38   | actually  | RR        | B         | ForceStressed         |
# | 39   | providing | VVG       | B         | Facilitate            |
# | 40   | it        | PPH1      | O         |                       |
# | 41   | \.        | Y         | O         |                       |

# %% [markdown]
# #### Reference Table of DS Categorical Tags

# %% [markdown]
# | **\*\*Category \(Cluster\)\*\*** | **\*\*Description\*\***                                                                                                                                                                                                                                                       | **\*\*Examples\*\***                                                                                |
# |----------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------|
# | **Academic Terms**               | Abstract, rare, specialized, or disciplinary\-specific terms that are indicative of informationally dense writing                                                                                                                                                             | \*market price\*, \*storage capacity\*, \*regulatory\*, \*distribution\*                            |
# | **Academic Writing Moves**       | Phrases and terms that indicate academic writing moves, which are common in research genres and are derived from the work of Swales \(1981\) and Cotos et al\. \(2015, 2017\)                                                                                                 | \*in the first section\*, \*the problem is that\*, \*payment methodology\*, \*point of contention\* |
# | **Character**                    | References multiple dimensions of a character or human being as a social agent, both individual and collective                                                                                                                                                                | \*Pauline\*, \*her\*, \*personnel\*, \*representatives\*                                            |
# | **Citation**                     | Language that indicates the attribution of information to, or citation of, another source\.                                                                                                                                                                                   | \*according to\*, \*is proposing that\*, \*quotes from\*                                            |
# | **Citation Authorized**          | Referencing the citation of another source that is represented as true and not arguable                                                                                                                                                                                       | \*confirm that\*, \*provide evidence\*, \*common sense\*                                            |
# | **Citation Hedged**              | Referencing the citation of another source that is presented as arguable                                                                                                                                                                                                      | \*suggest that\*, \*just one opinion\*                                                              |
# | **Confidence Hedged**            | Referencing language that presents a claim as uncertain                                                                                                                                                                                                                       | \*tends to get\*, \*maybe\*, \*it seems that\*                                                      |
# | **Confidence High**              | Referencing language that presents a claim with certainty                                                                                                                                                                                                                     | \*most likely\*, \*ensure that\*, \*know that\*, \*obviously\*                                      |
# | **Confidence Low**               | Referencing language that presents a claim as extremely unlikely                                                                                                                                                                                                              | \*unlikely\*, \*out of the question\*, \*impossible\*                                               |
# | **Contingent**                   | Referencing contingency, typically contingency in the world, rather than contingency in one's knowledge                                                                                                                                                                       | \*subject to\*, \*if possible\*, \*just in case\*, \*hypothetically\*                               |
# | **Description**                  | Language that evokes sights, sounds, smells, touches and tastes, as well as scenes and objects                                                                                                                                                                                | \*stay quiet\*, \*gas\-fired\*, \*solar panels\*, \*soft\*, \*on my desk\*                          |
# | **Facilitate**                   | Language that enables or directs one through specific tasks and actions                                                                                                                                                                                                       | \*let me\*, \*worth a try\*, \*I would suggest\*                                                    |
# | **First Person**                 | This cluster captures first person\.                                                                                                                                                                                                                                          | \*I\*, \*as soon as I\*, \*we have been\*                                                           |
# | **Force Stressed**               | Language that is forceful and stressed, often using emphatics, comparative forms, or superlative forms                                                                                                                                                                        | \*really good\*, \*the sooner the better\*, \*necessary\*                                           |
# | **Future**                       | Referencing future actions, states, or desires                                                                                                                                                                                                                                | \*will be\*, \*hope to\*, \*expected changes\*                                                      |
# | **Information Change**           | Referencing changes of information, particularly changes that are more neutral                                                                                                                                                                                                | \*changes\*, \*revised\*, \*growth\*, \*modification to\*                                           |
# | **Information Change Negative**  | Referencing negative change\.                                                                                                                                                                                                                                                 | \*going downhill\*, \*slow erosion\*, \*get worse\*                                                 |
# | **Information Change Positive**  | Referencing positive change\.                                                                                                                                                                                                                                                 | \*improving\*, \*accrued interest\*, \*boost morale\*                                               |
# | **Information Exposition**       | Information in the form of expository devices, or language that describes or explains, frequently in regards to quantities and comparisons                                                                                                                                    | \*final amount\*, \*several\*, \*three\*, \*compare\*, \*80%\*                                      |
# | **Information Place**            | Language designating places\.                                                                                                                                                                                                                                                 | \*the city\*, \*surrounding areas\*, \*Houston\*, \*home\*                                          |
# | **Information Report Verbs**     | Informational verbs and verb phrases of reporting\.                                                                                                                                                                                                                           | \*report\*, \*posted\*, \*release\*, \*point out\*                                                  |
# | **Information States**           | Referencing information states, or states of being\.                                                                                                                                                                                                                          | \*is\*, \*are\*, \*existing\*, \*been\*                                                             |
# | **Information Topics**           | Referencing topics, usually nominal subjects or objects, that indicate the “aboutness” of a text                                                                                                                                                                              | \*time\*, \*money\*, \*stock price\*, \*phone interview\*                                           |
# | **Inquiry**                      | Referencing inquiry, or language that points to some kind of inquiry or investigation                                                                                                                                                                                         | \*find out\*, \*let me know if you have any questions\*, \*wondering if\*                           |
# | **Interactive**                  | Addresses from the author to the reader or from persons in the text to other persons\. The address comes in the language of everyday conversation, colloquy, exchange, questions, attention\-getters, feedback, interactive genre markers, and the use of the second person\. | \*can you\*, \*thank you for\*, \*please see\*, \*sounds good to me\*                               |
# | **Metadiscourse Cohesive**       | The use of words to build cohesive markers that help the reader navigate the text and signal linkages in the text, which are often additive or contrastive                                                                                                                    | \*or\*, \*but\*, \*also\*, \*on the other hand\*, \*notwithstanding\*, \*that being said\*          |
# | **Metadiscourse Interactive**    | The use of words to build cohesive markers that interact with the reader                                                                                                                                                                                                      | \*I agree\*, \*let’s talk\*, \*by the way\*                                                         |
# | **Narrative**                    | Language that involves people, description, and events extending in time                                                                                                                                                                                                      | \*today\*, \*tomorrow\*, \*during the\*, \*this weekend\*                                           |
# | **Negative**                     | Referencing dimensions of negativity, including negative acts, emotions, relations, and values                                                                                                                                                                                | \*does not\*, \*sorry for\*, \*problems\*, \*confusion\*                                            |
# | **Positive**                     | Referencing dimensions of positivity, including actions, emotions, relations, and values                                                                                                                                                                                      | \*thanks\*, \*approval\*, \*agreement\*, \*looks good\*                                             |
# | **Public Terms**                 | Referencing public terms, concepts from public language, media, the language of authority, institutions, and responsibility                                                                                                                                                   | \*discussion\*, \*amendment\*, \*corporation\*, \*authority\*, \*settlement\*                       |
# | **Reasoning**                    | Language that has a reasoning focus, supporting inferences about cause, consequence, generalization, concession, and linear inference either from premise to conclusion or conclusion to premise                                                                              | \*because\*, \*therefore\*, \*analysis\*, \*even if\*, \*as a result\*, \*indicating that\*         |
# | **Responsibility**               | Referencing the language of responsibility\.                                                                                                                                                                                                                                  | \*supposed to\*, \*requirements\*, \*obligations\*                                                  |
# | **Strategic**                    | This dimension is active when the text structures strategies activism, advantage\-seeking, game\-playing cognition, plans, and goal\-seeking\.                                                                                                                                | \*plan\*, \*trying to\*, \*strategy\*, \*decision\*, \*coordinate\*, \*look at the\*                |
# | **Syntactic Complexity**         | The features in this category are often what are called “function words,” like determiners and prepositions\.                                                                                                                                                                 | \*the\*, \*to\*, \*for\*, \*in\*, \*a lot of\*                                                      |
# | **Uncertainty**                  | References uncertainty, when confidence levels are unknown\.                                                                                                                                                                                                                  | \*kind of\*, \*I have no idea\*, \*for some reason\*                                                |
# | **Updates**                      | References updates that anticipate someone searching for information and receiving it                                                                                                                                                                                         | \*already\*, \*a new\*, \*now that\*, \*here are some\*                                             |

# %% [markdown]
# ## 4.2 Why is Speech Tagging Useful?

# %% [markdown]
# <img src="https://imgs.xkcd.com/comics/language_nerd.png" alt="I don't mean to go all [Language Nerd](https://xkcd.com/1443/) on you, but parts of speech are important. Even if they seem kind of boring. *Parts of speech* are the grammatical units of language — such as (in English) nouns, verbs, adjectives, adverbs, pronouns, and prepositions. Each of these parts of speech plays a different role in a sentence.">

# %% [markdown]
# By computationally identifying parts of speech, we can start computationally exploring *syntax*, the relationship between words, rather than only focusing on words in isolation, as other analyses perform such as *tf-idf*.
#
# Though parts of speech may seem pedantic, and difficult to apply at first, the POS and DS tags (*LANGUAGE AS DIGITAL DATA!*) help us work with our computational media, i.e., computers, to work toward that ever-elusive abstract noun: *meaning*.
#
# The *xkcd* comic above nicely illustrates how words are not monolithic or static in meaning. Why? Language is a dynamic part of the human experience. Language has a history—a history that feeds into what we do with language right now, which also impacts how words develop into our future. Consequently, syntactical tagging of word relationships - even within the seemingly simple language unit that we call sentences - is difficult. Words can and do shift roles and functions and how they impact social relationships (rhetoric!), because langauge is more than a "bag of words" and their syntactical relationships, e.g. "legit" as *adjective* and *adverb*. We've tangled up language in all aspects of our world.

# %% [markdown]
# ## 4.3 Speech Tagging Lesson

# %% [markdown]
# ### 4.3.1 Install necessary libraries

# %%
# %pip install -U spacy==3.5.0 
# Special modified version of tmtoolkit to work with docuscospacy (I logged the issue with DS, so this works with 0.2.3)
# %pip install pip install https://github.com/lingeringcode/temptmtoolkit/archive/refs/heads/main.zip
# %pip install docuscospacy==0.2.3
# Run the install command for 'json' just in case you don't have it
# Out:
# Requirement already satisfied: spacy==3.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (3.5.0)
# Requirement already satisfied: numpy>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (1.26.2)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (58.1.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (2.0.10)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (8.1.12)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (2.31.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (2.4.8)
# Requirement already satisfied: pathy>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (0.10.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (1.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (1.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (1.0.5)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (6.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (3.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (4.66.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy==3.5.0) (1.10.13)
# Requirement already satisfied: packaging>=20.0 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from spacy==3.5.0) (23.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy==3.5.0) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.5.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy==3.5.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2->spacy==3.5.0) (2.1.3)
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting https://github.com/lingeringcode/temptmtoolkit/archive/refs/heads/main.zip
#   Using cached https://github.com/lingeringcode/temptmtoolkit/archive/refs/heads/main.zip
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (21.2.4)
# Requirement already satisfied: install in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.22.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from temptmtoolkit==0.11.2) (1.26.2)
# Requirement already satisfied: scipy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from temptmtoolkit==0.11.2) (1.11.4)
# Requirement already satisfied: globre>=0.1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from temptmtoolkit==0.11.2) (0.1.5)
# Requirement already satisfied: pandas>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from temptmtoolkit==0.11.2) (2.1.3)
# Requirement already satisfied: xlrd>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from temptmtoolkit==0.11.2) (2.0.1)
# Requirement already satisfied: openpyxl>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from temptmtoolkit==0.11.2) (3.1.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from temptmtoolkit==0.11.2) (3.8.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (10.1.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (23.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (4.45.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (6.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (1.4.5)
# Requirement already satisfied: zipp>=3.1.0 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.0->temptmtoolkit==0.11.2) (3.17.0)
# Requirement already satisfied: et-xmlfile in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openpyxl>=3.0.0->temptmtoolkit==0.11.2) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.4.0->temptmtoolkit==0.11.2) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.4.0->temptmtoolkit==0.11.2) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->temptmtoolkit==0.11.2) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: docuscospacy==0.2.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.2.3)
# Requirement already satisfied: spacy>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from docuscospacy==0.2.3) (3.5.0)
# Requirement already satisfied: numpy>=1.22.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from docuscospacy==0.2.3) (1.26.2)
# Requirement already satisfied: loky>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from docuscospacy==0.2.3) (3.4.1)
# Requirement already satisfied: pandas>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from docuscospacy==0.2.3) (2.1.3)
# Requirement already satisfied: tmtoolkit>=0.11.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from docuscospacy==0.2.3) (0.12.0)
# Requirement already satisfied: bidict>=0.21.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from docuscospacy==0.2.3) (0.22.1)
# Requirement already satisfied: cloudpickle in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from loky>=3.0.0->docuscospacy==0.2.3) (3.0.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.4.0->docuscospacy==0.2.3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.4.0->docuscospacy==0.2.3) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from pandas>=1.4.0->docuscospacy==0.2.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->docuscospacy==0.2.3) (1.16.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (23.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.0.10)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.31.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (0.7.0)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.1.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (6.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.0.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.10.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.1.2)
# Requirement already satisfied: pathy>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (0.10.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (4.66.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (8.1.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.0.5)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (58.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=3.3.0->docuscospacy==0.2.3) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (2023.11.17)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.3.0->docuscospacy==0.2.3) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.3.0->docuscospacy==0.2.3) (0.7.11)
# Requirement already satisfied: wheel<1.0,>=0.40 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (0.41.3)
# Requirement already satisfied: openpyxl<4.0,>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.1.2)
# Requirement already satisfied: matplotlib<4.0,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.8.2)
# Requirement already satisfied: xlrd>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (2.0.1)
# Requirement already satisfied: globre<0.2,>=0.1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (0.1.5)
# Requirement already satisfied: scipy<2.0,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.11.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (4.45.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (6.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (0.12.1)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.17.0)
# Requirement already satisfied: et-xmlfile in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openpyxl<4.0,>=3.0.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.1.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy>=3.3.0->docuscospacy==0.2.3) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2->spacy>=3.3.0->docuscospacy==0.2.3) (2.1.3)
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 4.3.2 Import Libraries + EDA

# %%
import spacy
from spacy import displacy
from temptmtoolkit.corpus import Corpus, vocabulary_size, corpus_num_tokens
import re
from docuscospacy.corpus_analysis import convert_corpus, frequency_table, tags_table, ngrams_table, coll_table, tags_dtm, kwic_center_node, keyness_table
import pandas as pd
import json
import statistics

# %% [markdown]
# #### Quick EDA to understand the data

# %%
##############
## Import Data
##############

# Open/read the sample JSON file
file_adj_corpus = open('../data/04-textual-analysis/kaggle-nb-example/dict_viz_and_adjacent_cells.json', 'r')

# Convert the JSON data into python dict object
dict_adj_corpus = json.load(file_adj_corpus)

# Check the type of the Python object
print(type(dict_adj_corpus))

# Iterate through the dictionary
# And print the key: value pairs
# for key, value in dict_adj_corpus.items():
#   print(f"\nKey: {key}")
#   print(f"Value: {value}\n")

# Close the opened sample JSON file
file_adj_corpus.close()
# Out:
# <class 'dict'>

# %% [markdown]
# #### What is the sum of cells adjacent to visual cells per position?

# %% [markdown]
# **PROVENANCE**: This data comes from Kaggle.com, where data scientists share data and notebooks that analyze it. This set specifically collected notebooks that employ machine-learning techniques with the goal to understand how people used visuals throughout the process. Consequently, the data are organized by two factors:
#
# 1. whether or not a notebook cell is a "code" cell or a "Markdown" cell, and
# 2. whether the cell is positioned before or after a cell that produces a visualization.
#
# Review the summary stats work below to get to know the data some more before we use other more specific `.txt` files that I created from this particular data set.

# %%
####################################################################
# 1. What is the sum of cells adjacent to visual cells per position?
####################################################################
def sum_adj_cells(c):
  md_before_count = 0
  md_after_count = 0
  code_before_count = 0
  code_after_count = 0
  for vcell_key in c:
    if c[vcell_key]['adjacent_before'] != 'None':
      if c[vcell_key]['adjacent_before']['cell_type'] == 'markdown':
        md_before_count = md_before_count + 1
      elif c[vcell_key]['adjacent_before']['cell_type'] == 'code':
        code_before_count = code_before_count + 1
    elif c[vcell_key]['adjacent_after'] != 'None':
      if c[vcell_key]['adjacent_after']['cell_type'] == 'markdown':
        md_after_count = md_after_count + 1
      elif c[vcell_key]['adjacent_after']['cell_type'] == 'code':
        code_after_count = code_after_count + 1

  print(
    'Q1: What is the sum of cells adjacent to visual cells per posiiton?'
    '\n- md_before_count:', md_before_count,
    '\n- md_after_count:', md_after_count,
    '\n- code_before_count:', code_before_count,
    '\n- code_after_count:', code_after_count,
    '\n- TOTAL:', md_before_count+md_after_count+code_before_count+code_after_count
  )

sum_adj_cells(dict_adj_corpus)
# Out:
# Q1: What is the sum of cells adjacent to visual cells per posiiton?
# - md_before_count: 6749
# - md_after_count: 54
# - code_before_count: 3546
# - code_after_count: 53
# - TOTAL: 10402

# %% [markdown]
# #### What positions are visual cells in the notebook?

# %%
##################################################
# 2. What positions are visual cells in the notebook?
##################################################
def describe_viz_cell_positions(c):
  # Overall positioning
  cp_occurrences = 0
  ni_cp_occurrences = 0
  overall_cell_position_sum = 0
  no_import_cell_position_sum = 0
  sum_cells_sum = 0
  overall_position_list = []
  no_import_position_list = []
  sum_of_cells_list = []
  for vcell_key in c:
    # Tally occurrences
    cp_occurrences = cp_occurrences+1
    sum_cells_sum = sum_cells_sum+c[vcell_key]['total_cells_in_nb']

    # List total cells in notebooks
    sum_of_cells_list.append(c[vcell_key]['total_cells_in_nb'])

    overall_cell_position_sum = overall_cell_position_sum + c[vcell_key]['cell_position_in_nb']
    overall_position_list.append(c[vcell_key]['cell_position_in_nb'])

    # Filter out imports
    re_import = r'import\s'
    import_match = re.match(re_import, c[vcell_key]['source'])
    # print(import_match)
    if import_match == None:
      ni_cp_occurrences = ni_cp_occurrences+1
      no_import_cell_position_sum = no_import_cell_position_sum + c[vcell_key]['cell_position_in_nb']
      no_import_position_list.append(c[vcell_key]['cell_position_in_nb'])

  # MEDIAN
  # Sort the lists in ascending order
  overall_position_list = sorted(overall_position_list)
  no_import_position_list = sorted(no_import_position_list)
  sum_of_cells_list = sorted(sum_of_cells_list)

  overall_position_median = statistics.median(overall_position_list)
  no_imports_position_median = statistics.median(no_import_position_list)
  sum_cells_median = statistics.median(sum_of_cells_list)

  # MODE
  # Round numbers in list to whole number
  whole_num_overall_position_list = []
  for op in overall_position_list:
    whole_num_overall_position_list.append(round(op))
  
  whole_num_ni_position_list = []
  for nip in no_import_position_list:
    whole_num_ni_position_list.append(round(nip))
  
  overall_position_mode = statistics.mode(whole_num_overall_position_list)
  no_imports_position_mode = statistics.mode(whole_num_ni_position_list)
  sum_cells_mode = statistics.mode(sum_of_cells_list)

  print(
    '\n\nQ2: What positions are visual cells in the notebook?',
    '\n- OVERALL Avg Mean Cell Position:', overall_cell_position_sum / cp_occurrences,
    '\n- OVERALL Median Cell Position:', overall_position_median,
    '\n- OVERALL Mode Cell Position:', overall_position_mode,
    '\n- NO IMPORTS Avg Mean Cell Position:', no_import_cell_position_sum / ni_cp_occurrences,
    '\n- NO IMPORTS Median Cell Position:', no_imports_position_median,
    '\n- NO IMPORTS Mode Cell Position:', no_imports_position_mode,
    '\n- TOTAL CELLS Avg Mean:', sum_cells_sum / cp_occurrences,
    '\n- TOTAL CELLS Median:', sum_cells_median,
    '\n- TOTAL CELLS Mode:', sum_cells_mode,
    '\n- OVERALL Sum Total Cells:', cp_occurrences,
    '\n- NO IMPORTS Sum Total Cells:', ni_cp_occurrences,
    '\n- IMPORTS ONLY Sum Total Cells:', (ni_cp_occurrences-cp_occurrences),
    '\n'
  )

describe_viz_cell_positions(dict_adj_corpus)
# Out:
# Q2: What positions are visual cells in the notebook?
# - OVERALL Avg Mean Cell Position: 65.78426175765347
# - OVERALL Median Cell Position: 41.009803921568626
# - OVERALL Mode Cell Position: 2
# - NO IMPORTS Avg Mean Cell Position: 68.74707099136471
# - NO IMPORTS Median Cell Position: 43.014084507042256
# - NO IMPORTS Mode Cell Position: 21
# - TOTAL CELLS Avg Mean: 135.87084092434557
# - TOTAL CELLS Median: 99
# - TOTAL CELLS Mode: 827
# - OVERALL Sum Total Cells: 10429
# - NO IMPORTS Sum Total Cells: 9707
# - IMPORTS ONLY Sum Total Cells: -722

# %% [markdown]
# #### Other EDA?

# %% [markdown]
# Feel free to use the pandas dataframes below to do any more EDA, if you'd like. But, the main part of this lesson is to learn more about POS and Categorical tagging.

# %%
# Isolate NON-IMPORT-ADJACENT Markdown Cells
def get_non_import_adj_md_cells(c):
  list__all_cell_content = []
  list__ni_md_before_cell_content = []
  list__ni_md_after_cell_content = []
  for vcell_key in c:
    # Filter out imports
    re_import = r'import\s'
    import_match = re.match(re_import, c[vcell_key]['source'])
    if (import_match == None):
      # Before Vcell
      if c[vcell_key]['adjacent_before'] != 'None' and (c[vcell_key]['adjacent_before']['cell_type'] == 'markdown'):
        list__ni_md_before_cell_content.append(c[vcell_key]['adjacent_before']['source'])
        list__all_cell_content.append(c[vcell_key]['adjacent_before']['source'])
      # After Vcell
      elif c[vcell_key]['adjacent_after'] != 'None' and (c[vcell_key]['adjacent_after']['cell_type'] == 'markdown'):
        list__ni_md_after_cell_content.append(c[vcell_key]['adjacent_after']['source'])
        list__all_cell_content.append(c[vcell_key]['adjacent_after']['source'])

  dict__ni_md_cell_contents = [
    {'all_vcells': list__all_cell_content},
    {'before_vcells': list__ni_md_before_cell_content},
    {'after_vcells': list__ni_md_after_cell_content}
  ]

  return dict__ni_md_cell_contents

# %%
# Remove "Import" cells from samples
dict__ni_adj_corpus = get_non_import_adj_md_cells(dict_adj_corpus)

# Convert dictionaries to dataframes
df__ALL_ni_adj_corpus = pd.DataFrame(dict__ni_adj_corpus[0]['all_vcells']).rename(columns={0:'all_vcells'})
df__BEFORE_ni_adj_corpus = pd.DataFrame(dict__ni_adj_corpus[1]['before_vcells']).rename(columns={0:'before_vcells'})
df__AFTER_ni_adj_corpus = pd.DataFrame(dict__ni_adj_corpus[2]['after_vcells']).rename(columns={0:'after_vcells'})

# %%
# Optional EDA code

# %% [markdown]
# ### 4.3.3 Download LLM

# %% [markdown]
# Ok, now that you know the data a little better than before, we can start our POS and Categorical tags analysis.
#
# First, we need to download DocuScope's LLM: `en_docusco_spacy`. Their (English-only) LLM will process and make predictions about our texts.
#
# - **NOTE**: Another commonly used LLM is spacy's `en_core_web_sm`. This LLM was trained on the annotated "OntoNotes" corpus.
#
# To download and install the `en_docusco_spacy` model,
#
# 1. Execute the cell below: `%pip install en_docusco_spacy`.
# 2. Execute the subsequent cell that uses `spacy` to load the `en_docusco_spacy` model as a variable method.
#
# Now, we can use DS's LLM!

# %%
# %pip install https://huggingface.co/browndw/en_docusco_spacy/resolve/main/en_docusco_spacy-any-py3-none-any.whl
# Out:
# Collecting en-docusco-spacy==any
#   Downloading https://huggingface.co/browndw/en_docusco_spacy/resolve/main/en_docusco_spacy-any-py3-none-any.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from en-docusco-spacy==any) (3.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.31.0)
# Requirement already satisfied: pathy>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.10.3)
# Requirement already satisfied: numpy>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.26.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.0.10)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (58.1.0)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.1.2)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.7.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.10.13)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (8.1.12)
# Requirement already satisfied: packaging>=20.0 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (23.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.0.12)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (6.4.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.4.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (4.66.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/benpost/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (4.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2023.11.17)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.1.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.7.11)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.1.3)
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
nlp = spacy.load('en_docusco_spacy')

# %% [markdown]
# ### 4.3.4 Conducting a corpus analysis with docuscopacy

# %% [markdown]
# In this part of the lesson, we will follow the `docuscospacy` package's [documentation tutorial](https://docuscospacy.readthedocs.io/en/latest/corpus_analysis.html).
#
# Using this LLM, we will conduct some of the following actions to conduct a corpus analysis:
#
# - Token frequencies
# - Ngrams
# - Word collocations around a node word
# - Keyword comparisions against a reference corpus
#
# What's great about `docuscospacy` (DS) is how it provides methods by which review the results from the analysis—another form of EDA!
#
# For example, DS can render outputs, such as tables with either POS or DS tags. This will help you differentiate potential moments when a POS like *can* functions as a *noun* vs. *can as verb*. It may prove interesting! Who knows until see what language patterns may be found!
#
# In another example, we'll review how `docuscospacy` conducts and aggregates multi-token sequenced tags, e.g., where *in spite of* is tagged as a token sequence, it is combined into a signle token.
#
# Overall, our goal is to get to know the data and get creative with how we analyze it.

# %% [markdown]
# ### 4.3.5 Load Corpus Data and Pre-Processing the Corpus

# %% [markdown]
# Accurate tagging requires some processing/cleaning of the data. In the function below, we
#
# 1. Make all of the text uniformly lowercase, because remember that computers define every type of character, such as lowercase `k` vs. uppercase `K`.
# 2. Remove any potential HTML tags in this particular corpus.
# 3. Split the possessive `its` into two tokens.
# 4. Removes carriage returns, tabs, extra spaces, etc.

# %%
def pre_process(txt):
    # 1. remove lowercase
    txt=txt.lower()
    # 2. remove HTML tags
    txt=re.sub('</?.*?>','', txt)
    # 3. remove posessives
    txt = re.sub(r'\bits\b', 'it s', txt)
    txt = re.sub(r'\bIts\b', 'It s', txt)
    # Split text into tokens (tokenize it)
    txt = " ".join(txt.split())
    
    return(txt)

# %%
# You may need to change this variable, if you end up using diferent data sets
nlp.max_length = 1500000
# 1300000 for Kaggle's by-position
print(nlp.max_length)
# Out:
# 1500000

# %%
# %%time
corp = Corpus.from_folder(
    # Note how this uses a folder reference, not just a file.
    # It parses txt files divvied up into differently sorted parts of a corpus/es

    # CHOOSE YOUR CORPUS! :-) The lesson starts by using the Kaggle 'by-position' data.
    # Use this data first. Then, for your application, choose another set if you'd like

    '../data/04-textual-analysis/kaggle-nb-example/by-votes', 
    # '../data/04-textual-analysis/kaggle-nb-example/by-votes',
    
    # NOTE: For the sake of file sizes and in-memory work, I randomly sampled the Jeopardy questions (10000 per document set)
    # '../data/04-textual-analysis/jeopardy/split', 
    spacy_instance=nlp, # Our loaded LLM
    raw_preproc=[pre_process], # Cleaning function
    spacy_token_attrs=['tag', 'ent_iob', 'ent_type', 'is_punct'] #Run these tagging functions
)
# Out:
# CPU times: user 44 s, sys: 5.71 s, total: 49.7 s
# Wall time: 58.3 s

# %% [markdown]
# ### 4.3.6 Basic Summary Stats About Corpus

# %% [markdown]
# It is always a good idea to calcu;ate and review some aggregated information about your corpus. These stats can help you identify potential oddities before you even begin the other work. And, some of the values will be useful later.

# %%
corpus_total = corpus_num_tokens(corp)
corpus_types = vocabulary_size(corp)
total_punct = []
for i in range(0,len(corp)):
    total_punct.append(sum(corp[i]['is_punct']))
total_punct = sum(total_punct)
non_punct = corpus_total - total_punct

print(
    'Aphanumeric tokens:', non_punct, 
    '\nPunctuation tokens:', total_punct, 
    '\nTotal tokens:', corpus_total, 
    '\nToken types:', corpus_types
)
# Out:
# Aphanumeric tokens: 489261
# Punctuation tokens: 123432
# Total tokens: 612693
# Token types: 30347

# %% [markdown]
# ### 4.3.7 Converting the corpus to a DS class object

# %% [markdown]
# Before we generate any tables, we first need to convert the corpus into a convenient object that we can manipulate. From `docuscospacy.corpus_analysis` we will import a number of functions including `convert_corpus`, which takes the object produced by the `Corpus.from_folder` function and converts it into a dictionary, whose keys are the names of the corpus files.

# %%
from docuscospacy.corpus_analysis import convert_corpus, frequency_table, tags_table, ngrams_table, coll_table, tags_dtm, kwic_center_node, keyness_table

# %%
tp = convert_corpus(corp)

# %%
# Listify the keys to review them for accuracy: Did it get all of the desired files?
list(tp.keys())
# Out:
# ['kaggle_LESS_THAN_130_votes_notebooks',
#  'kaggle_GREATER_THAN_130_LESS_THAN_300_votes_notebooks',
#  'kaggle_GREATER_THAN_300_votes_notebooks']

# %%
# Listify a file's content in the dictionary by changing the positional values to change the file and tagged tokens in the file
list(tp.values())[1][10:]
# Out:
# [('after ', 'II', 'B-Narrative'),
#  ('rank ', 'NN1', 'B-AcademicTerms'),
#  ('gauss ', 'NN1', 'O-'),
#  ('and ', 'CC', 'O-'),
#  ('pca ', 'VV0', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('distributions ', 'NN2', 'B-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('data_all', 'NN1', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('there ', 'EX', 'O-'),
#  ('is ', 'VBZ', 'O-'),
#  ('77', 'MC', 'B-InformationExposition'),
#  ('% ', 'Y', 'B-InformationExposition'),
#  ('of ', 'IO', 'O-'),
#  ('missing ', 'VVG', 'B-AcademicWritingMoves'),
#  ('data ', 'NN', 'I-AcademicWritingMoves'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'B-Description'),
#  ('cabin ', 'NN1', 'I-Description'),
#  ('column', 'NN1', 'B-Description'),
#  (', ', 'Y', 'O-'),
#  ('it', 'PPH1', 'B-ForceStressed'),
#  ("'s ", 'VBZ', 'I-ForceStressed'),
#  ('usually ', 'RR', 'B-Narrative'),
#  ('way ', 'RR', 'B-Description'),
#  ('too ', 'RG', 'B-Negative'),
#  ('much ', 'DA1', 'I-Negative'),
#  ('for ', 'IF', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('column ', 'NN1', 'B-Description'),
#  ('to ', 'TO', 'O-'),
#  ('be ', 'VBI', 'O-'),
#  ('exploitable', 'JJ', 'O-'),
#  (', ', 'Y', 'B-MetadiscourseCohesive'),
#  ('but ', 'CCB', 'I-MetadiscourseCohesive'),
#  ('as ', 'CSA', 'B-Character'),
#  ('we ', 'PPIS2', 'I-Character'),
#  ('have ', 'VH0', 'O-'),
#  ('a ', 'AT1', 'O-'),
#  ('small ', 'JJ', 'B-InformationExposition'),
#  ('amount ', 'NN1', 'I-InformationExposition'),
#  ('of ', 'IO', 'O-'),
#  ('data', 'NN', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-FirstPerson'),
#  ('will ', 'VM', 'I-FirstPerson'),
#  ('still ', 'RR', 'B-Updates'),
#  ('try ', 'VVI', 'B-Strategic'),
#  ('to ', 'TO', 'I-Strategic'),
#  ('use ', 'VVI', 'O-'),
#  ('it ', 'PPH1', 'O-'),
#  ('in ', 'II', 'O-'),
#  ('feature ', 'NN1', 'O-'),
#  ('engineering', 'NN1', 'O-'),
#  ('. ', 'Y', 'O-'),
#  ('\\n', 'NP1', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('age', 'NN1', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-FirstPerson'),
#  ('will ', 'VM', 'I-FirstPerson'),
#  ('either ', 'RR', 'B-MetadiscourseCohesive'),
#  ('interpolate ', 'VVI', 'B-Negative'),
#  ('missing ', 'JJ', 'B-Negative'),
#  ('values ', 'NN2', 'O-'),
#  ('or ', 'CC', 'B-MetadiscourseCohesive'),
#  ('we ', 'PPIS2', 'B-FirstPerson'),
#  ('will ', 'VM', 'I-FirstPerson'),
#  ('fill ', 'VVI', 'I-FirstPerson'),
#  ('it ', 'PPH1', 'O-'),
#  ('with ', 'IW', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('mean ', 'JJ', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('the ', 'AT', 'B-InformationExposition'),
#  ('corresponding ', 'JJ', 'I-InformationExposition'),
#  ('category ', 'NN1', 'B-Reasoning'),
#  ('(', 'Y', 'O-'),
#  ('in ', 'II', 'O-'),
#  ('term ', 'NN1', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('class', 'NN1', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('age', 'NN1', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('sex', 'NN1', 'B-AcademicTerms'),
#  (') ', 'Y', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('passenger', 'NN1', 'B-Character'),
#  ('. ', 'Y', 'O-'),
#  ('\\n', 'NP1', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('there ', 'EX', 'O-'),
#  ('is ', 'VBZ', 'O-'),
#  ('only ', 'RR', 'B-InformationExposition'),
#  ('two ', 'MC', 'I-InformationExposition'),
#  ('missing ', 'JJ', 'B-Negative'),
#  ('values ', 'NN2', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('embarked ', 'JJ', 'B-Description'),
#  ('column', 'NN1', 'B-Description'),
#  (', ', 'Y', 'O-'),
#  ('let', 'VM21', 'B-Interactive'),
#  ("'s ", 'VM22', 'I-Interactive'),
#  ('try ', 'VVI', 'I-Interactive'),
#  ('to ', 'TO', 'I-Interactive'),
#  ('replace ', 'VVI', 'B-InformationExposition'),
#  ('it', 'PPH1', 'I-InformationExposition'),
#  ('. ', 'Y', 'O-'),
#  ('below ', 'RL', 'O-'),
#  ('is ', 'VBZ', 'B-ForceStressed'),
#  ('the ', 'AT', 'I-ForceStressed'),
#  ('distribution ', 'NN1', 'I-ForceStressed'),
#  ('of ', 'IO', 'O-'),
#  ('embarked ', 'VVD', 'B-Description'),
#  ('according ', 'II21', 'B-Citation'),
#  ('to ', 'II22', 'I-Citation'),
#  ('fare ', 'VVI', 'B-Description'),
#  ('and ', 'CC', 'O-'),
#  ('sex', 'NN1', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('and ', 'CC', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('two ', 'MC', 'B-InformationExposition'),
#  ('observations ', 'NN2', 'B-AcademicTerms'),
#  ('with ', 'IW', 'O-'),
#  ('missing ', 'VVG', 'B-Negative'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('embarked', 'VVD', 'B-Negative'),
#  ('"', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('value', 'NN1', 'O-'),
#  ('. ', 'Y', 'B-Character'),
#  ('let', 'VM21', 'I-Character'),
#  ("'s ", 'VM22', 'I-Character'),
#  ('look ', 'VVI', 'O-'),
#  ('at ', 'II', 'O-'),
#  ('there ', 'RL', 'O-'),
#  ('two ', 'MC', 'B-InformationExposition'),
#  ('observations ', 'NN2', 'B-AcademicTerms'),
#  ('and ', 'CC', 'O-'),
#  ('choose ', 'VV0', 'B-Character'),
#  ('the ', 'AT', 'I-Character'),
#  ('best ', 'JJT', 'B-Positive'),
#  ('matching ', 'JJ', 'O-'),
#  ('embarked ', 'JJ', 'B-Description'),
#  ('value ', 'NN1', 'O-'),
#  ('according ', 'II21', 'B-Citation'),
#  ('to ', 'II22', 'I-Citation'),
#  ('their ', 'APPGE', 'I-Citation'),
#  ('fare ', 'NN1', 'B-Positive'),
#  ('value ', 'NN1', 'I-Positive'),
#  ('and ', 'CC', 'O-'),
#  ('sex', 'NN1', 'B-AcademicTerms'),
#  (':', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('both ', 'DB2', 'O-'),
#  ('passengers ', 'NN2', 'B-Character'),
#  ('are ', 'VBR', 'B-InformationStates'),
#  ('female ', 'JJ', 'B-Character'),
#  ('who ', 'PNQS', 'O-'),
#  ('paid ', 'VVD', 'O-'),
#  ('80 ', 'MC', 'B-InformationExposition'),
#  ('dollars ', 'NNU2', 'B-InformationTopics'),
#  ('as ', 'CSA', 'O-'),
#  ('fare ', 'NN1', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('their ', 'APPGE', 'B-Character'),
#  ('tickets', 'NN2', 'B-Description'),
#  ('. ', 'Y', 'B-MetadiscourseInteractive'),
#  ('moreover', 'RR', 'I-MetadiscourseInteractive'),
#  (', ', 'Y', 'I-MetadiscourseInteractive'),
#  ('they ', 'PPHS2', 'O-'),
#  ('have ', 'VH0', 'O-'),
#  ('the ', 'AT', 'B-InformationExposition'),
#  ('same ', 'DA', 'I-InformationExposition'),
#  ('ticket ', 'NN1', 'B-Description'),
#  ('and ', 'CC', 'O-'),
#  ('cabin', 'NN1', 'B-Description'),
#  (', ', 'Y', 'B-Reasoning'),
#  ('so ', 'CS', 'I-Reasoning'),
#  ('they ', 'PPHS2', 'O-'),
#  ('probably ', 'RR', 'B-ConfidenceHigh'),
#  ('had ', 'VHD', 'B-Negative'),
#  ('to ', 'TO', 'I-Negative'),
#  ('board ', 'VVI', 'B-AcademicTerms'),
#  ('at ', 'II', 'B-Description'),
#  ('the ', 'AT', 'I-Description'),
#  ('same ', 'DA', 'O-'),
#  ('place', 'NN1', 'O-'),
#  ('! ', 'Y', 'B-ForceStressed'),
#  ('according ', 'II21', 'B-Citation'),
#  ('to ', 'II22', 'I-Citation'),
#  ('the ', 'AT', 'I-Citation'),
#  ('distribution ', 'NN1', 'B-AcademicTerms'),
#  ('above', 'RL', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('the ', 'AT', 'B-InformationExposition'),
#  ('more ', 'RGR', 'I-InformationExposition'),
#  ('probable ', 'JJ', 'B-ConfidenceHedged'),
#  ('embarked ', 'JJ', 'B-Description'),
#  ('value ', 'NN1', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('them ', 'PPHO2', 'B-Narrative'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('cherbourg ', 'NN1', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('c', 'ZZ1', 'O-'),
#  (')', 'Y', 'O-'),
#  ('. ', 'Y', 'O-'),
#  ('we', 'PPIS2', 'B-FirstPerson'),
#  ("'ll ", 'VM', 'I-FirstPerson'),
#  ('replace ', 'VVI', 'B-InformationExposition'),
#  ('these ', 'DD2', 'B-Narrative'),
#  ('two ', 'MC', 'B-InformationExposition'),
#  ('missing ', 'JJ', 'B-Negative'),
#  ('values ', 'NN2', 'O-'),
#  ('later ', 'RRR', 'B-Narrative'),
#  ('during ', 'II', 'B-Narrative'),
#  ('features ', 'NN2', 'O-'),
#  ('engineering ', 'NN1', 'B-InformationTopics'),
#  ('part', 'NN1', 'I-InformationTopics'),
#  ('. ', 'Y', 'O-'),
#  ('\\n\\n', 'NP1', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('finally', 'RR', 'B-Narrative'),
#  (', ', 'Y', 'I-Narrative'),
#  ('let', 'VM21', 'B-Interactive'),
#  ("'s ", 'VM22', 'I-Interactive'),
#  ('plot ', 'VVI', 'B-AcademicTerms'),
#  ('some ', 'DD', 'B-InformationExposition'),
#  ('histograms ', 'NN2', 'B-Strategic'),
#  ('to ', 'TO', 'O-'),
#  ('visualise ', 'VVI', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('distributions ', 'NN2', 'B-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('our ', 'APPGE', 'B-Positive'),
#  ('variables', 'NN2', 'B-InformationChange'),
#  (':', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('both ', 'DB2', 'O-'),
#  ('passengers ', 'NN2', 'B-Character'),
#  ('are ', 'VBR', 'B-InformationStates'),
#  ('female ', 'JJ', 'B-Character'),
#  ('who ', 'PNQS', 'O-'),
#  ('paid ', 'VVD', 'O-'),
#  ('80 ', 'MC', 'B-InformationExposition'),
#  ('dollars ', 'NNU2', 'B-InformationTopics'),
#  ('as ', 'CSA', 'O-'),
#  ('fare ', 'NN1', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('their ', 'APPGE', 'B-Character'),
#  ('tickets', 'NN2', 'B-Description'),
#  ('. ', 'Y', 'B-MetadiscourseInteractive'),
#  ('moreover', 'RR', 'I-MetadiscourseInteractive'),
#  (', ', 'Y', 'I-MetadiscourseInteractive'),
#  ('they ', 'PPHS2', 'O-'),
#  ('have ', 'VH0', 'O-'),
#  ('the ', 'AT', 'B-InformationExposition'),
#  ('same ', 'DA', 'I-InformationExposition'),
#  ('ticket ', 'NN1', 'B-Description'),
#  ('and ', 'CC', 'O-'),
#  ('cabin', 'NN1', 'B-Description'),
#  (', ', 'Y', 'B-Reasoning'),
#  ('so ', 'CS', 'I-Reasoning'),
#  ('they ', 'PPHS2', 'O-'),
#  ('probably ', 'RR', 'B-ConfidenceHigh'),
#  ('had ', 'VHD', 'B-Negative'),
#  ('to ', 'TO', 'I-Negative'),
#  ('board ', 'VVI', 'B-AcademicTerms'),
#  ('at ', 'II', 'B-Description'),
#  ('the ', 'AT', 'I-Description'),
#  ('same ', 'DA', 'O-'),
#  ('place', 'NN1', 'O-'),
#  ('! ', 'Y', 'B-ForceStressed'),
#  ('according ', 'II21', 'B-Citation'),
#  ('to ', 'II22', 'I-Citation'),
#  ('the ', 'AT', 'I-Citation'),
#  ('distribution ', 'NN1', 'B-AcademicTerms'),
#  ('above', 'RL', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('the ', 'AT', 'B-InformationExposition'),
#  ('more ', 'RGR', 'I-InformationExposition'),
#  ('probable ', 'JJ', 'B-ConfidenceHedged'),
#  ('embarked ', 'JJ', 'B-Description'),
#  ('value ', 'NN1', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('them ', 'PPHO2', 'B-Narrative'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('cherbourg ', 'NN1', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('c', 'ZZ1', 'O-'),
#  (')', 'Y', 'O-'),
#  ('. ', 'Y', 'O-'),
#  ('we', 'PPIS2', 'B-FirstPerson'),
#  ("'ll ", 'VM', 'I-FirstPerson'),
#  ('replace ', 'VVI', 'B-InformationExposition'),
#  ('these ', 'DD2', 'B-Narrative'),
#  ('two ', 'MC', 'B-InformationExposition'),
#  ('missing ', 'JJ', 'B-Negative'),
#  ('values ', 'NN2', 'O-'),
#  ('later ', 'RRR', 'B-Narrative'),
#  ('during ', 'II', 'B-Narrative'),
#  ('features ', 'NN2', 'O-'),
#  ('engineering ', 'NN1', 'B-InformationTopics'),
#  ('part', 'NN1', 'I-InformationTopics'),
#  ('. ', 'Y', 'O-'),
#  ('\\n\\n', 'NP1', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('finally', 'RR', 'B-Narrative'),
#  (', ', 'Y', 'I-Narrative'),
#  ('let', 'VM21', 'B-Interactive'),
#  ("'s ", 'VM22', 'I-Interactive'),
#  ('plot ', 'VVI', 'B-AcademicTerms'),
#  ('some ', 'DD', 'B-InformationExposition'),
#  ('histograms ', 'NN2', 'B-Strategic'),
#  ('to ', 'TO', 'O-'),
#  ('visualise ', 'VVI', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('distributions ', 'NN2', 'B-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('our ', 'APPGE', 'B-Positive'),
#  ('variables', 'NN2', 'B-InformationChange'),
#  (':', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('with ', 'IW', 'O-'),
#  ('this ', 'DD1', 'O-'),
#  ('first ', 'MD', 'B-Inquiry'),
#  ('exploration', 'NN1', 'I-Inquiry'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-MetadiscourseInteractive'),
#  ('can ', 'VM', 'I-MetadiscourseInteractive'),
#  ('see ', 'VVI', 'I-MetadiscourseInteractive'),
#  ('that ', 'DD1', 'I-MetadiscourseInteractive'),
#  (':', 'Y', 'O-'),
#  ('\\n\\n', 'NN1', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('only ', 'RR', 'B-InformationExposition'),
#  ('aproximately ', 'RR', 'B-Positive'),
#  ('35', 'MC', 'B-InformationExposition'),
#  ('% ', 'Y', 'B-InformationExposition'),
#  ('of ', 'IO', 'O-'),
#  ('passengers ', 'NN2', 'B-Character'),
#  ('survived ', 'VVD', 'B-Narrative'),
#  ('...', 'Y', 'O-'),
#  ('\\n', 'FO', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('more ', 'DAR', 'B-InformationExposition'),
#  ('than ', 'CSN', 'I-InformationExposition'),
#  ('the ', 'AT', 'I-InformationExposition'),
#  ('half ', 'NN1', 'B-InformationExposition'),
#  ('of ', 'IO', 'O-'),
#  ('passengers ', 'NN2', 'B-Character'),
#  ('are ', 'VBR', 'B-InformationStates'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('lowest ', 'JJT', 'B-InformationExposition'),
#  ('class ', 'NN1', 'B-AcademicTerms'),
#  ('(', 'Y', 'O-'),
#  ('pclass ', 'NN1', 'B-Description'),
#  ('= ', 'Y', 'O-'),
#  ('3)\\n', 'FO', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('most ', 'DAT', 'B-ConfidenceHedged'),
#  ('of ', 'IO', 'I-ConfidenceHedged'),
#  ('the ', 'AT', 'I-ConfidenceHedged'),
#  ('fare ', 'NN1', 'B-Description'),
#  ('tickets ', 'NN2', 'I-Description'),
#  ('are ', 'VBR', 'B-InformationStates'),
#  ('below ', 'RG', 'O-'),
#  ('50\\n', 'MC', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('majority ', 'NN1', 'B-PublicTerms'),
#  ('of ', 'IO', 'I-PublicTerms'),
#  ('passengers ', 'NN2', 'B-Character'),
#  ('are ', 'VBR', 'B-InformationStates'),
#  ('alone ', 'JJ', 'B-Character'),
#  ('(', 'Y', 'O-'),
#  ('sibsp ', 'NN1', 'B-Description'),
#  ('and ', 'CC', 'O-'),
#  ('parch)\\n\\n*note ', 'NN1', 'O-'),
#  (': ', 'Y', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('eda ', 'NN1', 'B-AcademicTerms'),
#  ('is ', 'VBZ', 'B-Interactive'),
#  ('not ', 'XX', 'I-Interactive'),
#  ('complete ', 'JJ', 'B-ForceStressed'),
#  ('at ', 'RR21', 'B-ForceStressed'),
#  ('all ', 'RR22', 'I-ForceStressed'),
#  ('since ', 'CS', 'O-'),
#  ('it ', 'PPH1', 'B-Negative'),
#  ('is ', 'VBZ', 'I-Negative'),
#  ('not ', 'XX', 'I-Negative'),
#  ('the ', 'AT', 'B-AcademicWritingMoves'),
#  ('purpose ', 'NN1', 'I-AcademicWritingMoves'),
#  ('of ', 'IO', 'I-AcademicWritingMoves'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('kernel ', 'NN1', 'B-Description'),
#  ('to ', 'TO', 'O-'),
#  ('make ', 'VVI', 'B-InformationReportVerbs'),
#  ('a ', 'AT1', 'B-Description'),
#  ('deep ', 'JJ', 'I-Description'),
#  ('exploration ', 'NN1', 'B-Inquiry'),
#  ('of ', 'IO', 'O-'),
#  ('data', 'NN', 'B-AcademicTerms'),
#  ('. ', 'Y', 'B-MetadiscourseCohesive'),
#  ('however', 'RR', 'I-MetadiscourseCohesive'),
#  (', ', 'Y', 'O-'),
#  ('you ', 'PPY', 'B-Interactive'),
#  ('can ', 'VM', 'I-Interactive'),
#  ('look ', 'VVI', 'B-Description'),
#  ('at ', 'II', 'I-Description'),
#  ('my ', 'APPGE', 'B-FirstPerson'),
#  ('[', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('eda ', 'NN1', 'B-AcademicTerms'),
#  ('kernel**](https://www.kaggle.com', 'NN1', 'O-'),
#  ('/', 'Y', 'O-'),
#  ('nhlr21', 'FO', 'O-'),
#  ('/', 'Y', 'O-'),
#  ('titanic', 'JJ', 'B-ForceStressed'),
#  ('-', 'Y', 'O-'),
#  ('colorful', 'JJ', 'B-ForceStressed'),
#  ('-', 'Y', 'O-'),
#  ('eda', 'NN1', 'B-AcademicTerms'),
#  (') ', 'Y', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('competition ', 'NN1', 'B-Strategic'),
#  ('if ', 'CS', 'B-Contingent'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('interests ', 'NN2', 'O-'),
#  ('you', 'PPY', 'B-ForceStressed'),
#  ('.', 'Y', 'I-ForceStressed'),
#  ('*', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-FirstPerson'),
#  ('are ', 'VBR', 'I-FirstPerson'),
#  ('not ', 'XX', 'O-'),
#  ('done ', 'VDN', 'O-'),
#  ('yet ', 'RR', 'B-Reasoning'),
#  ('! ', 'Y', 'O-'),
#  ('what ', 'DDQ', 'O-'),
#  ('about ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('results ', 'NN2', 'B-Reasoning'),
#  ('? ', 'Y', 'B-Interactive'),
#  ('i', 'ZZ1', 'B-FirstPerson'),
#  ("'ve ", 'VH0', 'I-FirstPerson'),
#  ('tried ', 'VVN', 'B-Strategic'),
#  ('to ', 'TO', 'I-Strategic'),
#  ('make ', 'VVI', 'B-InformationReportVerbs'),
#  ('30 ', 'MC', 'B-InformationExposition'),
#  ('submissions ', 'NN2', 'B-AcademicTerms'),
#  ('with ', 'IW', 'O-'),
#  ('this ', 'DD1', 'O-'),
#  ('classifier', 'NN1', 'B-Character'),
#  (', ', 'Y', 'O-'),
#  ('here ', 'RL', 'B-Narrative'),
#  ('are ', 'VBR', 'I-Narrative'),
#  ('the ', 'AT', 'I-Narrative'),
#  ('results ', 'NN2', 'B-Reasoning'),
#  (':', 'Y', 'O-'),
#  ('\\n ', 'NP1', 'O-'),
#  ('\\n| ', 'JJ', 'O-'),
#  ('score ', 'NN1', 'O-'),
#  ('| ', 'Y', 'O-'),
#  ('nb ', 'NN1', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('occurrences ', 'NN2', 'O-'),
#  ('|\\n|--------- ', 'JJ', 'O-'),
#  ('| ', 'Y', 'O-'),
#  ('-------------------------- ', 'Y', 'O-'),
#  ('|\\n| ', 'FO', 'O-'),
#  ('0.77511 ', 'MC', 'O-'),
#  ('| ', 'Y', 'O-'),
#  ('2 ', 'MC', 'B-InformationExposition'),
#  ('|\\n| ', 'FO', 'O-'),
#  ('0.77990 ', 'MC', 'O-'),
#  ('| ', 'Y', 'O-'),
#  ('3 ', 'MC', 'B-InformationExposition'),
#  ('|\\n| ', 'FO', 'O-'),
#  ('0.78468 ', 'MC', 'O-'),
#  ('| ', 'Y', 'O-'),
#  ('10 ', 'MC', 'B-InformationExposition'),
#  ('|\\n| ', 'FO', 'O-'),
#  ('0.78947 ', 'MC', 'O-'),
#  ('| ', 'Y', 'O-'),
#  ('11 ', 'MC', 'B-InformationExposition'),
#  ('|\\n| ', 'FO', 'O-'),
#  ('0.79425 ', 'MC', 'O-'),
#  ('| ', 'Y', 'O-'),
#  ('2 ', 'MC', 'B-InformationExposition'),
#  ('|\\n| ', 'FO', 'O-'),
#  ('0.79904 ', 'MC', 'O-'),
#  ('| ', 'Y', 'O-'),
#  ('2 ', 'MC', 'B-InformationExposition'),
#  ('|\\n\\n\\n', 'NP1', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('although ', 'CS', 'B-MetadiscourseCohesive'),
#  ('i ', 'ZZ1', 'B-ConfidenceHigh'),
#  ('know ', 'VV0', 'I-ConfidenceHigh'),
#  ('that ', 'CST', 'I-ConfidenceHigh'),
#  ('we ', 'PPIS2', 'B-ConfidenceHedged'),
#  ('can ', 'VM', 'I-ConfidenceHedged'),
#  ('do ', 'VDI', 'B-ForceStressed'),
#  ('much ', 'RR', 'O-'),
#  ('better', 'RRR', 'B-InformationExposition'),
#  (', ', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('0.79904 ', 'MC', 'O-'),
#  ('still ', 'JJ', 'B-Updates'),
#  ('places ', 'VVZ', 'O-'),
#  ('us ', 'PPIO2', 'O-'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'B-Description'),
#  ('top ', 'NN1', 'I-Description'),
#  ('16', 'MC', 'B-InformationExposition'),
#  ('%', 'Y', 'B-InformationExposition'),
#  ('. ', 'Y', 'O-'),
#  ('on ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('other ', 'JJ', 'O-'),
#  ('hand', 'NN1', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-MetadiscourseInteractive'),
#  ('see ', 'VV0', 'I-MetadiscourseInteractive'),
#  ('that ', 'CST', 'I-MetadiscourseInteractive'),
#  ('our ', 'APPGE', 'B-Positive'),
#  ('homemade ', 'JJ', 'O-'),
#  ('classifier ', 'NN1', 'O-'),
#  ('has ', 'VHZ', 'B-InformationStates'),
#  ('reduced ', 'VVN', 'B-InformationChange'),
#  ('the ', 'AT', 'I-InformationChange'),
#  ('variance ', 'NN1', 'B-Contingent'),
#  ('so ', 'CS', 'B-Reasoning'),
#  ('it ', 'PPH1', 'I-Reasoning'),
#  ('is ', 'VBZ', 'I-Reasoning'),
#  ('reliable ', 'JJ', 'B-Positive'),
#  ('and ', 'CC', 'O-'),
#  ('constant ', 'JJ', 'B-InformationExposition'),
#  ('in ', 'II', 'O-'),
#  ('it ', 'PPH1', 'O-'),
#  ('s ', 'GE', 'O-'),
#  ('performance ', 'NN1', 'B-InformationTopics'),
#  ('(', 'Y', 'O-'),
#  ('something ', 'PN1', 'B-ForceStressed'),
#  ('that ', 'CST', 'I-ForceStressed'),
#  ('is ', 'VBZ', 'B-Interactive'),
#  ('not ', 'XX', 'I-Interactive'),
#  ('tested ', 'VVN', 'O-'),
#  ('by ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('leaderboard ', 'NN1', 'B-Description'),
#  ('but ', 'CCB', 'B-Negative'),
#  ('still ', 'RR', 'I-Negative'),
#  ('important ', 'JJ', 'B-ForceStressed'),
#  ('for ', 'IF', 'O-'),
#  ('a ', 'AT1', 'O-'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('sceintist', 'NN1', 'O-'),
#  (')', 'Y', 'O-'),
#  ('. ', 'Y', 'B-MetadiscourseInteractive'),
#  ('moreover', 'RR', 'I-MetadiscourseInteractive'),
#  (', ', 'Y', 'B-FirstPerson'),
#  ('our ', 'APPGE', 'I-FirstPerson'),
#  ('solution ', 'NN1', 'B-AcademicTerms'),
#  ('remains ', 'VVZ', 'B-Narrative'),
#  ('simple ', 'JJ', 'B-ForceStressed'),
#  ('and ', 'CC', 'O-'),
#  ('accessible ', 'JJ', 'B-Facilitate'),
#  ('even ', 'RR', 'B-ForceStressed'),
#  ('for ', 'IF', 'I-ForceStressed'),
#  ('beginners', 'NN2', 'B-Character'),
#  ('. ', 'Y', 'O-'),
#  ('\\n\\n', 'NP1', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('thank ', 'VV0', 'B-Interactive'),
#  ('you ', 'PPY', 'I-Interactive'),
#  ('for ', 'IF', 'B-Interactive'),
#  ('your ', 'APPGE', 'I-Interactive'),
#  ('reading', 'NN1', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('feel ', 'VV0', 'B-Positive'),
#  ('free ', 'JJ', 'I-Positive'),
#  ('to ', 'TO', 'I-Positive'),
#  ('fork ', 'VVI', 'B-Description'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('kernel ', 'NN1', 'B-Description'),
#  ('and ', 'CC', 'O-'),
#  ('improve ', 'VV0', 'B-InformationChangePositive'),
#  ('it', 'PPH1', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('and ', 'CC', 'O-'),
#  ('enjoy ', 'VV0', 'B-Positive'),
#  ('datascience ', 'NN1', 'B-Description'),
#  (':', 'Y', 'O-'),
#  ('d', 'ZZ1', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('check ', 'NN1', 'B-Inquiry'),
#  ('out ', 'RP', 'I-Inquiry'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('beautiful ', 'JJ', 'B-Positive'),
#  ('distribution ', 'NN1', 'B-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('kaggle ', 'NN1', 'B-Description'),
#  ('scoring ', 'NN1', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('our ', 'APPGE', 'B-Positive'),
#  ('homemade ', 'JJ', 'O-'),
#  ('classifier ', 'NN1', 'O-'),
#  ('!', 'Y', 'B-ForceStressed'),
#  ('* ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('characteristics/ ', 'NN2', 'O-'),
#  ('demographics\\nlet', 'FO', 'O-'),
#  ("'s ", 'GE', 'O-'),
#  ('look ', 'NN1', 'B-Strategic'),
#  ('at ', 'II', 'I-Strategic'),
#  ('the ', 'AT', 'I-Strategic'),
#  ('demographics ', 'NN2', 'B-AcademicTerms'),
#  ('or ', 'CC', 'B-MetadiscourseCohesive'),
#  ('characteristics ', 'NN2', 'B-InformationTopics'),
#  ('first', 'MD', 'O-'),
#  (', ', 'Y', 'B-InformationExposition'),
#  ('like ', 'II', 'I-InformationExposition'),
#  ('country', 'NN1', 'B-InformationPlace'),
#  (', ', 'Y', 'O-'),
#  ('gender ', 'NN1', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('age ', 'NN1', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('highest ', 'JJT', 'B-InformationExposition'),
#  ('education ', 'NN1', 'B-AcademicTerms'),
#  ('etc.\\nalthough ', 'NN2', 'O-'),
#  ('you ', 'PPY', 'B-Interactive'),
#  ('ca', 'VM', 'B-Negative'),
#  ("n't ", 'XX', 'I-Negative'),
#  ('work ', 'VVI', 'I-Negative'),
#  ('your ', 'APPGE', 'B-Interactive'),
#  ('way ', 'NN1', 'O-'),
#  ('through ', 'II', 'O-'),
#  ('most ', 'DAT', 'B-InformationExposition'),
#  ('of ', 'IO', 'O-'),
#  ('these', 'DD2', 'O-'),
#  (', ', 'Y', 'B-MetadiscourseCohesive'),
#  ('but ', 'CCB', 'I-MetadiscourseCohesive'),
#  ('it ', 'PPH1', 'B-ConfidenceHigh'),
#  ('is ', 'VBZ', 'I-ConfidenceHigh'),
#  ('crucial ', 'JJ', 'B-ForceStressed'),
#  ('in ', 'II', 'O-'),
#  ('understanding ', 'VVG', 'B-Character'),
#  ('our ', 'APPGE', 'B-Positive'),
#  ('data', 'NN', 'O-'),
#  ('.', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('>', 'Y', 'B-Interactive'),
#  ('* ', 'Y', 'O-'),
#  ('most ', 'DAT', 'B-ConfidenceHedged'),
#  ('of ', 'IO', 'I-ConfidenceHedged'),
#  ('the ', 'AT', 'I-ConfidenceHedged'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('scientists ', 'NN2', 'B-Character'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'B-Reasoning'),
#  ('survey ', 'NN1', 'I-Reasoning'),
#  ('come ', 'VV0', 'B-Narrative'),
#  ('from ', 'II', 'I-Narrative'),
#  ('usa ', 'NN1', 'B-Character'),
#  ('and ', 'CC', 'O-'),
#  ('india', 'NP1', 'B-InformationPlace'),
#  (', ', 'Y', 'B-MetadiscourseCohesive'),
#  ('like ', 'II', 'I-MetadiscourseCohesive'),
#  ('the ', 'AT', 'I-MetadiscourseCohesive'),
#  ('last ', 'MD', 'B-Narrative'),
#  ('two ', 'MC', 'B-InformationExposition'),
#  ('years.they ', 'PPHS2', 'O-'),
#  ('are ', 'VBR', 'B-InformationStates'),
#  ('\\nfollowed ', 'NN2', 'O-'),
#  ('by ', 'II', 'O-'),
#  ('brazil ', 'NP1', 'B-InformationPlace'),
#  ('and ', 'CC', 'O-'),
#  ('russia', 'NN1', 'B-InformationPlace'),
#  ('. ', 'Y', 'O-'),
#  ('\\n', 'NP1', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-MetadiscourseInteractive'),
#  ('have ', 'VH0', 'I-MetadiscourseInteractive'),
#  ('just ', 'RR', 'B-ForceStressed'),
#  ('5 ', 'MC', 'I-ForceStressed'),
#  ('countries ', 'NN2', 'B-InformationPlace'),
#  ('from ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('african ', 'JJ', 'B-Character'),
#  ('sub', 'NN1', 'B-InformationExposition'),
#  ('-', 'Y', 'O-'),
#  ('continent', 'NN1', 'B-InformationPlace'),
#  (', ', 'Y', 'O-'),
#  ('with ', 'IW', 'B-ForceStressed'),
#  ('very ', 'RG', 'I-ForceStressed'),
#  ('low ', 'JJ', 'B-AcademicTerms'),
#  ('participation', 'NN1', 'O-'),
#  ('. ', 'Y', 'O-'),
#  ('the ', 'AT', 'B-AcademicTerms'),
#  ('other ', 'JJ', 'I-AcademicTerms'),
#  ('countries ', 'NN2', 'B-InformationPlace'),
#  ('because ', 'II21', 'B-Reasoning'),
#  ('of ', 'II22', 'I-Reasoning'),
#  ('very ', 'RG', 'B-ConfidenceHigh'),
#  ('low ', 'JJ', 'B-AcademicTerms'),
#  ('responses ', 'NN2', 'B-Narrative'),
#  ('must ', 'VM', 'B-Character'),
#  ('be ', 'VBI', 'I-Character'),
#  ('grouped ', 'VVN', 'B-InformationTopics'),
#  ('in ', 'II', 'O-'),
#  ('others.\\n', 'FO', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('the ', 'AT', 'B-InformationExposition'),
#  ('same ', 'DA', 'I-InformationExposition'),
#  ('goes ', 'VVZ', 'B-Narrative'),
#  ('for ', 'IF', 'I-Narrative'),
#  ('south ', 'ND1', 'B-InformationPlace'),
#  ('america', 'NP1', 'I-InformationPlace'),
#  (',', 'Y', 'O-'),
#  ('except ', 'II21', 'B-Contingent'),
#  ('for ', 'II22', 'I-Contingent'),
#  ('brazil', 'NP1', 'B-InformationPlace'),
#  (', ', 'Y', 'O-'),
#  ('there ', 'EX', 'O-'),
#  ('is ', 'VBZ', 'O-'),
#  ('very ', 'RG', 'B-ConfidenceHigh'),
#  ('low ', 'JJ', 'B-AcademicTerms'),
#  ('participation ', 'NN1', 'O-'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('survey.\\n', 'FO', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('>', 'Y', 'B-Interactive'),
#  ('* ', 'Y', 'O-'),
#  ('most ', 'DAT', 'B-ConfidenceHedged'),
#  ('of ', 'IO', 'I-ConfidenceHedged'),
#  ('the ', 'AT', 'I-ConfidenceHedged'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('scientists ', 'NN2', 'B-Character'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'B-Reasoning'),
#  ('survey ', 'NN1', 'I-Reasoning'),
#  ('come ', 'VV0', 'B-Narrative'),
#  ('from ', 'II', 'I-Narrative'),
#  ('usa ', 'NN1', 'B-Character'),
#  ('and ', 'CC', 'O-'),
#  ('india', 'NP1', 'B-InformationPlace'),
#  (', ', 'Y', 'B-MetadiscourseCohesive'),
#  ('like ', 'II', 'I-MetadiscourseCohesive'),
#  ('the ', 'AT', 'I-MetadiscourseCohesive'),
#  ('last ', 'MD', 'B-Narrative'),
#  ('two ', 'MC', 'B-InformationExposition'),
#  ('years.they ', 'PPHS2', 'O-'),
#  ('are ', 'VBR', 'B-InformationStates'),
#  ('\\nfollowed ', 'NN2', 'O-'),
#  ('by ', 'II', 'O-'),
#  ('brazil ', 'NP1', 'B-InformationPlace'),
#  ('and ', 'CC', 'O-'),
#  ('russia', 'NN1', 'B-InformationPlace'),
#  ('. ', 'Y', 'O-'),
#  ('\\n', 'NP1', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-MetadiscourseInteractive'),
#  ('have ', 'VH0', 'I-MetadiscourseInteractive'),
#  ('just ', 'RR', 'B-ForceStressed'),
#  ('5 ', 'MC', 'I-ForceStressed'),
#  ('countries ', 'NN2', 'B-InformationPlace'),
#  ('from ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('african ', 'JJ', 'B-Character'),
#  ('sub', 'NN1', 'B-InformationExposition'),
#  ('-', 'Y', 'O-'),
#  ('continent', 'NN1', 'B-InformationPlace'),
#  (', ', 'Y', 'O-'),
#  ('with ', 'IW', 'B-ForceStressed'),
#  ('very ', 'RG', 'I-ForceStressed'),
#  ('low ', 'JJ', 'B-AcademicTerms'),
#  ('participation', 'NN1', 'O-'),
#  ('. ', 'Y', 'O-'),
#  ('the ', 'AT', 'B-AcademicTerms'),
#  ('other ', 'JJ', 'I-AcademicTerms'),
#  ('countries ', 'NN2', 'B-InformationPlace'),
#  ('because ', 'II21', 'B-Reasoning'),
#  ('of ', 'II22', 'I-Reasoning'),
#  ('very ', 'RG', 'B-ConfidenceHigh'),
#  ('low ', 'JJ', 'B-AcademicTerms'),
#  ('responses ', 'NN2', 'B-Narrative'),
#  ('must ', 'VM', 'B-Character'),
#  ('be ', 'VBI', 'I-Character'),
#  ('grouped ', 'VVN', 'B-InformationTopics'),
#  ('in ', 'II', 'O-'),
#  ('others.\\n', 'FO', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('the ', 'AT', 'B-InformationExposition'),
#  ('same ', 'DA', 'I-InformationExposition'),
#  ('goes ', 'VVZ', 'B-Narrative'),
#  ('for ', 'IF', 'I-Narrative'),
#  ('south ', 'ND1', 'B-InformationPlace'),
#  ('america', 'NP1', 'I-InformationPlace'),
#  (',', 'Y', 'O-'),
#  ('except ', 'II21', 'B-Contingent'),
#  ('for ', 'II22', 'I-Contingent'),
#  ('brazil', 'NP1', 'B-InformationPlace'),
#  (', ', 'Y', 'O-'),
#  ('there ', 'EX', 'O-'),
#  ('is ', 'VBZ', 'O-'),
#  ('very ', 'RG', 'B-ConfidenceHigh'),
#  ('low ', 'JJ', 'B-AcademicTerms'),
#  ('participation ', 'NN1', 'O-'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('survey.\\n', 'FO', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('> ', 'Y', 'B-Interactive'),
#  ('* ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('male ', 'JJ', 'B-AcademicWritingMoves'),
#  ('data ', 'NN', 'I-AcademicWritingMoves'),
#  ('scientits ', 'NN2', 'B-Description'),
#  ('are ', 'VBR', 'B-InformationExposition'),
#  ('more ', 'DAR', 'I-InformationExposition'),
#  ('than ', 'CSN', 'I-InformationExposition'),
#  ('5 ', 'MC', 'B-InformationExposition'),
#  ('times ', 'NNT2', 'O-'),
#  ('their ', 'APPGE', 'B-Character'),
#  ('female ', 'JJ', 'B-Character'),
#  ('counterparts', 'NN2', 'B-MetadiscourseCohesive'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('. ', 'Y', 'B-MetadiscourseCohesive'),
#  ('this ', 'DD1', 'I-MetadiscourseCohesive'),
#  ('leads ', 'VVZ', 'B-Reasoning'),
#  ('to ', 'II', 'I-Reasoning'),
#  ('*', 'Y', 'O-'),
#  ('bias', 'NN1', 'B-Negative'),
#  ('* ', 'Y', 'O-'),
#  ('in ', 'II', 'B-Description'),
#  ('machine ', 'NN1', 'I-Description'),
#  ('learning', 'NN1', 'B-Positive'),
#  ('. ', 'Y', 'I-Positive'),
#  ('ml ', 'NNU', 'O-'),
#  ('algorithms ', 'NN2', 'B-AcademicTerms'),
#  ('are ', 'VBR', 'B-InformationStates'),
#  ('representative ', 'JJ', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('they ', 'PPHS2', 'O-'),
#  ('eat ', 'VV0', 'B-Narrative'),
#  ('and ', 'CC', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('people ', 'NN', 'B-Character'),
#  ('who ', 'PNQS', 'O-'),
#  ('build ', 'VV0', 'B-InformationReportVerbs'),
#  ('them', 'PPHO2', 'B-Narrative'),
#  ('. ', 'Y', 'O-'),
#  ('an ', 'AT1', 'O-'),
#  ('interesting ', 'JJ', 'B-Inquiry'),
#  ('incident ', 'NN1', 'B-Negative'),
#  ('can ', 'VM', 'B-ConfidenceHedged'),
#  ('be ', 'VBI', 'I-ConfidenceHedged'),
#  ('cited ', 'VVN', 'B-Citation'),
#  ('here', 'RL', 'B-Narrative'),
#  (', ', 'Y', 'I-Narrative'),
#  ('back ', 'RP', 'O-'),
#  ('in ', 'II', 'O-'),
#  ('2014 ', 'MC', 'B-Narrative'),
#  ('amazon ', 'NN1', 'B-Description'),
#  ('trained ', 'VVD', 'B-InformationTopics'),
#  ('a ', 'AT1', 'I-InformationTopics'),
#  ('ml ', 'NNU', 'O-'),
#  ('system ', 'NN1', 'B-AcademicTerms'),
#  ('to ', 'TO', 'O-'),
#  ('hire ', 'VVI', 'B-Strategic'),
#  ('people ', 'NN', 'B-Character'),
#  ('and ', 'CC', 'B-ForceStressed'),
#  ('it ', 'PPH1', 'I-ForceStressed'),
#  ('was ', 'VBDZ', 'I-ForceStressed'),
#  ('unreasonably ', 'RR', 'B-Negative'),
#  ('throwing ', 'VVG', 'B-Description'),
#  ('away ', 'RL', 'I-Description'),
#  ('women', 'NN2', 'B-Character'),
#  ("'s ", 'GE', 'I-Character'),
#  ('resumes', 'NN2', 'B-Narrative'),
#  ('. ', 'Y', 'O-'),
#  ('a ', 'AT1', 'O-'),
#  ('further ', 'JJR', 'B-AcademicWritingMoves'),
#  ('study ', 'NN1', 'I-AcademicWritingMoves'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'B-Negative'),
#  ('problem ', 'NN1', 'I-Negative'),
#  ('found ', 'VVD', 'B-Inquiry'),
#  ('out ', 'RP', 'I-Inquiry'),
#  ('that ', 'CST', 'I-Inquiry'),
#  ('the ', 'AT', 'O-'),
#  ('consequently', 'RR', 'B-Reasoning'),
#  (', ', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('ai ', 'FU', 'O-'),
#  ('concluded ', 'VVD', 'B-Reasoning'),
#  ('that ', 'CST', 'I-Reasoning'),
#  ('men ', 'NN2', 'B-Character'),
#  ('were ', 'VBDR', 'B-Narrative'),
#  ('preferable', 'JJ', 'O-'),
#  ('. ', 'Y', 'B-ForceStressed'),
#  ('it ', 'PPH1', 'I-ForceStressed'),
#  ('downgraded ', 'VVD', 'B-InformationChangeNegative'),
#  ('resumes ', 'NN2', 'B-Narrative'),
#  ('containing ', 'VVG', 'B-InformationReportVerbs'),
#  ('the ', 'AT', 'I-InformationReportVerbs'),
#  ('words ', 'NN2', 'B-AcademicTerms'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('women\'s"",and ', 'NP1', 'O-'),
#  ('filtered ', 'VVD', 'B-Narrative'),
#  ('out ', 'RP', 'I-Narrative'),
#  ('candidates ', 'NN2', 'B-Character'),
#  ('who', 'PNQS', 'B-Interactive'),
#  ("'d ", 'VHD', 'I-Interactive'),
#  ('attended ', 'VVN', 'O-'),
#  ('two ', 'MC', 'B-InformationExposition'),
#  ('women', 'NN2', 'B-Character'),
#  ("'s ", 'GE', 'I-Character'),
#  ('only ', 'JJ', 'B-InformationExposition'),
#  ('colleges.[[1]](https://www.businessinsider.in', 'NP1', 'O-'),
#  ('/', 'Y', 'O-'),
#  ('tech', 'NN1', 'B-AcademicTerms'),
#  ('/', 'Y', 'O-'),
#  ('amazon', 'NN1', 'B-Description'),
#  ('-', 'Y', 'O-'),
#  ('built', 'VVD', 'B-InformationReportVerbs'),
#  ('-', 'Y', 'O-'),
#  ('an', 'AT1', 'O-'),
#  ('-', 'Y', 'O-'),
#  ('ai', 'FU', 'B-Character'),
#  ('-', 'Y', 'O-'),
#  ('to', 'II', 'O-'),
#  ('-', 'Y', 'O-'),
#  ('hire', 'VV0', 'B-Strategic'),
#  ('-', 'Y', 'O-'),
#  ('people', 'NN', 'B-Character'),
#  ('-', 'Y', 'O-'),
#  ('but', 'CCB', 'B-MetadiscourseCohesive'),
#  ...]

# %% [markdown]
# ### 4.3.8 Generate Frequency Tables

# %% [markdown]
# We can use DS's `frequency_table` function to easily review counts. Here's the description from the API:
#
# <blockquote>
# <h4><a href="https://docuscospacy.readthedocs.io/en/latest/api.html#corpus-analysis-frequency-table-tok-n-tokens-count-by-pos">corpus_analysis.frequency_table(tok, n_tokens, count_by=’pos’)</a></h4>
# <p>Generate a count of token frequencies.</p>
# <div><dl class="field-list simple">
# <dt class="field-odd">Parameters</dt>
# <dd class="field-odd"><ul class="simple">
# <li><p><strong>tok</strong> - A dictionary of tuples as generated by the <cite>convert_corpus</cite> function</p></li>
# <li><p><strong>n_tokens</strong> - A count of total tokens against which to normalize</p></li>
# <li><p><strong>count_by</strong> - One of ‘pos’ or ‘ds’ for aggregating tokens</p></li>
# </ul>
# </dd>
# <dt class="field-even">Return</dt>
# <dd class="field-even"><ul class="simple">
# <li><p>a dataframe of absolute frequencies, normalized frequencies (per million tokens) and ranges</p></li>
# </ul>
# </dd>
# </dl>
# </div>
# </blockquote>
#
# `frequency_table` also [normalizes](https://en.wikipedia.org/wiki/Normalization_(statistics)) the data across the corpus, so that the counts can be compared across the corpi, i.e. compare and contrast the returned absolute frequencies (col `AF`), normalized relative frequencies (per million tokens) (col `RF`), and ranges (col `Range`). token shares a common scale.

# %% [markdown]
# #### 4.3.8.1 POS tables

# %% [markdown]
# In our first frequency table, we will normalize the counts with the non_punct (or the total number of tokens that are not punctuation), because POS token counts omit tokens tagged as punctuation. Later we will count ALLTHETHINGS, since DS includes punctuation.

# %%
freq_table_POS = frequency_table(
    tok=tp, # converted corpus into dict objs
    count_by='pos', # Count by POS tags
    n_tokens=non_punct # norm the corpus by excluding punctuation
)

# %%
freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_63efe">
#   <thead>
#     <tr>
#       <th id="T_63efe_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_63efe_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_63efe_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_63efe_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_63efe_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_63efe_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_63efe_row0_col1" class="data row0 col1" >AT</td>
#       <td id="T_63efe_row0_col2" class="data row0 col2" >27889</td>
#       <td id="T_63efe_row0_col3" class="data row0 col3" >57002.30</td>
#       <td id="T_63efe_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_63efe_row1_col0" class="data row1 col0" >of</td>
#       <td id="T_63efe_row1_col1" class="data row1 col1" >IO</td>
#       <td id="T_63efe_row1_col2" class="data row1 col2" >12999</td>
#       <td id="T_63efe_row1_col3" class="data row1 col3" >26568.64</td>
#       <td id="T_63efe_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_63efe_row2_col0" class="data row2 col0" >and</td>
#       <td id="T_63efe_row2_col1" class="data row2 col1" >CC</td>
#       <td id="T_63efe_row2_col2" class="data row2 col2" >9628</td>
#       <td id="T_63efe_row2_col3" class="data row2 col3" >19678.66</td>
#       <td id="T_63efe_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_63efe_row3_col0" class="data row3 col0" >a</td>
#       <td id="T_63efe_row3_col1" class="data row3 col1" >AT1</td>
#       <td id="T_63efe_row3_col2" class="data row3 col2" >8922</td>
#       <td id="T_63efe_row3_col3" class="data row3 col3" >18235.67</td>
#       <td id="T_63efe_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_63efe_row4_col0" class="data row4 col0" >is</td>
#       <td id="T_63efe_row4_col1" class="data row4 col1" >VBZ</td>
#       <td id="T_63efe_row4_col2" class="data row4 col2" >8161</td>
#       <td id="T_63efe_row4_col3" class="data row4 col3" >16680.26</td>
#       <td id="T_63efe_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_63efe_row5_col0" class="data row5 col0" >to</td>
#       <td id="T_63efe_row5_col1" class="data row5 col1" >TO</td>
#       <td id="T_63efe_row5_col2" class="data row5 col2" >6944</td>
#       <td id="T_63efe_row5_col3" class="data row5 col3" >14192.83</td>
#       <td id="T_63efe_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_63efe_row6_col0" class="data row6 col0" >in</td>
#       <td id="T_63efe_row6_col1" class="data row6 col1" >II</td>
#       <td id="T_63efe_row6_col2" class="data row6 col2" >6936</td>
#       <td id="T_63efe_row6_col3" class="data row6 col3" >14176.48</td>
#       <td id="T_63efe_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_63efe_row7_col0" class="data row7 col0" >we</td>
#       <td id="T_63efe_row7_col1" class="data row7 col1" >PPIS2</td>
#       <td id="T_63efe_row7_col2" class="data row7 col2" >5662</td>
#       <td id="T_63efe_row7_col3" class="data row7 col3" >11572.56</td>
#       <td id="T_63efe_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_63efe_row8_col0" class="data row8 col0" >are</td>
#       <td id="T_63efe_row8_col1" class="data row8 col1" >VBR</td>
#       <td id="T_63efe_row8_col2" class="data row8 col2" >4937</td>
#       <td id="T_63efe_row8_col3" class="data row8 col3" >10090.73</td>
#       <td id="T_63efe_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_63efe_row9_col0" class="data row9 col0" >for</td>
#       <td id="T_63efe_row9_col1" class="data row9 col1" >IF</td>
#       <td id="T_63efe_row9_col2" class="data row9 col2" >4517</td>
#       <td id="T_63efe_row9_col3" class="data row9 col3" >9232.29</td>
#       <td id="T_63efe_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Since it's a dataframe, we can filter and sort it easily with the `query()` method. Yay!
#
# Below, we filter for an AF greater than 10 and token tags as verbs (starting with ‘V’).
#
# Refer to the [CLAWS7 POS table](https://ucrel.lancs.ac.uk/claws7tags.html) for desired speech tags to filter against.

# %%
freq_table_POS.query('AF > 10 and Tag.str.startswith("V")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d5cd9">
#   <thead>
#     <tr>
#       <th id="T_d5cd9_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_d5cd9_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_d5cd9_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_d5cd9_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_d5cd9_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d5cd9_row0_col0" class="data row0 col0" >is</td>
#       <td id="T_d5cd9_row0_col1" class="data row0 col1" >VBZ</td>
#       <td id="T_d5cd9_row0_col2" class="data row0 col2" >8161</td>
#       <td id="T_d5cd9_row0_col3" class="data row0 col3" >16680.26</td>
#       <td id="T_d5cd9_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_d5cd9_row1_col0" class="data row1 col0" >are</td>
#       <td id="T_d5cd9_row1_col1" class="data row1 col1" >VBR</td>
#       <td id="T_d5cd9_row1_col2" class="data row1 col2" >4937</td>
#       <td id="T_d5cd9_row1_col3" class="data row1 col3" >10090.73</td>
#       <td id="T_d5cd9_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_d5cd9_row2_col0" class="data row2 col0" >can</td>
#       <td id="T_d5cd9_row2_col1" class="data row2 col1" >VM</td>
#       <td id="T_d5cd9_row2_col2" class="data row2 col2" >3198</td>
#       <td id="T_d5cd9_row2_col3" class="data row2 col3" >6536.39</td>
#       <td id="T_d5cd9_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_d5cd9_row3_col0" class="data row3 col0" >be</td>
#       <td id="T_d5cd9_row3_col1" class="data row3 col1" >VBI</td>
#       <td id="T_d5cd9_row3_col2" class="data row3 col2" >2840</td>
#       <td id="T_d5cd9_row3_col3" class="data row3 col3" >5804.67</td>
#       <td id="T_d5cd9_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_d5cd9_row4_col0" class="data row4 col0" >have</td>
#       <td id="T_d5cd9_row4_col1" class="data row4 col1" >VH0</td>
#       <td id="T_d5cd9_row4_col2" class="data row4 col2" >1914</td>
#       <td id="T_d5cd9_row4_col3" class="data row4 col3" >3912.02</td>
#       <td id="T_d5cd9_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_d5cd9_row5_col0" class="data row5 col0" >will</td>
#       <td id="T_d5cd9_row5_col1" class="data row5 col1" >VM</td>
#       <td id="T_d5cd9_row5_col2" class="data row5 col2" >1851</td>
#       <td id="T_d5cd9_row5_col3" class="data row5 col3" >3783.26</td>
#       <td id="T_d5cd9_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_d5cd9_row6_col0" class="data row6 col0" >see</td>
#       <td id="T_d5cd9_row6_col1" class="data row6 col1" >VVI</td>
#       <td id="T_d5cd9_row6_col2" class="data row6 col2" >1247</td>
#       <td id="T_d5cd9_row6_col3" class="data row6 col3" >2548.74</td>
#       <td id="T_d5cd9_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_d5cd9_row7_col0" class="data row7 col0" >has</td>
#       <td id="T_d5cd9_row7_col1" class="data row7 col1" >VHZ</td>
#       <td id="T_d5cd9_row7_col2" class="data row7 col2" >1019</td>
#       <td id="T_d5cd9_row7_col3" class="data row7 col3" >2082.73</td>
#       <td id="T_d5cd9_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_d5cd9_row8_col0" class="data row8 col0" >do</td>
#       <td id="T_d5cd9_row8_col1" class="data row8 col1" >VD0</td>
#       <td id="T_d5cd9_row8_col2" class="data row8 col2" >1002</td>
#       <td id="T_d5cd9_row8_col3" class="data row8 col3" >2047.99</td>
#       <td id="T_d5cd9_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_d5cd9_row9_col0" class="data row9 col0" >let 's</td>
#       <td id="T_d5cd9_row9_col1" class="data row9 col1" >VM</td>
#       <td id="T_d5cd9_row9_col2" class="data row9 col2" >853</td>
#       <td id="T_d5cd9_row9_col3" class="data row9 col3" >1743.45</td>
#       <td id="T_d5cd9_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Filter for adverbs, yo! How are we modifying those verbs?
freq_table_POS.query('Tag.str.startswith("R")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0c92b">
#   <thead>
#     <tr>
#       <th id="T_0c92b_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_0c92b_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_0c92b_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_0c92b_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_0c92b_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0c92b_row0_col0" class="data row0 col0" >also</td>
#       <td id="T_0c92b_row0_col1" class="data row0 col1" >RR</td>
#       <td id="T_0c92b_row0_col2" class="data row0 col2" >1157</td>
#       <td id="T_0c92b_row0_col3" class="data row0 col3" >2364.79</td>
#       <td id="T_0c92b_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row1_col0" class="data row1 col0" >very</td>
#       <td id="T_0c92b_row1_col1" class="data row1 col1" >RG</td>
#       <td id="T_0c92b_row1_col2" class="data row1 col2" >829</td>
#       <td id="T_0c92b_row1_col3" class="data row1 col3" >1694.39</td>
#       <td id="T_0c92b_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row2_col0" class="data row2 col0" >most</td>
#       <td id="T_0c92b_row2_col1" class="data row2 col1" >RGT</td>
#       <td id="T_0c92b_row2_col2" class="data row2 col2" >805</td>
#       <td id="T_0c92b_row2_col3" class="data row2 col3" >1645.34</td>
#       <td id="T_0c92b_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row3_col0" class="data row3 col0" >more</td>
#       <td id="T_0c92b_row3_col1" class="data row3 col1" >RGR</td>
#       <td id="T_0c92b_row3_col2" class="data row3 col2" >688</td>
#       <td id="T_0c92b_row3_col3" class="data row3 col3" >1406.20</td>
#       <td id="T_0c92b_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row4_col0" class="data row4 col0" >how</td>
#       <td id="T_0c92b_row4_col1" class="data row4 col1" >RRQ</td>
#       <td id="T_0c92b_row4_col2" class="data row4 col2" >634</td>
#       <td id="T_0c92b_row4_col3" class="data row4 col3" >1295.83</td>
#       <td id="T_0c92b_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row5_col0" class="data row5 col0" >only</td>
#       <td id="T_0c92b_row5_col1" class="data row5 col1" >RR</td>
#       <td id="T_0c92b_row5_col2" class="data row5 col2" >611</td>
#       <td id="T_0c92b_row5_col3" class="data row5 col3" >1248.82</td>
#       <td id="T_0c92b_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row6_col0" class="data row6 col0" >here</td>
#       <td id="T_0c92b_row6_col1" class="data row6 col1" >RL</td>
#       <td id="T_0c92b_row6_col2" class="data row6 col2" >546</td>
#       <td id="T_0c92b_row6_col3" class="data row6 col3" >1115.97</td>
#       <td id="T_0c92b_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row7_col0" class="data row7 col0" >now</td>
#       <td id="T_0c92b_row7_col1" class="data row7 col1" >RT</td>
#       <td id="T_0c92b_row7_col2" class="data row7 col2" >541</td>
#       <td id="T_0c92b_row7_col3" class="data row7 col3" >1105.75</td>
#       <td id="T_0c92b_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row8_col0" class="data row8 col0" >then</td>
#       <td id="T_0c92b_row8_col1" class="data row8 col1" >RT</td>
#       <td id="T_0c92b_row8_col2" class="data row8 col2" >478</td>
#       <td id="T_0c92b_row8_col3" class="data row8 col3" >976.98</td>
#       <td id="T_0c92b_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row9_col0" class="data row9 col0" >so</td>
#       <td id="T_0c92b_row9_col1" class="data row9 col1" >RR</td>
#       <td id="T_0c92b_row9_col2" class="data row9 col2" >466</td>
#       <td id="T_0c92b_row9_col3" class="data row9 col3" >952.46</td>
#       <td id="T_0c92b_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row10_col0" class="data row10 col0" >just</td>
#       <td id="T_0c92b_row10_col1" class="data row10 col1" >RR</td>
#       <td id="T_0c92b_row10_col2" class="data row10 col2" >402</td>
#       <td id="T_0c92b_row10_col3" class="data row10 col3" >821.65</td>
#       <td id="T_0c92b_row10_col4" class="data row10 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row11_col0" class="data row11 col0" >out</td>
#       <td id="T_0c92b_row11_col1" class="data row11 col1" >RP</td>
#       <td id="T_0c92b_row11_col2" class="data row11 col2" >392</td>
#       <td id="T_0c92b_row11_col3" class="data row11 col3" >801.21</td>
#       <td id="T_0c92b_row11_col4" class="data row11 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row12_col0" class="data row12 col0" >however</td>
#       <td id="T_0c92b_row12_col1" class="data row12 col1" >RR</td>
#       <td id="T_0c92b_row12_col2" class="data row12 col2" >347</td>
#       <td id="T_0c92b_row12_col3" class="data row12 col3" >709.23</td>
#       <td id="T_0c92b_row12_col4" class="data row12 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row13_col0" class="data row13 col0" >how</td>
#       <td id="T_0c92b_row13_col1" class="data row13 col1" >RGQ</td>
#       <td id="T_0c92b_row13_col2" class="data row13 col2" >311</td>
#       <td id="T_0c92b_row13_col3" class="data row13 col3" >635.65</td>
#       <td id="T_0c92b_row13_col4" class="data row13 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row14_col0" class="data row14 col0" >up</td>
#       <td id="T_0c92b_row14_col1" class="data row14 col1" >RP</td>
#       <td id="T_0c92b_row14_col2" class="data row14 col2" >304</td>
#       <td id="T_0c92b_row14_col3" class="data row14 col3" >621.35</td>
#       <td id="T_0c92b_row14_col4" class="data row14 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row15_col0" class="data row15 col0" >much</td>
#       <td id="T_0c92b_row15_col1" class="data row15 col1" >RR</td>
#       <td id="T_0c92b_row15_col2" class="data row15 col2" >287</td>
#       <td id="T_0c92b_row15_col3" class="data row15 col3" >586.60</td>
#       <td id="T_0c92b_row15_col4" class="data row15 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row16_col0" class="data row16 col0" >more</td>
#       <td id="T_0c92b_row16_col1" class="data row16 col1" >RRR</td>
#       <td id="T_0c92b_row16_col2" class="data row16 col2" >282</td>
#       <td id="T_0c92b_row16_col3" class="data row16 col3" >576.38</td>
#       <td id="T_0c92b_row16_col4" class="data row16 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row17_col0" class="data row17 col0" >almost</td>
#       <td id="T_0c92b_row17_col1" class="data row17 col1" >RR</td>
#       <td id="T_0c92b_row17_col2" class="data row17 col2" >265</td>
#       <td id="T_0c92b_row17_col3" class="data row17 col3" >541.63</td>
#       <td id="T_0c92b_row17_col4" class="data row17 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row18_col0" class="data row18 col0" >below</td>
#       <td id="T_0c92b_row18_col1" class="data row18 col1" >RL</td>
#       <td id="T_0c92b_row18_col2" class="data row18 col2" >260</td>
#       <td id="T_0c92b_row18_col3" class="data row18 col3" >531.41</td>
#       <td id="T_0c92b_row18_col4" class="data row18 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c92b_row19_col0" class="data row19 col0" >well</td>
#       <td id="T_0c92b_row19_col1" class="data row19 col1" >RR</td>
#       <td id="T_0c92b_row19_col2" class="data row19 col2" >233</td>
#       <td id="T_0c92b_row19_col3" class="data row19 col3" >476.23</td>
#       <td id="T_0c92b_row19_col4" class="data row19 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.2 DS category tables

# %% [markdown]
# Note how we normalize by ‘corpus_total’ as DocuScope includes punctuation in its tagging system.

# %%
freq_table_DS = frequency_table(
    tok=tp, 
    n_tokens=corpus_total, 
    count_by='ds'
)

# %%
freq_table_DS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_35d88">
#   <thead>
#     <tr>
#       <th id="T_35d88_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_35d88_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_35d88_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_35d88_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_35d88_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_35d88_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_35d88_row0_col1" class="data row0 col1" >Untagged</td>
#       <td id="T_35d88_row0_col2" class="data row0 col2" >16488</td>
#       <td id="T_35d88_row0_col3" class="data row0 col3" >26910.70</td>
#       <td id="T_35d88_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35d88_row1_col0" class="data row1 col0" >and</td>
#       <td id="T_35d88_row1_col1" class="data row1 col1" >Untagged</td>
#       <td id="T_35d88_row1_col2" class="data row1 col2" >9123</td>
#       <td id="T_35d88_row1_col3" class="data row1 col3" >14890.00</td>
#       <td id="T_35d88_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35d88_row2_col0" class="data row2 col0" >of</td>
#       <td id="T_35d88_row2_col1" class="data row2 col1" >Untagged</td>
#       <td id="T_35d88_row2_col2" class="data row2 col2" >8960</td>
#       <td id="T_35d88_row2_col3" class="data row2 col3" >14623.96</td>
#       <td id="T_35d88_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35d88_row3_col0" class="data row3 col0" >in</td>
#       <td id="T_35d88_row3_col1" class="data row3 col1" >Untagged</td>
#       <td id="T_35d88_row3_col2" class="data row3 col2" >4856</td>
#       <td id="T_35d88_row3_col3" class="data row3 col3" >7925.67</td>
#       <td id="T_35d88_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35d88_row4_col0" class="data row4 col0" >a</td>
#       <td id="T_35d88_row4_col1" class="data row4 col1" >Untagged</td>
#       <td id="T_35d88_row4_col2" class="data row4 col2" >4647</td>
#       <td id="T_35d88_row4_col3" class="data row4 col3" >7584.55</td>
#       <td id="T_35d88_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35d88_row5_col0" class="data row5 col0" >to</td>
#       <td id="T_35d88_row5_col1" class="data row5 col1" >Untagged</td>
#       <td id="T_35d88_row5_col2" class="data row5 col2" >4306</td>
#       <td id="T_35d88_row5_col3" class="data row5 col3" >7027.99</td>
#       <td id="T_35d88_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35d88_row6_col0" class="data row6 col0" >for</td>
#       <td id="T_35d88_row6_col1" class="data row6 col1" >Untagged</td>
#       <td id="T_35d88_row6_col2" class="data row6 col2" >3539</td>
#       <td id="T_35d88_row6_col3" class="data row6 col3" >5776.14</td>
#       <td id="T_35d88_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35d88_row7_col0" class="data row7 col0" >that</td>
#       <td id="T_35d88_row7_col1" class="data row7 col1" >Untagged</td>
#       <td id="T_35d88_row7_col2" class="data row7 col2" >2760</td>
#       <td id="T_35d88_row7_col3" class="data row7 col3" >4504.70</td>
#       <td id="T_35d88_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35d88_row8_col0" class="data row8 col0" >with</td>
#       <td id="T_35d88_row8_col1" class="data row8 col1" >Untagged</td>
#       <td id="T_35d88_row8_col2" class="data row8 col2" >2581</td>
#       <td id="T_35d88_row8_col3" class="data row8 col3" >4212.55</td>
#       <td id="T_35d88_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35d88_row9_col0" class="data row9 col0" >is</td>
#       <td id="T_35d88_row9_col1" class="data row9 col1" >Information States</td>
#       <td id="T_35d88_row9_col2" class="data row9 col2" >2312</td>
#       <td id="T_35d88_row9_col3" class="data row9 col3" >3773.50</td>
#       <td id="T_35d88_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's sort by DS tags!
#
# Review the DS tags in their [user docs](https://docuscospacy.readthedocs.io/en/latest/docuscope.html#categories).

# %%
# By INQUIRY
freq_table_DS.query('Tag.str.startswith("Inquiry")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b179e">
#   <thead>
#     <tr>
#       <th id="T_b179e_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_b179e_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_b179e_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_b179e_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_b179e_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b179e_row0_col0" class="data row0 col0" >learning</td>
#       <td id="T_b179e_row0_col1" class="data row0 col1" >Inquiry</td>
#       <td id="T_b179e_row0_col2" class="data row0 col2" >974</td>
#       <td id="T_b179e_row0_col3" class="data row0 col3" >1589.70</td>
#       <td id="T_b179e_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b179e_row1_col0" class="data row1 col0" >interesting</td>
#       <td id="T_b179e_row1_col1" class="data row1 col1" >Inquiry</td>
#       <td id="T_b179e_row1_col2" class="data row1 col2" >249</td>
#       <td id="T_b179e_row1_col3" class="data row1 col3" >406.40</td>
#       <td id="T_b179e_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b179e_row2_col0" class="data row2 col0" >learn</td>
#       <td id="T_b179e_row2_col1" class="data row2 col1" >Inquiry</td>
#       <td id="T_b179e_row2_col2" class="data row2 col2" >223</td>
#       <td id="T_b179e_row2_col3" class="data row2 col3" >363.97</td>
#       <td id="T_b179e_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b179e_row3_col0" class="data row3 col0" >evaluation</td>
#       <td id="T_b179e_row3_col1" class="data row3 col1" >Inquiry</td>
#       <td id="T_b179e_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_b179e_row3_col3" class="data row3 col3" >163.21</td>
#       <td id="T_b179e_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b179e_row4_col0" class="data row4 col0" >hypothesis</td>
#       <td id="T_b179e_row4_col1" class="data row4 col1" >Inquiry</td>
#       <td id="T_b179e_row4_col2" class="data row4 col2" >77</td>
#       <td id="T_b179e_row4_col3" class="data row4 col3" >125.67</td>
#       <td id="T_b179e_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b179e_row5_col0" class="data row5 col0" >reviews</td>
#       <td id="T_b179e_row5_col1" class="data row5 col1" >Inquiry</td>
#       <td id="T_b179e_row5_col2" class="data row5 col2" >58</td>
#       <td id="T_b179e_row5_col3" class="data row5 col3" >94.66</td>
#       <td id="T_b179e_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b179e_row6_col0" class="data row6 col0" >findings</td>
#       <td id="T_b179e_row6_col1" class="data row6 col1" >Inquiry</td>
#       <td id="T_b179e_row6_col2" class="data row6 col2" >57</td>
#       <td id="T_b179e_row6_col3" class="data row6 col3" >93.03</td>
#       <td id="T_b179e_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b179e_row7_col0" class="data row7 col0" >the question</td>
#       <td id="T_b179e_row7_col1" class="data row7 col1" >Inquiry</td>
#       <td id="T_b179e_row7_col2" class="data row7 col2" >55</td>
#       <td id="T_b179e_row7_col3" class="data row7 col3" >89.77</td>
#       <td id="T_b179e_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b179e_row8_col0" class="data row8 col0" >to understand</td>
#       <td id="T_b179e_row8_col1" class="data row8 col1" >Inquiry</td>
#       <td id="T_b179e_row8_col2" class="data row8 col2" >49</td>
#       <td id="T_b179e_row8_col3" class="data row8 col3" >79.97</td>
#       <td id="T_b179e_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b179e_row9_col0" class="data row9 col0" >find out</td>
#       <td id="T_b179e_row9_col1" class="data row9 col1" >Inquiry</td>
#       <td id="T_b179e_row9_col2" class="data row9 col2" >48</td>
#       <td id="T_b179e_row9_col3" class="data row9 col3" >78.34</td>
#       <td id="T_b179e_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# By INFORMATION TOPICS
freq_table_DS.query('Tag.str.startswith("Information Topics")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ebdbb">
#   <thead>
#     <tr>
#       <th id="T_ebdbb_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_ebdbb_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_ebdbb_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_ebdbb_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_ebdbb_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ebdbb_row0_col0" class="data row0 col0" >other</td>
#       <td id="T_ebdbb_row0_col1" class="data row0 col1" >Information Topics</td>
#       <td id="T_ebdbb_row0_col2" class="data row0 col2" >467</td>
#       <td id="T_ebdbb_row0_col3" class="data row0 col3" >762.21</td>
#       <td id="T_ebdbb_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row1_col0" class="data row1 col0" >data science</td>
#       <td id="T_ebdbb_row1_col1" class="data row1 col1" >Information Topics</td>
#       <td id="T_ebdbb_row1_col2" class="data row1 col2" >396</td>
#       <td id="T_ebdbb_row1_col3" class="data row1 col3" >646.33</td>
#       <td id="T_ebdbb_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row2_col0" class="data row2 col0" >non</td>
#       <td id="T_ebdbb_row2_col1" class="data row2 col1" >Information Topics</td>
#       <td id="T_ebdbb_row2_col2" class="data row2 col2" >350</td>
#       <td id="T_ebdbb_row2_col3" class="data row2 col3" >571.25</td>
#       <td id="T_ebdbb_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row3_col0" class="data row3 col0" >training</td>
#       <td id="T_ebdbb_row3_col1" class="data row3 col1" >Information Topics</td>
#       <td id="T_ebdbb_row3_col2" class="data row3 col2" >256</td>
#       <td id="T_ebdbb_row3_col3" class="data row3 col3" >417.83</td>
#       <td id="T_ebdbb_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row4_col0" class="data row4 col0" >time</td>
#       <td id="T_ebdbb_row4_col1" class="data row4 col1" >Information Topics</td>
#       <td id="T_ebdbb_row4_col2" class="data row4 col2" >238</td>
#       <td id="T_ebdbb_row4_col3" class="data row4 col3" >388.45</td>
#       <td id="T_ebdbb_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row5_col0" class="data row5 col0" >job</td>
#       <td id="T_ebdbb_row5_col1" class="data row5 col1" >Information Topics</td>
#       <td id="T_ebdbb_row5_col2" class="data row5 col2" >236</td>
#       <td id="T_ebdbb_row5_col3" class="data row5 col3" >385.18</td>
#       <td id="T_ebdbb_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row6_col0" class="data row6 col0" >price</td>
#       <td id="T_ebdbb_row6_col1" class="data row6 col1" >Information Topics</td>
#       <td id="T_ebdbb_row6_col2" class="data row6 col2" >192</td>
#       <td id="T_ebdbb_row6_col3" class="data row6 col3" >313.37</td>
#       <td id="T_ebdbb_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row7_col0" class="data row7 col0" >series</td>
#       <td id="T_ebdbb_row7_col1" class="data row7 col1" >Information Topics</td>
#       <td id="T_ebdbb_row7_col2" class="data row7 col2" >191</td>
#       <td id="T_ebdbb_row7_col3" class="data row7 col3" >311.74</td>
#       <td id="T_ebdbb_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row8_col0" class="data row8 col0" >group</td>
#       <td id="T_ebdbb_row8_col1" class="data row8 col1" >Information Topics</td>
#       <td id="T_ebdbb_row8_col2" class="data row8 col2" >182</td>
#       <td id="T_ebdbb_row8_col3" class="data row8 col3" >297.05</td>
#       <td id="T_ebdbb_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row9_col0" class="data row9 col0" >type</td>
#       <td id="T_ebdbb_row9_col1" class="data row9 col1" >Information Topics</td>
#       <td id="T_ebdbb_row9_col2" class="data row9 col2" >173</td>
#       <td id="T_ebdbb_row9_col3" class="data row9 col3" >282.36</td>
#       <td id="T_ebdbb_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row10_col0" class="data row10 col0" >performance</td>
#       <td id="T_ebdbb_row10_col1" class="data row10 col1" >Information Topics</td>
#       <td id="T_ebdbb_row10_col2" class="data row10 col2" >165</td>
#       <td id="T_ebdbb_row10_col3" class="data row10 col3" >269.30</td>
#       <td id="T_ebdbb_row10_col4" class="data row10 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row11_col0" class="data row11 col0" >online</td>
#       <td id="T_ebdbb_row11_col1" class="data row11 col1" >Information Topics</td>
#       <td id="T_ebdbb_row11_col2" class="data row11 col2" >163</td>
#       <td id="T_ebdbb_row11_col3" class="data row11 col3" >266.04</td>
#       <td id="T_ebdbb_row11_col4" class="data row11 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row12_col0" class="data row12 col0" >sales</td>
#       <td id="T_ebdbb_row12_col1" class="data row12 col1" >Information Topics</td>
#       <td id="T_ebdbb_row12_col2" class="data row12 col2" >153</td>
#       <td id="T_ebdbb_row12_col3" class="data row12 col3" >249.72</td>
#       <td id="T_ebdbb_row12_col4" class="data row12 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row13_col0" class="data row13 col0" >company</td>
#       <td id="T_ebdbb_row13_col1" class="data row13 col1" >Information Topics</td>
#       <td id="T_ebdbb_row13_col2" class="data row13 col2" >140</td>
#       <td id="T_ebdbb_row13_col3" class="data row13 col3" >228.50</td>
#       <td id="T_ebdbb_row13_col4" class="data row13 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row14_col0" class="data row14 col0" >output</td>
#       <td id="T_ebdbb_row14_col1" class="data row14 col1" >Information Topics</td>
#       <td id="T_ebdbb_row14_col2" class="data row14 col2" >138</td>
#       <td id="T_ebdbb_row14_col3" class="data row14 col3" >225.24</td>
#       <td id="T_ebdbb_row14_col4" class="data row14 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row15_col0" class="data row15 col0" >sample</td>
#       <td id="T_ebdbb_row15_col1" class="data row15 col1" >Information Topics</td>
#       <td id="T_ebdbb_row15_col2" class="data row15 col2" >136</td>
#       <td id="T_ebdbb_row15_col3" class="data row15 col3" >221.97</td>
#       <td id="T_ebdbb_row15_col4" class="data row15 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row16_col0" class="data row16 col0" >university</td>
#       <td id="T_ebdbb_row16_col1" class="data row16 col1" >Information Topics</td>
#       <td id="T_ebdbb_row16_col2" class="data row16 col2" >130</td>
#       <td id="T_ebdbb_row16_col3" class="data row16 col3" >212.18</td>
#       <td id="T_ebdbb_row16_col4" class="data row16 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row17_col0" class="data row17 col0" >color</td>
#       <td id="T_ebdbb_row17_col1" class="data row17 col1" >Information Topics</td>
#       <td id="T_ebdbb_row17_col2" class="data row17 col2" >126</td>
#       <td id="T_ebdbb_row17_col3" class="data row17 col3" >205.65</td>
#       <td id="T_ebdbb_row17_col4" class="data row17 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row18_col0" class="data row18 col0" >various</td>
#       <td id="T_ebdbb_row18_col1" class="data row18 col1" >Information Topics</td>
#       <td id="T_ebdbb_row18_col2" class="data row18 col2" >126</td>
#       <td id="T_ebdbb_row18_col3" class="data row18 col3" >205.65</td>
#       <td id="T_ebdbb_row18_col4" class="data row18 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ebdbb_row19_col0" class="data row19 col0" >space</td>
#       <td id="T_ebdbb_row19_col1" class="data row19 col1" >Information Topics</td>
#       <td id="T_ebdbb_row19_col2" class="data row19 col2" >123</td>
#       <td id="T_ebdbb_row19_col3" class="data row19 col3" >200.75</td>
#       <td id="T_ebdbb_row19

# %%
# By INFORMATION REPORT VERBS
freq_table_DS.query('Tag.str.startswith("Information Report Verbs")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b4d52">
#   <thead>
#     <tr>
#       <th id="T_b4d52_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_b4d52_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_b4d52_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_b4d52_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_b4d52_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b4d52_row0_col0" class="data row0 col0" >make</td>
#       <td id="T_b4d52_row0_col1" class="data row0 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row0_col2" class="data row0 col2" >228</td>
#       <td id="T_b4d52_row0_col3" class="data row0 col3" >372.13</td>
#       <td id="T_b4d52_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row1_col0" class="data row1 col0" >experience</td>
#       <td id="T_b4d52_row1_col1" class="data row1 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row1_col2" class="data row1 col2" >226</td>
#       <td id="T_b4d52_row1_col3" class="data row1 col3" >368.86</td>
#       <td id="T_b4d52_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row2_col0" class="data row2 col0" >made</td>
#       <td id="T_b4d52_row2_col1" class="data row2 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row2_col2" class="data row2 col2" >131</td>
#       <td id="T_b4d52_row2_col3" class="data row2 col3" >213.81</td>
#       <td id="T_b4d52_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row3_col0" class="data row3 col0" >build</td>
#       <td id="T_b4d52_row3_col1" class="data row3 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row3_col2" class="data row3 col2" >96</td>
#       <td id="T_b4d52_row3_col3" class="data row3 col3" >156.69</td>
#       <td id="T_b4d52_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row4_col0" class="data row4 col0" >create</td>
#       <td id="T_b4d52_row4_col1" class="data row4 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row4_col2" class="data row4 col2" >96</td>
#       <td id="T_b4d52_row4_col3" class="data row4 col3" >156.69</td>
#       <td id="T_b4d52_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row5_col0" class="data row5 col0" >generated</td>
#       <td id="T_b4d52_row5_col1" class="data row5 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row5_col2" class="data row5 col2" >90</td>
#       <td id="T_b4d52_row5_col3" class="data row5 col3" >146.89</td>
#       <td id="T_b4d52_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row6_col0" class="data row6 col0" >building</td>
#       <td id="T_b4d52_row6_col1" class="data row6 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row6_col2" class="data row6 col2" >89</td>
#       <td id="T_b4d52_row6_col3" class="data row6 col3" >145.26</td>
#       <td id="T_b4d52_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row7_col0" class="data row7 col0" >making</td>
#       <td id="T_b4d52_row7_col1" class="data row7 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row7_col2" class="data row7 col2" >85</td>
#       <td id="T_b4d52_row7_col3" class="data row7 col3" >138.73</td>
#       <td id="T_b4d52_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row8_col0" class="data row8 col0" >contains</td>
#       <td id="T_b4d52_row8_col1" class="data row8 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row8_col2" class="data row8 col2" >82</td>
#       <td id="T_b4d52_row8_col3" class="data row8 col3" >133.84</td>
#       <td id="T_b4d52_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row9_col0" class="data row9 col0" >created</td>
#       <td id="T_b4d52_row9_col1" class="data row9 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row9_col2" class="data row9 col2" >80</td>
#       <td id="T_b4d52_row9_col3" class="data row9 col3" >130.57</td>
#       <td id="T_b4d52_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row10_col0" class="data row10 col0" >include</td>
#       <td id="T_b4d52_row10_col1" class="data row10 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row10_col2" class="data row10 col2" >77</td>
#       <td id="T_b4d52_row10_col3" class="data row10 col3" >125.67</td>
#       <td id="T_b4d52_row10_col4" class="data row10 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row11_col0" class="data row11 col0" >observe</td>
#       <td id="T_b4d52_row11_col1" class="data row11 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row11_col2" class="data row11 col2" >77</td>
#       <td id="T_b4d52_row11_col3" class="data row11 col3" >125.67</td>
#       <td id="T_b4d52_row11_col4" class="data row11 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row12_col0" class="data row12 col0" >remove</td>
#       <td id="T_b4d52_row12_col1" class="data row12 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row12_col2" class="data row12 col2" >74</td>
#       <td id="T_b4d52_row12_col3" class="data row12 col3" >120.78</td>
#       <td id="T_b4d52_row12_col4" class="data row12 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row13_col0" class="data row13 col0" >makes</td>
#       <td id="T_b4d52_row13_col1" class="data row13 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row13_col2" class="data row13 col2" >67</td>
#       <td id="T_b4d52_row13_col3" class="data row13 col3" >109.35</td>
#       <td id="T_b4d52_row13_col4" class="data row13 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row14_col0" class="data row14 col0" >indicates</td>
#       <td id="T_b4d52_row14_col1" class="data row14 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row14_col2" class="data row14 col2" >64</td>
#       <td id="T_b4d52_row14_col3" class="data row14 col3" >104.46</td>
#       <td id="T_b4d52_row14_col4" class="data row14 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row15_col0" class="data row15 col0" >generate</td>
#       <td id="T_b4d52_row15_col1" class="data row15 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row15_col2" class="data row15 col2" >59</td>
#       <td id="T_b4d52_row15_col3" class="data row15 col3" >96.30</td>
#       <td id="T_b4d52_row15_col4" class="data row15 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row16_col0" class="data row16 col0" >depending on</td>
#       <td id="T_b4d52_row16_col1" class="data row16 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row16_col2" class="data row16 col2" >54</td>
#       <td id="T_b4d52_row16_col3" class="data row16 col3" >88.14</td>
#       <td id="T_b4d52_row16_col4" class="data row16 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row17_col0" class="data row17 col0" >built</td>
#       <td id="T_b4d52_row17_col1" class="data row17 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row17_col2" class="data row17 col2" >53</td>
#       <td id="T_b4d52_row17_col3" class="data row17 col3" >86.50</td>
#       <td id="T_b4d52_row17_col4" class="data row17 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row18_col0" class="data row18 col0" >observed</td>
#       <td id="T_b4d52_row18_col1" class="data row18 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row18_col2" class="data row18 col2" >48</td>
#       <td id="T_b4d52_row18_col3" class="data row18 col3" >78.34</td>
#       <td id="T_b4d52_row18_col4" class="data row18 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b4d52_row19_col0" class="data row19 col0" >sold</td>
#       <td id="T_b4d52_row19_col1" class="data row19 col1" >Information Report Verbs</td>
#       <td id="T_b4d52_row19_col2" class="data row19

# %%
# By INFORMATION CHANGE
freq_table_DS.query('Tag.str.startswith("Information Change")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fec70">
#   <thead>
#     <tr>
#       <th id="T_fec70_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_fec70_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_fec70_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_fec70_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_fec70_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fec70_row0_col0" class="data row0 col0" >variable</td>
#       <td id="T_fec70_row0_col1" class="data row0 col1" >Information Change</td>
#       <td id="T_fec70_row0_col2" class="data row0 col2" >350</td>
#       <td id="T_fec70_row0_col3" class="data row0 col3" >571.25</td>
#       <td id="T_fec70_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fec70_row1_col0" class="data row1 col0" >variables</td>
#       <td id="T_fec70_row1_col1" class="data row1 col1" >Information Change</td>
#       <td id="T_fec70_row1_col2" class="data row1 col2" >295</td>
#       <td id="T_fec70_row1_col3" class="data row1 col3" >481.48</td>
#       <td id="T_fec70_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fec70_row2_col0" class="data row2 col0" >scatter</td>
#       <td id="T_fec70_row2_col1" class="data row2 col1" >Information Change</td>
#       <td id="T_fec70_row2_col2" class="data row2 col2" >135</td>
#       <td id="T_fec70_row2_col3" class="data row2 col3" >220.34</td>
#       <td id="T_fec70_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fec70_row3_col0" class="data row3 col0" >increases</td>
#       <td id="T_fec70_row3_col1" class="data row3 col1" >Information Change</td>
#       <td id="T_fec70_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_fec70_row3_col3" class="data row3 col3" >163.21</td>
#       <td id="T_fec70_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fec70_row4_col0" class="data row4 col0" >create a</td>
#       <td id="T_fec70_row4_col1" class="data row4 col1" >Information Change</td>
#       <td id="T_fec70_row4_col2" class="data row4 col2" >81</td>
#       <td id="T_fec70_row4_col3" class="data row4 col3" >132.20</td>
#       <td id="T_fec70_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fec70_row5_col0" class="data row5 col0" >transformation</td>
#       <td id="T_fec70_row5_col1" class="data row5 col1" >Information Change</td>
#       <td id="T_fec70_row5_col2" class="data row5 col2" >77</td>
#       <td id="T_fec70_row5_col3" class="data row5 col3" >125.67</td>
#       <td id="T_fec70_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fec70_row6_col0" class="data row6 col0" >into a</td>
#       <td id="T_fec70_row6_col1" class="data row6 col1" >Information Change</td>
#       <td id="T_fec70_row6_col2" class="data row6 col2" >74</td>
#       <td id="T_fec70_row6_col3" class="data row6 col3" >120.78</td>
#       <td id="T_fec70_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fec70_row7_col0" class="data row7 col0" >change</td>
#       <td id="T_fec70_row7_col1" class="data row7 col1" >Information Change</td>
#       <td id="T_fec70_row7_col2" class="data row7 col2" >71</td>
#       <td id="T_fec70_row7_col3" class="data row7 col3" >115.88</td>
#       <td id="T_fec70_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fec70_row8_col0" class="data row8 col0" >growth</td>
#       <td id="T_fec70_row8_col1" class="data row8 col1" >Information Change</td>
#       <td id="T_fec70_row8_col2" class="data row8 col2" >68</td>
#       <td id="T_fec70_row8_col3" class="data row8 col3" >110.99</td>
#       <td id="T_fec70_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fec70_row9_col0" class="data row9 col0" >increase in</td>
#       <td id="T_fec70_row9_col1" class="data row9 col1" >Information Change Positive</td>
#       <td id="T_fec70_row9_col2" class="data row9 col2" >67</td>
#       <td id="T_fec70_row9_col3" class="data row9 col3" >109.35</td>
#       <td id="T_fec70_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# By REASONING
freq_table_DS.query('Tag.str.startswith("Reasoning")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_957e0">
#   <thead>
#     <tr>
#       <th id="T_957e0_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_957e0_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_957e0_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_957e0_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_957e0_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_957e0_row0_col0" class="data row0 col0" >models</td>
#       <td id="T_957e0_row0_col1" class="data row0 col1" >Reasoning</td>
#       <td id="T_957e0_row0_col2" class="data row0 col2" >490</td>
#       <td id="T_957e0_row0_col3" class="data row0 col3" >799.75</td>
#       <td id="T_957e0_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_957e0_row1_col0" class="data row1 col0" >analysis</td>
#       <td id="T_957e0_row1_col1" class="data row1 col1" >Reasoning</td>
#       <td id="T_957e0_row1_col2" class="data row1 col2" >265</td>
#       <td id="T_957e0_row1_col3" class="data row1 col3" >432.52</td>
#       <td id="T_957e0_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_957e0_row2_col0" class="data row2 col0" >because</td>
#       <td id="T_957e0_row2_col1" class="data row2 col1" >Reasoning</td>
#       <td id="T_957e0_row2_col2" class="data row2 col2" >243</td>
#       <td id="T_957e0_row2_col3" class="data row2 col3" >396.61</td>
#       <td id="T_957e0_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_957e0_row3_col0" class="data row3 col0" >, so</td>
#       <td id="T_957e0_row3_col1" class="data row3 col1" >Reasoning</td>
#       <td id="T_957e0_row3_col2" class="data row3 col2" >209</td>
#       <td id="T_957e0_row3_col3" class="data row3 col3" >341.12</td>
#       <td id="T_957e0_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_957e0_row4_col0" class="data row4 col0" >based on</td>
#       <td id="T_957e0_row4_col1" class="data row4 col1" >Reasoning</td>
#       <td id="T_957e0_row4_col2" class="data row4 col2" >182</td>
#       <td id="T_957e0_row4_col3" class="data row4 col3" >297.05</td>
#       <td id="T_957e0_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_957e0_row5_col0" class="data row5 col0" >results</td>
#       <td id="T_957e0_row5_col1" class="data row5 col1" >Reasoning</td>
#       <td id="T_957e0_row5_col2" class="data row5 col2" >182</td>
#       <td id="T_957e0_row5_col3" class="data row5 col3" >297.05</td>
#       <td id="T_957e0_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_957e0_row6_col0" class="data row6 col0" >categories</td>
#       <td id="T_957e0_row6_col1" class="data row6 col1" >Reasoning</td>
#       <td id="T_957e0_row6_col2" class="data row6 col2" >181</td>
#       <td id="T_957e0_row6_col3" class="data row6 col3" >295.42</td>
#       <td id="T_957e0_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_957e0_row7_col0" class="data row7 col0" >category</td>
#       <td id="T_957e0_row7_col1" class="data row7 col1" >Reasoning</td>
#       <td id="T_957e0_row7_col2" class="data row7 col2" >173</td>
#       <td id="T_957e0_row7_col3" class="data row7 col3" >282.36</td>
#       <td id="T_957e0_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_957e0_row8_col0" class="data row8 col0" >all the</td>
#       <td id="T_957e0_row8_col1" class="data row8 col1" >Reasoning</td>
#       <td id="T_957e0_row8_col2" class="data row8 col2" >167</td>
#       <td id="T_957e0_row8_col3" class="data row8 col3" >272.57</td>
#       <td id="T_957e0_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_957e0_row9_col0" class="data row9 col0" >survey</td>
#       <td id="T_957e0_row9_col1" class="data row9 col1" >Reasoning</td>
#       <td id="T_957e0_row9_col2" class="data row9 col2" >161</td>
#       <td id="T_957e0_row9_col3" class="data row9 col3" >262.77</td>
#       <td id="T_957e0_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# By UNCERTAINTY
freq_table_DS.query('Tag.str.startswith("Uncertainty")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5dc58">
#   <thead>
#     <tr>
#       <th id="T_5dc58_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_5dc58_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_5dc58_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_5dc58_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_5dc58_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5dc58_row0_col0" class="data row0 col0" >kind of</td>
#       <td id="T_5dc58_row0_col1" class="data row0 col1" >Uncertainty</td>
#       <td id="T_5dc58_row0_col2" class="data row0 col2" >66</td>
#       <td id="T_5dc58_row0_col3" class="data row0 col3" >107.72</td>
#       <td id="T_5dc58_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5dc58_row1_col0" class="data row1 col0" >whether</td>
#       <td id="T_5dc58_row1_col1" class="data row1 col1" >Uncertainty</td>
#       <td id="T_5dc58_row1_col2" class="data row1 col2" >34</td>
#       <td id="T_5dc58_row1_col3" class="data row1 col3" >55.49</td>
#       <td id="T_5dc58_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5dc58_row2_col0" class="data row2 col0" >whether the</td>
#       <td id="T_5dc58_row2_col1" class="data row2 col1" >Uncertainty</td>
#       <td id="T_5dc58_row2_col2" class="data row2 col2" >27</td>
#       <td id="T_5dc58_row2_col3" class="data row2 col3" >44.07</td>
#       <td id="T_5dc58_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5dc58_row3_col0" class="data row3 col0" >whether a</td>
#       <td id="T_5dc58_row3_col1" class="data row3 col1" >Uncertainty</td>
#       <td id="T_5dc58_row3_col2" class="data row3 col2" >11</td>
#       <td id="T_5dc58_row3_col3" class="data row3 col3" >17.95</td>
#       <td id="T_5dc58_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5dc58_row4_col0" class="data row4 col0" >anonymity</td>
#       <td id="T_5dc58_row4_col1" class="data row4 col1" >Uncertainty</td>
#       <td id="T_5dc58_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_5dc58_row4_col3" class="data row4 col3" >16.32</td>
#       <td id="T_5dc58_row4_col4" class="data row4 col4" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_5dc58_row5_col0" class="data row5 col0" >or maybe</td>
#       <td id="T_5dc58_row5_col1" class="data row5 col1" >Uncertainty</td>
#       <td id="T_5dc58_row5_col2" class="data row5 col2" >8</td>
#       <td id="T_5dc58_row5_col3" class="data row5 col3" >13.06</td>
#       <td id="T_5dc58_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5dc58_row6_col0" class="data row6 col0" >risk</td>
#       <td id="T_5dc58_row6_col1" class="data row6 col1" >Uncertainty</td>
#       <td id="T_5dc58_row6_col2" class="data row6 col2" >8</td>
#       <td id="T_5dc58_row6_col3" class="data row6 col3" >13.06</td>
#       <td id="T_5dc58_row6_col4" class="data row6 col4" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_5dc58_row7_col0" class="data row7 col0" >there might be</td>
#       <td id="T_5dc58_row7_col1" class="data row7 col1" >Uncertainty</td>
#       <td id="T_5dc58_row7_col2" class="data row7 col2" >8</td>
#       <td id="T_5dc58_row7_col3" class="data row7 col3" >13.06</td>
#       <td id="T_5dc58_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5dc58_row8_col0" class="data row8 col0" >whether or not</td>
#       <td id="T_5dc58_row8_col1" class="data row8 col1" >Uncertainty</td>
#       <td id="T_5dc58_row8_col2" class="data row8 col2" >8</td>
#       <td id="T_5dc58_row8_col3" class="data row8 col3" >13.06</td>
#       <td id="T_5dc58_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5dc58_row9_col0" class="data row9 col0" >or perhaps</td>
#       <td id="T_5dc58_row9_col1" class="data row9 col1" >Uncertainty</td>
#       <td id="T_5dc58_row9_col2" class="data row9 col2" >7</td>
#       <td id="T_5dc58_row9_col3" class="data row9 col3" >11.42</td>
#       <td id="T_5dc58_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.3 Tags Frequency Tables

# %% [markdown]
# We can focus on the tag counts by using the `tags_table` function. It works just like the `frequency_table` function, taking a dictionary created by the `convert_corpus` function, an integer against which to normalize, and a `count_by` argument of either `‘pos’` or `‘ds’`.

# %%
tags_freq_table_POS = tags_table(
    tok=tp,
    n_tokens=non_punct,
    count_by='pos'
)

# %%
tags_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6643a">
#   <thead>
#     <tr>
#       <th id="T_6643a_level0_col0" class="col_heading level0 col0" >Tag</th>
#       <th id="T_6643a_level0_col1" class="col_heading level0 col1" >AF</th>
#       <th id="T_6643a_level0_col2" class="col_heading level0 col2" >RF</th>
#       <th id="T_6643a_level0_col3" class="col_heading level0 col3" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6643a_row0_col0" class="data row0 col0" >NN1</td>
#       <td id="T_6643a_row0_col1" class="data row0 col1" >92371</td>
#       <td id="T_6643a_row0_col2" class="data row0 col2" >18.88</td>
#       <td id="T_6643a_row0_col3" class="data row0 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6643a_row1_col0" class="data row1 col0" >JJ</td>
#       <td id="T_6643a_row1_col1" class="data row1 col1" >34623</td>
#       <td id="T_6643a_row1_col2" class="data row1 col2" >7.08</td>
#       <td id="T_6643a_row1_col3" class="data row1 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6643a_row2_col0" class="data row2 col0" >NN2</td>
#       <td id="T_6643a_row2_col1" class="data row2 col1" >34074</td>
#       <td id="T_6643a_row2_col2" class="data row2 col2" >6.96</td>
#       <td id="T_6643a_row2_col3" class="data row2 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6643a_row3_col0" class="data row3 col0" >AT</td>
#       <td id="T_6643a_row3_col1" class="data row3 col1" >28776</td>
#       <td id="T_6643a_row3_col2" class="data row3 col2" >5.88</td>
#       <td id="T_6643a_row3_col3" class="data row3 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6643a_row4_col0" class="data row4 col0" >II</td>
#       <td id="T_6643a_row4_col1" class="data row4 col1" >27636</td>
#       <td id="T_6643a_row4_col2" class="data row4 col2" >5.65</td>
#       <td id="T_6643a_row4_col3" class="data row4 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6643a_row5_col0" class="data row5 col0" >VVI</td>
#       <td id="T_6643a_row5_col1" class="data row5 col1" >13628</td>
#       <td id="T_6643a_row5_col2" class="data row5 col2" >2.79</td>
#       <td id="T_6643a_row5_col3" class="data row5 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6643a_row6_col0" class="data row6 col0" >MC</td>
#       <td id="T_6643a_row6_col1" class="data row6 col1" >13301</td>
#       <td id="T_6643a_row6_col2" class="data row6 col2" >2.72</td>
#       <td id="T_6643a_row6_col3" class="data row6 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6643a_row7_col0" class="data row7 col0" >IO</td>
#       <td id="T_6643a_row7_col1" class="data row7 col1" >13001</td>
#       <td id="T_6643a_row7_col2" class="data row7 col2" >2.66</td>
#       <td id="T_6643a_row7_col3" class="data row7 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6643a_row8_col0" class="data row8 col0" >RR</td>
#       <td id="T_6643a_row8_col1" class="data row8 col1" >12443</td>
#       <td id="T_6643a_row8_col2" class="data row8 col2" >2.54</td>
#       <td id="T_6643a_row8_col3" class="data row8 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6643a_row9_col0" class="data row9 col0" >CC</td>
#       <td id="T_6643a_row9_col1" class="data row9 col1" >11690</td>
#       <td id="T_6643a_row9_col2" class="data row9 col2" >2.39</td>
#       <td id="T_6643a_row9_col3" class="data row9 col3" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# And by DocuScope category:

# %%
tags_freq_table_DS = tags_table(
    tok=tp,
    n_tokens=corpus_total,
    count_by='ds'
)

# %%
tags_freq_table_DS.sort_values('RF', ascending=False).head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b222b">
#   <thead>
#     <tr>
#       <th id="T_b222b_level0_col0" class="col_heading level0 col0" >Tag</th>
#       <th id="T_b222b_level0_col1" class="col_heading level0 col1" >AF</th>
#       <th id="T_b222b_level0_col2" class="col_heading level0 col2" >RF</th>
#       <th id="T_b222b_level0_col3" class="col_heading level0 col3" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b222b_row0_col0" class="data row0 col0" >Academic Terms</td>
#       <td id="T_b222b_row0_col1" class="data row0 col1" >38875</td>
#       <td id="T_b222b_row0_col2" class="data row0 col2" >6.34</td>
#       <td id="T_b222b_row0_col3" class="data row0 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b222b_row1_col0" class="data row1 col0" >Description</td>
#       <td id="T_b222b_row1_col1" class="data row1 col1" >29394</td>
#       <td id="T_b222b_row1_col2" class="data row1 col2" >4.80</td>
#       <td id="T_b222b_row1_col3" class="data row1 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b222b_row2_col0" class="data row2 col0" >Information Exposition</td>
#       <td id="T_b222b_row2_col1" class="data row2 col1" >27497</td>
#       <td id="T_b222b_row2_col2" class="data row2 col2" >4.49</td>
#       <td id="T_b222b_row2_col3" class="data row2 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b222b_row3_col0" class="data row3 col0" >Narrative</td>
#       <td id="T_b222b_row3_col1" class="data row3 col1" >19414</td>
#       <td id="T_b222b_row3_col2" class="data row3 col2" >3.17</td>
#       <td id="T_b222b_row3_col3" class="data row3 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b222b_row4_col0" class="data row4 col0" >Character</td>
#       <td id="T_b222b_row4_col1" class="data row4 col1" >16809</td>
#       <td id="T_b222b_row4_col2" class="data row4 col2" >2.74</td>
#       <td id="T_b222b_row4_col3" class="data row4 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b222b_row5_col0" class="data row5 col0" >Information Topics</td>
#       <td id="T_b222b_row5_col1" class="data row5 col1" >13093</td>
#       <td id="T_b222b_row5_col2" class="data row5 col2" >2.14</td>
#       <td id="T_b222b_row5_col3" class="data row5 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b222b_row6_col0" class="data row6 col0" >Force Stressed</td>
#       <td id="T_b222b_row6_col1" class="data row6 col1" >8568</td>
#       <td id="T_b222b_row6_col2" class="data row6 col2" >1.40</td>
#       <td id="T_b222b_row6_col3" class="data row6 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b222b_row7_col0" class="data row7 col0" >Negative</td>
#       <td id="T_b222b_row7_col1" class="data row7 col1" >8362</td>
#       <td id="T_b222b_row7_col2" class="data row7 col2" >1.36</td>
#       <td id="T_b222b_row7_col3" class="data row7 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b222b_row8_col0" class="data row8 col0" >Positive</td>
#       <td id="T_b222b_row8_col1" class="data row8 col1" >8080</td>
#       <td id="T_b222b_row8_col2" class="data row8 col2" >1.32</td>
#       <td id="T_b222b_row8_col3" class="data row8 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b222b_row9_col0" class="data row9 col0" >Metadiscourse Cohesive</td>
#       <td id="T_b222b_row9_col1" class="data row9 col1" >7463</td>
#       <td id="T_b222b_row9_col2" class="data row9 col2" >1.22</td>
#       <td id="T_b222b_row9_col3" class="data row9 col3" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.4 N-gram Frequency Tables

# %% [markdown]
# Ngrams (between bigrams and 5-grams) can be calculated using the `ngrams_table` function. It works much like the `frequency_table` function but with the addition of a span argument `ng_span` consisting of an integer between 2 and 5.
#
# This will return a table of 3-grams:

# %%
ngram_freq_table_POS = ngrams_table(
    tok=tp,
    ng_span=3,
    n_tokens=non_punct,
    count_by='pos'
)

# %% [markdown]
# The returned data frame includes both the sequence of tokens, as well as the sequence of tags:

# %%
ngram_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_87d2c">
#   <thead>
#     <tr>
#       <th id="T_87d2c_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_87d2c_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_87d2c_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_87d2c_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_87d2c_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_87d2c_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_87d2c_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_87d2c_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_87d2c_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_87d2c_row0_col0" class="data row0 col0" >we</td>
#       <td id="T_87d2c_row0_col1" class="data row0 col1" >can</td>
#       <td id="T_87d2c_row0_col2" class="data row0 col2" >see</td>
#       <td id="T_87d2c_row0_col3" class="data row0 col3" >PPIS2</td>
#       <td id="T_87d2c_row0_col4" class="data row0 col4" >VM</td>
#       <td id="T_87d2c_row0_col5" class="data row0 col5" >VVI</td>
#       <td id="T_87d2c_row0_col6" class="data row0 col6" >456</td>
#       <td id="T_87d2c_row0_col7" class="data row0 col7" >932.02</td>
#       <td id="T_87d2c_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_87d2c_row1_col0" class="data row1 col0" >the</td>
#       <td id="T_87d2c_row1_col1" class="data row1 col1" >number</td>
#       <td id="T_87d2c_row1_col2" class="data row1 col2" >of</td>
#       <td id="T_87d2c_row1_col3" class="data row1 col3" >AT</td>
#       <td id="T_87d2c_row1_col4" class="data row1 col4" >NN1</td>
#       <td id="T_87d2c_row1_col5" class="data row1 col5" >IO</td>
#       <td id="T_87d2c_row1_col6" class="data row1 col6" >416</td>
#       <td id="T_87d2c_row1_col7" class="data row1 col7" >850.26</td>
#       <td id="T_87d2c_row1_col8" class="data row1 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_87d2c_row2_col0" class="data row2 col0" >most</td>
#       <td id="T_87d2c_row2_col1" class="data row2 col1" >of</td>
#       <td id="T_87d2c_row2_col2" class="data row2 col2" >the</td>
#       <td id="T_87d2c_row2_col3" class="data row2 col3" >DAT</td>
#       <td id="T_87d2c_row2_col4" class="data row2 col4" >IO</td>
#       <td id="T_87d2c_row2_col5" class="data row2 col5" >AT</td>
#       <td id="T_87d2c_row2_col6" class="data row2 col6" >263</td>
#       <td id="T_87d2c_row2_col7" class="data row2 col7" >537.55</td>
#       <td id="T_87d2c_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_87d2c_row3_col0" class="data row3 col0" >of</td>
#       <td id="T_87d2c_row3_col1" class="data row3 col1" >the</td>
#       <td id="T_87d2c_row3_col2" class="data row3 col2" >following</td>
#       <td id="T_87d2c_row3_col3" class="data row3 col3" >IO</td>
#       <td id="T_87d2c_row3_col4" class="data row3 col4" >AT</td>
#       <td id="T_87d2c_row3_col5" class="data row3 col5" >JJ</td>
#       <td id="T_87d2c_row3_col6" class="data row3 col6" >263</td>
#       <td id="T_87d2c_row3_col7" class="data row3 col7" >537.55</td>
#       <td id="T_87d2c_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_87d2c_row4_col0" class="data row4 col0" >there</td>
#       <td id="T_87d2c_row4_col1" class="data row4 col1" >is</td>
#       <td id="T_87d2c_row4_col2" class="data row4 col2" >a</td>
#       <td id="T_87d2c_row4_col3" class="data row4 col3" >EX</td>
#       <td id="T_87d2c_row4_col4" class="data row4 col4" >VBZ</td>
#       <td id="T_87d2c_row4_col5" class="data row4 col5" >AT1</td>
#       <td id="T_87d2c_row4_col6" class="data row4 col6" >251</td>
#       <td id="T_87d2c_row4_col7" class="data row4 col7" >513.02</td>
#       <td id="T_87d2c_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_87d2c_row5_col0" class="data row5 col0" >the</td>
#       <td id="T_87d2c_row5_col1" class="data row5 col1" >distribution</td>
#       <td id="T_87d2c_row5_col2" class="data row5 col2" >of</td>
#       <td id="T_87d2c_row5_col3" class="data row5 col3" >AT</td>
#       <td id="T_87d2c_row5_col4" class="data row5 col4" >NN1</td>
#       <td id="T_87d2c_row5_col5" class="data row5 col5" >IO</td>
#       <td id="T_87d2c_row5_col6" class="data row5 col6" >235</td>
#       <td id="T_87d2c_row5_col7" class="data row5 col7" >480.32</td>
#       <td id="T_87d2c_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_87d2c_row6_col0" class="data row6 col0" >can</td>
#       <td id="T_87d2c_row6_col1" class="data row6 col1" >see</td>
#       <td id="T_87d2c_row6_col2" class="data row6 col2" >that</td>
#       <td id="T_87d2c_row6_col3" class="data row6 col3" >VM</td>
#       <td id="T_87d2c_row6_col4" class="data row6 col4" >VVI</td>
#       <td id="T_87d2c_row6_col5" class="data row6 col5" >CST</td>
#       <td id="T_87d2c_row6_col6" class="data row6 col6" >230</td>
#       <td id="T_87d2c_row6_col7" class="data row6 col7" >470.10</td>
#       <td id="T_87d2c_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_87d2c_row7_col0" class="data row7 col0" >any</td>
#       <td id="T_87d2c_row7_col1" class="data row7 col1" >of</td>
#       <td id="T_87d2c_row7_col2" class="data row7 col2" >the</td>
#       <td id="T_87d2c_row7_col3" class="data row7 col3" >DD</td>
#       <td id="T_87d2c_row7_col4" class="data row7 col4" >IO</td>
#       <td id="T_87d2c_row7_col5" class="data row7 col5" >AT</td>
#       <td id="T_87d2c_row7_col6" class="data row7 col6" >183</td>
#       <td id="T_87d2c_row7_col7" class="data row7 col7" >374.03</td>
#       <td id="T_87d2c_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_87d2c_row8_col0" class="data row8 col0" >a</td>
#       <td id="T_87d2c_row8_col1" class="data row8 col1" >lot</td>
#       <td id="T_87d2c_row8_col2" class="data row8 col2" >of</td>
#       <td id="T_87d2c_row8_col3" class="data row8 col3" >AT1</td>
#       <td id="T_87d2c_row8_col4" class="data row8 col4" >NN1</td>
#       <td id="T_87d2c_row8_col5" class="data row8 col5" >IO</td>
#       <td id="T_87d2c_row8_col6" class="data row8 col6" >168</td>
#       <td id="T_87d2c_row8_col7" class="data row8 col7" >343.38</td>
#       <td id="T_87d2c_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_87d2c_row9_col0" class="data row9 col0" >of</td>
#       <td id="T_87d2c_row9_col1" class="data row9 col1" >the</td>
#       <td id="T_87d2c_row9_col2" class="data row9 col2" >data</td>
#       <td id="T_87d2c_row9_col3" class="data row9 col3" >IO</td>
#       <td id="T_87d2c_row9_col4" class="data row9 col4" >AT</td>
#       <td id="T_87d2c_row9_col5" class="data row9 col5" >NN</td>
#       <td id="T_87d2c_row9_col6" class="data row9 col6" >164</td>
#       <td id="T_87d2c_row9_col7" class="data row9 col7" >335.20</td>
#       <td id="T_87d2c_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now we can filter ngrams that, for example, start with a verb:

# %%
ngram_freq_table_POS.query('Tag1.str.startswith("V")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_23e76">
#   <thead>
#     <tr>
#       <th id="T_23e76_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_23e76_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_23e76_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_23e76_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_23e76_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_23e76_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_23e76_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_23e76_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_23e76_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_23e76_row0_col0" class="data row0 col0" >can</td>
#       <td id="T_23e76_row0_col1" class="data row0 col1" >see</td>
#       <td id="T_23e76_row0_col2" class="data row0 col2" >that</td>
#       <td id="T_23e76_row0_col3" class="data row0 col3" >VM</td>
#       <td id="T_23e76_row0_col4" class="data row0 col4" >VVI</td>
#       <td id="T_23e76_row0_col5" class="data row0 col5" >CST</td>
#       <td id="T_23e76_row0_col6" class="data row0 col6" >230</td>
#       <td id="T_23e76_row0_col7" class="data row0 col7" >470.10</td>
#       <td id="T_23e76_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_23e76_row1_col0" class="data row1 col0" >use</td>
#       <td id="T_23e76_row1_col1" class="data row1 col1" >any</td>
#       <td id="T_23e76_row1_col2" class="data row1 col2" >of</td>
#       <td id="T_23e76_row1_col3" class="data row1 col3" >VV0</td>
#       <td id="T_23e76_row1_col4" class="data row1 col4" >DD</td>
#       <td id="T_23e76_row1_col5" class="data row1 col5" >IO</td>
#       <td id="T_23e76_row1_col6" class="data row1 col6" >116</td>
#       <td id="T_23e76_row1_col7" class="data row1 col7" >237.09</td>
#       <td id="T_23e76_row1_col8" class="data row1 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_23e76_row2_col0" class="data row2 col0" >look</td>
#       <td id="T_23e76_row2_col1" class="data row2 col1" >at</td>
#       <td id="T_23e76_row2_col2" class="data row2 col2" >the</td>
#       <td id="T_23e76_row2_col3" class="data row2 col3" >VVI</td>
#       <td id="T_23e76_row2_col4" class="data row2 col4" >II</td>
#       <td id="T_23e76_row2_col5" class="data row2 col5" >AT</td>
#       <td id="T_23e76_row2_col6" class="data row2 col6" >114</td>
#       <td id="T_23e76_row2_col7" class="data row2 col7" >233.00</td>
#       <td id="T_23e76_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_23e76_row3_col0" class="data row3 col0" >see</td>
#       <td id="T_23e76_row3_col1" class="data row3 col1" >that</td>
#       <td id="T_23e76_row3_col2" class="data row3 col2" >the</td>
#       <td id="T_23e76_row3_col3" class="data row3 col3" >VVI</td>
#       <td id="T_23e76_row3_col4" class="data row3 col4" >CST</td>
#       <td id="T_23e76_row3_col5" class="data row3 col5" >AT</td>
#       <td id="T_23e76_row3_col6" class="data row3 col6" >107</td>
#       <td id="T_23e76_row3_col7" class="data row3 col7" >218.70</td>
#       <td id="T_23e76_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_23e76_row4_col0" class="data row4 col0" >seems</td>
#       <td id="T_23e76_row4_col1" class="data row4 col1" >to</td>
#       <td id="T_23e76_row4_col2" class="data row4 col2" >be</td>
#       <td id="T_23e76_row4_col3" class="data row4 col3" >VVZ</td>
#       <td id="T_23e76_row4_col4" class="data row4 col4" >TO</td>
#       <td id="T_23e76_row4_col5" class="data row4 col5" >VBI</td>
#       <td id="T_23e76_row4_col6" class="data row4 col6" >97</td>
#       <td id="T_23e76_row4_col7" class="data row4 col7" >198.26</td>
#       <td id="T_23e76_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_23e76_row5_col0" class="data row5 col0" >based</td>
#       <td id="T_23e76_row5_col1" class="data row5 col1" >on</td>
#       <td id="T_23e76_row5_col2" class="data row5 col2" >the</td>
#       <td id="T_23e76_row5_col3" class="data row5 col3" >VVN</td>
#       <td id="T_23e76_row5_col4" class="data row5 col4" >II</td>
#       <td id="T_23e76_row5_col5" class="data row5 col5" >AT</td>
#       <td id="T_23e76_row5_col6" class="data row5 col6" >88</td>
#       <td id="T_23e76_row5_col7" class="data row5 col7" >179.86</td>
#       <td id="T_23e76_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_23e76_row6_col0" class="data row6 col0" >is</td>
#       <td id="T_23e76_row6_col1" class="data row6 col1" >the</td>
#       <td id="T_23e76_row6_col2" class="data row6 col2" >most</td>
#       <td id="T_23e76_row6_col3" class="data row6 col3" >VBZ</td>
#       <td id="T_23e76_row6_col4" class="data row6 col4" >AT</td>
#       <td id="T_23e76_row6_col5" class="data row6 col5" >RGT</td>
#       <td id="T_23e76_row6_col6" class="data row6 col6" >84</td>
#       <td id="T_23e76_row6_col7" class="data row6 col7" >171.69</td>
#       <td id="T_23e76_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_23e76_row7_col0" class="data row7 col0" >let 's</td>
#       <td id="T_23e76_row7_col1" class="data row7 col1" >look</td>
#       <td id="T_23e76_row7_col2" class="data row7 col2" >at</td>
#       <td id="T_23e76_row7_col3" class="data row7 col3" >VM</td>
#       <td id="T_23e76_row7_col4" class="data row7 col4" >VVI</td>
#       <td id="T_23e76_row7_col5" class="data row7 col5" >II</td>
#       <td id="T_23e76_row7_col6" class="data row7 col6" >84</td>
#       <td id="T_23e76_row7_col7" class="data row7 col7" >171.69</td>
#       <td id="T_23e76_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_23e76_row8_col0" class="data row8 col0" >are</td>
#       <td id="T_23e76_row8_col1" class="data row8 col1" >the</td>
#       <td id="T_23e76_row8_col2" class="data row8 col2" >most</td>
#       <td id="T_23e76_row8_col3" class="data row8 col3" >VBR</td>
#       <td id="T_23e76_row8_col4" class="data row8 col4" >AT</td>
#       <td id="T_23e76_row8_col5" class="data row8 col5" >RGT</td>
#       <td id="T_23e76_row8_col6" class="data row8 col6" >83</td>
#       <td id="T_23e76_row8_col7" class="data row8 col7" >169.64</td>
#       <td id="T_23e76_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_23e76_row9_col0" class="data row9 col0" >looking</td>
#       <td id="T_23e76_row9_col1" class="data row9 col1" >at</td>
#       <td id="T_23e76_row9_col2" class="data row9 col2" >the</td>
#       <td id="T_23e76_row9_col3" class="data row9 col3" >VVG</td>
#       <td id="T_23e76_row9_col4" class="data row9 col4" >II</td>
#       <td id="T_23e76_row9_col5" class="data row9 col5" >AT</td>
#       <td id="T_23e76_row9_col6" class="data row9 col6" >83</td>
#       <td id="T_23e76_row9_col7" class="data row9 col7" >169.64</td>
#       <td id="T_23e76_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_23e76_row10_col0" class="data row10 col0" >can</td>
#       <td id="T_23e76_row10_col1" class="data row10 col1" >be</td>
#       <td id="T_23e76_row10_col2" class="data row10 col2" >seen</td>
#       <td id="T_23e76_row10_col3" class="data row10 col3" >VM</td>
#       <td id="T_23e76_row10_col4" class="data row10 col4" >VBI</td>
#       <td id="T_23e76_row10_col5" class="data row10 col5" >VVN</td>
#       <td id="T_23e76_row10_col6" class="data row10 col6" >82</td>
#       <td id="T_23e76_row10_col7" class="data row10 col7" >167.60</td>
#       <td id="T_23e76_row10_col8" class="data row10 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_23e76_row11_col0" class="data row11 col0" >can</td>
#       <td id="T_23e76_row11_col1" class="data row11 col1" >see</td>
#       <td id="T_23e76_row11_col2" class="data row11 col2" >the</td>
#       <td id="T_23e76_row11_col3" class="data row11 col3" >VM</td>
#       <td id="T_23e76_row11_col4" class="data row11 col4" >VVI</td>
#       <td id="T_23e76_row11_col

# %% [markdown]
# Or sequences that end with a *past participle* (‘VVN’) preceded by a *to be verb* (‘VB’), thus showing passive constructions:

# %%
ngram_freq_table_POS.query('Tag3.str.startswith("VVN") and Tag2.str.startswith("VB")').head(15).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c24a9">
#   <thead>
#     <tr>
#       <th id="T_c24a9_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_c24a9_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_c24a9_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_c24a9_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_c24a9_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_c24a9_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_c24a9_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_c24a9_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_c24a9_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c24a9_row0_col0" class="data row0 col0" >can</td>
#       <td id="T_c24a9_row0_col1" class="data row0 col1" >be</td>
#       <td id="T_c24a9_row0_col2" class="data row0 col2" >seen</td>
#       <td id="T_c24a9_row0_col3" class="data row0 col3" >VM</td>
#       <td id="T_c24a9_row0_col4" class="data row0 col4" >VBI</td>
#       <td id="T_c24a9_row0_col5" class="data row0 col5" >VVN</td>
#       <td id="T_c24a9_row0_col6" class="data row0 col6" >82</td>
#       <td id="T_c24a9_row0_col7" class="data row0 col7" >167.60</td>
#       <td id="T_c24a9_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c24a9_row1_col0" class="data row1 col0" >can</td>
#       <td id="T_c24a9_row1_col1" class="data row1 col1" >be</td>
#       <td id="T_c24a9_row1_col2" class="data row1 col2" >used</td>
#       <td id="T_c24a9_row1_col3" class="data row1 col3" >VM</td>
#       <td id="T_c24a9_row1_col4" class="data row1 col4" >VBI</td>
#       <td id="T_c24a9_row1_col5" class="data row1 col5" >VVN</td>
#       <td id="T_c24a9_row1_col6" class="data row1 col6" >69</td>
#       <td id="T_c24a9_row1_col7" class="data row1 col7" >141.03</td>
#       <td id="T_c24a9_row1_col8" class="data row1 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c24a9_row2_col0" class="data row2 col0" >will</td>
#       <td id="T_c24a9_row2_col1" class="data row2 col1" >be</td>
#       <td id="T_c24a9_row2_col2" class="data row2 col2" >used</td>
#       <td id="T_c24a9_row2_col3" class="data row2 col3" >VM</td>
#       <td id="T_c24a9_row2_col4" class="data row2 col4" >VBI</td>
#       <td id="T_c24a9_row2_col5" class="data row2 col5" >VVN</td>
#       <td id="T_c24a9_row2_col6" class="data row2 col6" >37</td>
#       <td id="T_c24a9_row2_col7" class="data row2 col7" >75.62</td>
#       <td id="T_c24a9_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c24a9_row3_col0" class="data row3 col0" >can</td>
#       <td id="T_c24a9_row3_col1" class="data row3 col1" >be</td>
#       <td id="T_c24a9_row3_col2" class="data row3 col2" >found</td>
#       <td id="T_c24a9_row3_col3" class="data row3 col3" >VM</td>
#       <td id="T_c24a9_row3_col4" class="data row3 col4" >VBI</td>
#       <td id="T_c24a9_row3_col5" class="data row3 col5" >VVN</td>
#       <td id="T_c24a9_row3_col6" class="data row3 col6" >27</td>
#       <td id="T_c24a9_row3_col7" class="data row3 col7" >55.19</td>
#       <td id="T_c24a9_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c24a9_row4_col0" class="data row4 col0" >ratings</td>
#       <td id="T_c24a9_row4_col1" class="data row4 col1" >are</td>
#       <td id="T_c24a9_row4_col2" class="data row4 col2" >spread</td>
#       <td id="T_c24a9_row4_col3" class="data row4 col3" >NN2</td>
#       <td id="T_c24a9_row4_col4" class="data row4 col4" >VBR</td>
#       <td id="T_c24a9_row4_col5" class="data row4 col5" >VVN</td>
#       <td id="T_c24a9_row4_col6" class="data row4 col6" >24</td>
#       <td id="T_c24a9_row4_col7" class="data row4 col7" >49.05</td>
#       <td id="T_c24a9_row4_col8" class="data row4 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_c24a9_row5_col0" class="data row5 col0" >can</td>
#       <td id="T_c24a9_row5_col1" class="data row5 col1" >be</td>
#       <td id="T_c24a9_row5_col2" class="data row5 col2" >observed</td>
#       <td id="T_c24a9_row5_col3" class="data row5 col3" >VM</td>
#       <td id="T_c24a9_row5_col4" class="data row5 col4" >VBI</td>
#       <td id="T_c24a9_row5_col5" class="data row5 col5" >VVN</td>
#       <td id="T_c24a9_row5_col6" class="data row5 col6" >22</td>
#       <td id="T_c24a9_row5_col7" class="data row5 col7" >44.97</td>
#       <td id="T_c24a9_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c24a9_row6_col0" class="data row6 col0" >can</td>
#       <td id="T_c24a9_row6_col1" class="data row6 col1" >be</td>
#       <td id="T_c24a9_row6_col2" class="data row6 col2" >considered</td>
#       <td id="T_c24a9_row6_col3" class="data row6 col3" >VM</td>
#       <td id="T_c24a9_row6_col4" class="data row6 col4" >VBI</td>
#       <td id="T_c24a9_row6_col5" class="data row6 col5" >VVN</td>
#       <td id="T_c24a9_row6_col6" class="data row6 col6" >13</td>
#       <td id="T_c24a9_row6_col7" class="data row6 col7" >26.57</td>
#       <td id="T_c24a9_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c24a9_row7_col0" class="data row7 col0" >loan</td>
#       <td id="T_c24a9_row7_col1" class="data row7 col1" >is</td>
#       <td id="T_c24a9_row7_col2" class="data row7 col2" >repayed</td>
#       <td id="T_c24a9_row7_col3" class="data row7 col3" >NN1</td>
#       <td id="T_c24a9_row7_col4" class="data row7 col4" >VBZ</td>
#       <td id="T_c24a9_row7_col5" class="data row7 col5" >VVN</td>
#       <td id="T_c24a9_row7_col6" class="data row7 col6" >13</td>
#       <td id="T_c24a9_row7_col7" class="data row7 col7" >26.57</td>
#       <td id="T_c24a9_row7_col8" class="data row7 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_c24a9_row8_col0" class="data row8 col0" >can</td>
#       <td id="T_c24a9_row8_col1" class="data row8 col1" >be</td>
#       <td id="T_c24a9_row8_col2" class="data row8 col2" >discarded</td>
#       <td id="T_c24a9_row8_col3" class="data row8 col3" >VM</td>
#       <td id="T_c24a9_row8_col4" class="data row8 col4" >VBI</td>
#       <td id="T_c24a9_row8_col5" class="data row8 col5" >VVN</td>
#       <td id="T_c24a9_row8_col6" class="data row8 col6" >12</td>
#       <td id="T_c24a9_row8_col7" class="data row8 col7" >24.53</td>
#       <td id="T_c24a9_row8_col8" class="data row8 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_c24a9_row9_col0" class="data row9 col0" >distribution</td>
#       <td id="T_c24a9_row9_col1" class="data row9 col1" >are</td>
#       <td id="T_c24a9_row9_col2" class="data row9 col2" >left</td>
#       <td id="T_c24a9_row9_col3" class="data row9 col3" >NN1</td>
#       <td id="T_c24a9_row9_col4" class="data row9 col4" >VBR</td>
#       <td id="T_c24a9_row9_col5" class="data row9 col5" >VVN</td>
#       <td id="T_c24a9_row9_col6" class="data row9 col6" >12</td>
#       <td id="T_c24a9_row9_col7" class="data row9 col7" >24.53</td>
#       <td id="T_c24a9_row9_col8" class="data row9 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_c24a9_row10_col0" class="data row10 col0" >it</td>
#       <td id="T_c24a9_row10_col1" class="data row10 col1" >is</td>
#       <td id="T_c24a9_row10_col2" class="data row10 col2" >called</td>
#       <td id="T_c24a9_row10_col3" class="data row10 col3" >PPH1</td>
#       <td id="T_c24a9_row10_col4" class="data row10 col4" >VBZ</td>
#       <td id="T_c24a9_row10_col5" class="data row10 col5" >VVN</td>
#       <td id="T_c24a9_row10_col6" class="data row10 col6" >12</td>
#       <td id="T_c24a9_row10_col7" class="data row10 col7" >24.53</td>
#       <td id="T_c24a9_row10_col8" class="data row10 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c24a9_row11_col0" class="data row11 col0" >can</td>
#       <td id="T_c24a9_row11_col1" class="data row11 col1" >be</td>
#       <td id="T_c24a9_row11_col2" class="data row11 col2" >made</td>
#       <td id="T_c24a9_row11_col3" class="data row11 col3" >VM</td>
#       <td id="T_c24a9_row11_col4" class="data row11 col4" >VBI</td>
#       <

# %% [markdown]
# Similar ngram tables can be created for DocuScope sequences. Here we generate trigrams again:

# %%
ngram_freq_table_DS = ngrams_table(
    tok=tp,
    ng_span=3,
    n_tokens=corpus_total,
    count_by='ds'
)

# %%
ngram_freq_table_DS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b06c5">
#   <thead>
#     <tr>
#       <th id="T_b06c5_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_b06c5_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_b06c5_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_b06c5_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_b06c5_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_b06c5_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_b06c5_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_b06c5_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_b06c5_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b06c5_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_b06c5_row0_col1" class="data row0 col1" >number</td>
#       <td id="T_b06c5_row0_col2" class="data row0 col2" >of</td>
#       <td id="T_b06c5_row0_col3" class="data row0 col3" >Untagged</td>
#       <td id="T_b06c5_row0_col4" class="data row0 col4" >Untagged</td>
#       <td id="T_b06c5_row0_col5" class="data row0 col5" >Untagged</td>
#       <td id="T_b06c5_row0_col6" class="data row0 col6" >234</td>
#       <td id="T_b06c5_row0_col7" class="data row0 col7" >381.92</td>
#       <td id="T_b06c5_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b06c5_row1_col0" class="data row1 col0" >%</td>
#       <td id="T_b06c5_row1_col1" class="data row1 col1" >of</td>
#       <td id="T_b06c5_row1_col2" class="data row1 col2" >the</td>
#       <td id="T_b06c5_row1_col3" class="data row1 col3" >InformationExposition</td>
#       <td id="T_b06c5_row1_col4" class="data row1 col4" >Untagged</td>
#       <td id="T_b06c5_row1_col5" class="data row1 col5" >Untagged</td>
#       <td id="T_b06c5_row1_col6" class="data row1 col6" >191</td>
#       <td id="T_b06c5_row1_col7" class="data row1 col7" >311.74</td>
#       <td id="T_b06c5_row1_col8" class="data row1 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b06c5_row2_col0" class="data row2 col0" >the</td>
#       <td id="T_b06c5_row2_col1" class="data row2 col1" >distribution</td>
#       <td id="T_b06c5_row2_col2" class="data row2 col2" >of</td>
#       <td id="T_b06c5_row2_col3" class="data row2 col3" >Untagged</td>
#       <td id="T_b06c5_row2_col4" class="data row2 col4" >AcademicTerms</td>
#       <td id="T_b06c5_row2_col5" class="data row2 col5" >Untagged</td>
#       <td id="T_b06c5_row2_col6" class="data row2 col6" >131</td>
#       <td id="T_b06c5_row2_col7" class="data row2 col7" >213.81</td>
#       <td id="T_b06c5_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b06c5_row3_col0" class="data row3 col0" >there</td>
#       <td id="T_b06c5_row3_col1" class="data row3 col1" >is</td>
#       <td id="T_b06c5_row3_col2" class="data row3 col2" >a</td>
#       <td id="T_b06c5_row3_col3" class="data row3 col3" >Untagged</td>
#       <td id="T_b06c5_row3_col4" class="data row3 col4" >Untagged</td>
#       <td id="T_b06c5_row3_col5" class="data row3 col5" >Untagged</td>
#       <td id="T_b06c5_row3_col6" class="data row3 col6" >123</td>
#       <td id="T_b06c5_row3_col7" class="data row3 col7" >200.75</td>
#       <td id="T_b06c5_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b06c5_row4_col0" class="data row4 col0" >some</td>
#       <td id="T_b06c5_row4_col1" class="data row4 col1" >of</td>
#       <td id="T_b06c5_row4_col2" class="data row4 col2" >the</td>
#       <td id="T_b06c5_row4_col3" class="data row4 col3" >Untagged</td>
#       <td id="T_b06c5_row4_col4" class="data row4 col4" >Untagged</td>
#       <td id="T_b06c5_row4_col5" class="data row4 col5" >Untagged</td>
#       <td id="T_b06c5_row4_col6" class="data row4 col6" >109</td>
#       <td id="T_b06c5_row4_col7" class="data row4 col7" >177.90</td>
#       <td id="T_b06c5_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b06c5_row5_col0" class="data row5 col0" >use</td>
#       <td id="T_b06c5_row5_col1" class="data row5 col1" >on</td>
#       <td id="T_b06c5_row5_col2" class="data row5 col2" >a</td>
#       <td id="T_b06c5_row5_col3" class="data row5 col3" >Untagged</td>
#       <td id="T_b06c5_row5_col4" class="data row5 col4" >Untagged</td>
#       <td id="T_b06c5_row5_col5" class="data row5 col5" >Untagged</td>
#       <td id="T_b06c5_row5_col6" class="data row5 col6" >108</td>
#       <td id="T_b06c5_row5_col7" class="data row5 col7" >176.27</td>
#       <td id="T_b06c5_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b06c5_row6_col0" class="data row6 col0" >of</td>
#       <td id="T_b06c5_row6_col1" class="data row6 col1" >the</td>
#       <td id="T_b06c5_row6_col2" class="data row6 col2" >following</td>
#       <td id="T_b06c5_row6_col3" class="data row6 col3" >Untagged</td>
#       <td id="T_b06c5_row6_col4" class="data row6 col4" >Untagged</td>
#       <td id="T_b06c5_row6_col5" class="data row6 col5" >Narrative</td>
#       <td id="T_b06c5_row6_col6" class="data row6 col6" >107</td>
#       <td id="T_b06c5_row6_col7" class="data row6 col7" >174.64</td>
#       <td id="T_b06c5_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b06c5_row7_col0" class="data row7 col0" >in</td>
#       <td id="T_b06c5_row7_col1" class="data row7 col1" >terms</td>
#       <td id="T_b06c5_row7_col2" class="data row7 col2" >of</td>
#       <td id="T_b06c5_row7_col3" class="data row7 col3" >Untagged</td>
#       <td id="T_b06c5_row7_col4" class="data row7 col4" >Untagged</td>
#       <td id="T_b06c5_row7_col5" class="data row7 col5" >Untagged</td>
#       <td id="T_b06c5_row7_col6" class="data row7 col6" >105</td>
#       <td id="T_b06c5_row7_col7" class="data row7 col7" >171.37</td>
#       <td id="T_b06c5_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b06c5_row8_col0" class="data row8 col0" >which</td>
#       <td id="T_b06c5_row8_col1" class="data row8 col1" >of</td>
#       <td id="T_b06c5_row8_col2" class="data row8 col2" >the</td>
#       <td id="T_b06c5_row8_col3" class="data row8 col3" >Untagged</td>
#       <td id="T_b06c5_row8_col4" class="data row8 col4" >Untagged</td>
#       <td id="T_b06c5_row8_col5" class="data row8 col5" >Untagged</td>
#       <td id="T_b06c5_row8_col6" class="data row8 col6" >105</td>
#       <td id="T_b06c5_row8_col7" class="data row8 col7" >171.37</td>
#       <td id="T_b06c5_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_b06c5_row9_col0" class="data row9 col0" >on</td>
#       <td id="T_b06c5_row9_col1" class="data row9 col1" >a</td>
#       <td id="T_b06c5_row9_col2" class="data row9 col2" >regular basis</td>
#       <td id="T_b06c5_row9_col3" class="data row9 col3" >Untagged</td>
#       <td id="T_b06c5_row9_col4" class="data row9 col4" >Untagged</td>
#       <td id="T_b06c5_row9_col5" class="data row9 col5" >InformationTopics</td>
#       <td id="T_b06c5_row9_col6" class="data row9 col6" >101</td>
#       <td id="T_b06c5_row9_col7" class="data row9 col7" >164.85</td>
#       <td id="T_b06c5_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's find a sequence tagged as ‘Positive’ on the right and on the left we filter out Untagged (‘O’) and ‘Syntactic Complexity’:

# %%
ngram_freq_table_DS.query('Tag1.str.startswith("Positive") and (~Tag2.str.startswith("Syntactic") and ~Tag2.str.startswith("Untagged") and ~Tag3.str.startswith("Untagged"))').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_21317">
#   <thead>
#     <tr>
#       <th id="T_21317_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_21317_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_21317_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_21317_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_21317_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_21317_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_21317_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_21317_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_21317_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_21317_row0_col0" class="data row0 col0" >favorite</td>
#       <td id="T_21317_row0_col1" class="data row0 col1" >media</td>
#       <td id="T_21317_row0_col2" class="data row0 col2" >sources</td>
#       <td id="T_21317_row0_col3" class="data row0 col3" >Positive</td>
#       <td id="T_21317_row0_col4" class="data row0 col4" >PublicTerms</td>
#       <td id="T_21317_row0_col5" class="data row0 col5" >AcademicTerms</td>
#       <td id="T_21317_row0_col6" class="data row0 col6" >18</td>
#       <td id="T_21317_row0_col7" class="data row0 col7" >29.38</td>
#       <td id="T_21317_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_21317_row1_col0" class="data row1 col0" >best</td>
#       <td id="T_21317_row1_col1" class="data row1 col1" >developer</td>
#       <td id="T_21317_row1_col2" class="data row1 col2" >experience</td>
#       <td id="T_21317_row1_col3" class="data row1 col3" >Positive</td>
#       <td id="T_21317_row1_col4" class="data row1 col4" >Character</td>
#       <td id="T_21317_row1_col5" class="data row1 col5" >InformationReportVerbs</td>
#       <td id="T_21317_row1_col6" class="data row1 col6" >17</td>
#       <td id="T_21317_row1_col7" class="data row1 col7" >27.75</td>
#       <td id="T_21317_row1_col8" class="data row1 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_21317_row2_col0" class="data row2 col0" >ethical</td>
#       <td id="T_21317_row2_col1" class="data row2 col1" >ai products</td>
#       <td id="T_21317_row2_col2" class="data row2 col2" >in your</td>
#       <td id="T_21317_row2_col3" class="data row2 col3" >Positive</td>
#       <td id="T_21317_row2_col4" class="data row2 col4" >InformationTopics</td>
#       <td id="T_21317_row2_col5" class="data row2 col5" >Interactive</td>
#       <td id="T_21317_row2_col6" class="data row2 col6" >16</td>
#       <td id="T_21317_row2_col7" class="data row2 col7" >26.11</td>
#       <td id="T_21317_row2_col8" class="data row2 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_21317_row3_col0" class="data row3 col0" >precision</td>
#       <td id="T_21317_row3_col1" class="data row3 col1" >recall</td>
#       <td id="T_21317_row3_col2" class="data row3 col2" >curve</td>
#       <td id="T_21317_row3_col3" class="data row3 col3" >Positive</td>
#       <td id="T_21317_row3_col4" class="data row3 col4" >Character</td>
#       <td id="T_21317_row3_col5" class="data row3 col5" >Description</td>
#       <td id="T_21317_row3_col6" class="data row3 col6" >13</td>
#       <td id="T_21317_row3_col7" class="data row3 col7" >21.22</td>
#       <td id="T_21317_row3_col8" class="data row3 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_21317_row4_col0" class="data row4 col0" >our</td>
#       <td id="T_21317_row4_col1" class="data row4 col1" >classifying</td>
#       <td id="T_21317_row4_col2" class="data row4 col2" >assumption</td>
#       <td id="T_21317_row4_col3" class="data row4 col3" >Positive</td>
#       <td id="T_21317_row4_col4" class="data row4 col4" >Description</td>
#       <td id="T_21317_row4_col5" class="data row4 col5" >Character</td>
#       <td id="T_21317_row4_col6" class="data row4 col6" >12</td>
#       <td id="T_21317_row4_col7" class="data row4 col7" >19.59</td>
#       <td id="T_21317_row4_col8" class="data row4 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_21317_row5_col0" class="data row5 col0" >support</td>
#       <td id="T_21317_row5_col1" class="data row5 col1" >vector</td>
#       <td id="T_21317_row5_col2" class="data row5 col2" >machines</td>
#       <td id="T_21317_row5_col3" class="data row5 col3" >Positive</td>
#       <td id="T_21317_row5_col4" class="data row5 col4" >AcademicTerms</td>
#       <td id="T_21317_row5_col5" class="data row5 col5" >Description</td>
#       <td id="T_21317_row5_col6" class="data row5 col6" >12</td>
#       <td id="T_21317_row5_col7" class="data row5 col7" >19.59</td>
#       <td id="T_21317_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_21317_row6_col0" class="data row6 col0" >our</td>
#       <td id="T_21317_row6_col1" class="data row6 col1" >machine</td>
#       <td id="T_21317_row6_col2" class="data row6 col2" >learning</td>
#       <td id="T_21317_row6_col3" class="data row6 col3" >Positive</td>
#       <td id="T_21317_row6_col4" class="data row6 col4" >AcademicTerms</td>
#       <td id="T_21317_row6_col5" class="data row6 col5" >Inquiry</td>
#       <td id="T_21317_row6_col6" class="data row6 col6" >11</td>
#       <td id="T_21317_row6_col7" class="data row6 col7" >17.95</td>
#       <td id="T_21317_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_21317_row7_col0" class="data row7 col0" >our</td>
#       <td id="T_21317_row7_col1" class="data row7 col1" >model</td>
#       <td id="T_21317_row7_col2" class="data row7 col2" >is</td>
#       <td id="T_21317_row7_col3" class="data row7 col3" >Positive</td>
#       <td id="T_21317_row7_col4" class="data row7 col4" >AcademicTerms</td>
#       <td id="T_21317_row7_col5" class="data row7 col5" >InformationStates</td>
#       <td id="T_21317_row7_col6" class="data row7 col6" >11</td>
#       <td id="T_21317_row7_col7" class="data row7 col7" >17.95</td>
#       <td id="T_21317_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_21317_row8_col0" class="data row8 col0" >accuracy</td>
#       <td id="T_21317_row8_col1" class="data row8 col1" >precision</td>
#       <td id="T_21317_row8_col2" class="data row8 col2" >recall</td>
#       <td id="T_21317_row8_col3" class="data row8 col3" >Positive</td>
#       <td id="T_21317_row8_col4" class="data row8 col4" >Positive</td>
#       <td id="T_21317_row8_col5" class="data row8 col5" >Character</td>
#       <td id="T_21317_row8_col6" class="data row8 col6" >8</td>
#       <td id="T_21317_row8_col7" class="data row8 col7" >13.06</td>
#       <td id="T_21317_row8_col8" class="data row8 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_21317_row9_col0" class="data row9 col0" >confirms</td>
#       <td id="T_21317_row9_col1" class="data row9 col1" >our</td>
#       <td id="T_21317_row9_col2" class="data row9 col2" >assumption</td>
#       <td id="T_21317_row9_col3" class="data row9 col3" >Positive</td>
#       <td id="T_21317_row9_col4" class="data row9 col4" >Positive</td>
#       <td id="T_21317_row9_col5" class="data row9 col5" >Character</td>
#       <td id="T_21317_row9_col6" class="data row9 col6" >8</td>
#       <td id="T_21317_row9_col7" class="data row9 col7" >13.06</td>
#       <td id="T_21317_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
ngram_freq_table_DS.query('Tag1.str.startswith("Negative") and (~Tag2.str.startswith("Syntactic") and ~Tag2.str.startswith("Untagged") and ~Tag3.str.startswith("Untagged"))').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1e161">
#   <thead>
#     <tr>
#       <th id="T_1e161_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_1e161_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_1e161_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_1e161_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_1e161_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_1e161_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_1e161_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_1e161_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_1e161_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1e161_row0_col0" class="data row0 col0" >against the</td>
#       <td id="T_1e161_row0_col1" class="data row0 col1" >false</td>
#       <td id="T_1e161_row0_col2" class="data row0 col2" >positive rate</td>
#       <td id="T_1e161_row0_col3" class="data row0 col3" >Negative</td>
#       <td id="T_1e161_row0_col4" class="data row0 col4" >Negative</td>
#       <td id="T_1e161_row0_col5" class="data row0 col5" >InformationTopics</td>
#       <td id="T_1e161_row0_col6" class="data row0 col6" >8</td>
#       <td id="T_1e161_row0_col7" class="data row0 col7" >13.06</td>
#       <td id="T_1e161_row0_col8" class="data row0 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_1e161_row1_col0" class="data row1 col0" >partial</td>
#       <td id="T_1e161_row1_col1" class="data row1 col1" >autocorrelation</td>
#       <td id="T_1e161_row1_col2" class="data row1 col2" >function</td>
#       <td id="T_1e161_row1_col3" class="data row1 col3" >Negative</td>
#       <td id="T_1e161_row1_col4" class="data row1 col4" >AcademicTerms</td>
#       <td id="T_1e161_row1_col5" class="data row1 col5" >AcademicTerms</td>
#       <td id="T_1e161_row1_col6" class="data row1 col6" >8</td>
#       <td id="T_1e161_row1_col7" class="data row1 col7" >13.06</td>
#       <td id="T_1e161_row1_col8" class="data row1 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_1e161_row2_col0" class="data row2 col0" >false</td>
#       <td id="T_1e161_row2_col1" class="data row2 col1" >positive rate</td>
#       <td id="T_1e161_row2_col2" class="data row2 col2" >fpr</td>
#       <td id="T_1e161_row2_col3" class="data row2 col3" >Negative</td>
#       <td id="T_1e161_row2_col4" class="data row2 col4" >InformationTopics</td>
#       <td id="T_1e161_row2_col5" class="data row2 col5" >Description</td>
#       <td id="T_1e161_row2_col6" class="data row2 col6" >7</td>
#       <td id="T_1e161_row2_col7" class="data row2 col7" >11.42</td>
#       <td id="T_1e161_row2_col8" class="data row2 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_1e161_row3_col0" class="data row3 col0" >onlinebackup</td>
#       <td id="T_1e161_row3_col1" class="data row3 col1" >deviceprotection</td>
#       <td id="T_1e161_row3_col2" class="data row3 col2" >techsupport</td>
#       <td id="T_1e161_row3_col3" class="data row3 col3" >Negative</td>
#       <td id="T_1e161_row3_col4" class="data row3 col4" >Description</td>
#       <td id="T_1e161_row3_col5" class="data row3 col5" >Description</td>
#       <td id="T_1e161_row3_col6" class="data row3 col6" >7</td>
#       <td id="T_1e161_row3_col7" class="data row3 col7" >11.42</td>
#       <td id="T_1e161_row3_col8" class="data row3 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_1e161_row4_col0" class="data row4 col0" >onlinesecurity</td>
#       <td id="T_1e161_row4_col1" class="data row4 col1" >onlinebackup</td>
#       <td id="T_1e161_row4_col2" class="data row4 col2" >deviceprotection</td>
#       <td id="T_1e161_row4_col3" class="data row4 col3" >Negative</td>
#       <td id="T_1e161_row4_col4" class="data row4 col4" >Negative</td>
#       <td id="T_1e161_row4_col5" class="data row4 col5" >Description</td>
#       <td id="T_1e161_row4_col6" class="data row4 col6" >7</td>
#       <td id="T_1e161_row4_col7" class="data row4 col7" >11.42</td>
#       <td id="T_1e161_row4_col8" class="data row4 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_1e161_row5_col0" class="data row5 col0" >against the</td>
#       <td id="T_1e161_row5_col1" class="data row5 col1" >kde</td>
#       <td id="T_1e161_row5_col2" class="data row5 col2" >plot</td>
#       <td id="T_1e161_row5_col3" class="data row5 col3" >Negative</td>
#       <td id="T_1e161_row5_col4" class="data row5 col4" >Description</td>
#       <td id="T_1e161_row5_col5" class="data row5 col5" >AcademicTerms</td>
#       <td id="T_1e161_row5_col6" class="data row5 col6" >6</td>
#       <td id="T_1e161_row5_col7" class="data row5 col7" >9.79</td>
#       <td id="T_1e161_row5_col8" class="data row5 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_1e161_row6_col0" class="data row6 col0" >false</td>
#       <td id="T_1e161_row6_col1" class="data row6 col1" >negative</td>
#       <td id="T_1e161_row6_col2" class="data row6 col2" >errors</td>
#       <td id="T_1e161_row6_col3" class="data row6 col3" >Negative</td>
#       <td id="T_1e161_row6_col4" class="data row6 col4" >Negative</td>
#       <td id="T_1e161_row6_col5" class="data row6 col5" >Negative</td>
#       <td id="T_1e161_row6_col6" class="data row6 col6" >6</td>
#       <td id="T_1e161_row6_col7" class="data row6 col7" >9.79</td>
#       <td id="T_1e161_row6_col8" class="data row6 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_1e161_row7_col0" class="data row7 col0" >issue</td>
#       <td id="T_1e161_row7_col1" class="data row7 col1" >with your</td>
#       <td id="T_1e161_row7_col2" class="data row7 col2" >employer</td>
#       <td id="T_1e161_row7_col3" class="data row7 col3" >Negative</td>
#       <td id="T_1e161_row7_col4" class="data row7 col4" >Interactive</td>
#       <td id="T_1e161_row7_col5" class="data row7 col5" >Character</td>
#       <td id="T_1e161_row7_col6" class="data row7 col6" >6</td>
#       <td id="T_1e161_row7_col7" class="data row7 col7" >9.79</td>
#       <td id="T_1e161_row7_col8" class="data row7 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_1e161_row8_col0" class="data row8 col0" >no</td>
#       <td id="T_1e161_row8_col1" class="data row8 col1" >formal</td>
#       <td id="T_1e161_row8_col2" class="data row8 col2" >education</td>
#       <td id="T_1e161_row8_col3" class="data row8 col3" >Negative</td>
#       <td id="T_1e161_row8_col4" class="data row8 col4" >AcademicTerms</td>
#       <td id="T_1e161_row8_col5" class="data row8 col5" >AcademicTerms</td>
#       <td id="T_1e161_row8_col6" class="data row8 col6" >6</td>
#       <td id="T_1e161_row8_col7" class="data row8 col7" >9.79</td>
#       <td id="T_1e161_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1e161_row9_col0" class="data row9 col0" >repositories</td>
#       <td id="T_1e161_row9_col1" class="data row9 col1" >do</td>
#       <td id="T_1e161_row9_col2" class="data row9 col2" >data</td>
#       <td id="T_1e161_row9_col3" class="data row9 col3" >Negative</td>
#       <td id="T_1e161_row9_col4" class="data row9 col4" >ForceStressed</td>
#       <td id="T_1e161_row9_col5" class="data row9 col5" >AcademicTerms</td>
#       <td id="T_1e161_row9_col6" class="data row9 col6" >6</td>
#       <td id="T_1e161_row9_col7" class="data row9 col7" >9.79</td>
#       <td id="T_1e161_row9_col8" class="data row9 col8" >33.33</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.5 Collocation Frequency Tables

# %% [markdown]
# Calculate *collocations* within a left-and-right span of a node word can be calculated according to several association measures.
#
# Default span is 4 tokens to the left and 4 tokens to the right of the node word.
#
# Like `frequency_table`, `coll_table` requires a dictionary of the type generated by the `convert_corpus` function. It also requires
#
# - a node word,
# - a node tag, and
# - an association measure statistic
#
# <blockquote>
# <h4><a href="https://docuscospacy.readthedocs.io/en/latest/api.html#corpus-analysis-coll-table-tok-node-word-l-span-4-r-span-4-statistic-pmi-count-by-pos-node-tag-none-tag-ignore-false">corpus_analysis.coll_table(tok, node_word, l_span=4, r_span=4, statistic=’pmi’, count_by=’pos’, node_tag=None, tag_ignore=False)</a></h4>
# <div><dl class="field-list simple">
# <dt class="field-odd">Parameters</dt>
# <dd class="field-odd"><ul class="simple">
# <li><p><strong>tok</strong> - A dictionary of tuples as generated by the <cite>convert_corpus</cite> function</p></li>
# <li><p><strong>node_word</strong> - The token around with collocations are measured</p></li>
# <li><p><strong>l_span</strong> - An integer between 0 and 9 representing the span to the left of the node word</p></li>
# <li><p><strong>r_span</strong> - An integer between 0 and 9 representing the span to the right of the node word</p></li>
# <li><p><strong>statistic</strong> - The association measure to be calculated. One of: ‘pmi’, ‘npmi’, ‘pmi2’, ‘pmi3’</p></li>
# <li><p><strong>count_by</strong> - One of ‘pos’ or ‘ds’ for aggregating tokens</p></li>
# <li><p><strong>node_tag</strong> - A value specifying the tag of the node word. If the node_word were ‘can’, a node_tag ‘V’ would search for can as a verb.</p></li>
# <li><p><strong>tag_ignore</strong> - A boolean value indicating whether or not tags should be ignored during analysis.</p></li>
# </ul>
# </dd>
# <dt class="field-even">Return</dt>
# <dd class="field-even"><ul class="simple">
# <li><p>a dataframe containing collocate tokens, tags, the absolute frequency the collocate in the corpus, the absolute frequency of the collocate within the designated span, and the association measure.</p></li>
# </ul>
# </dd>
# </dl>
# </div>
# </blockquote>

# %% [markdown]
# ##### POS tags

# %%
collocations_freq_table_POS = coll_table(
    tok=tp,
    node_word='can',
    node_tag='V',
    statistic='pmi',
    count_by='pos'
)
collocations_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/benpost/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb Cell 99 line 1
# ----> <a href='vscode-notebook-cell:/Users/benpost/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=0'>1</a> collocations_freq_table_POS = coll_table(
#       <a href='vscode-notebook-cell:/Users/benpost/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=1'>2</a>     tok=tp,
#       <a href='vscode-notebook-cell:/Users/benpost/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=2'>3</a>     node_word='can',
#       <a href='vscode-notebook-cell:/Users/benpost/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=3'>4</a>     node_tag='V',
#       <a href='vscode-notebook-cell:/Users/benpost/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=4'>5</a>     statistic='pmi',
#       <a href='vscode-notebook-cell:/Users/benpost/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=5'>6</a>     count_by='pos'
#       <a href='vscode-notebook-cell:/Users/benpost/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=6'>7</a> )
#       <a href='vscode-notebook-cell:/Users/benpost/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=7'>8</a> collocations_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/docuscospacy/corpus_analysis.py:249, in coll_table(tok, node_word, l_span, r_span, statistic, count_by, node_tag, tag_ignore)
#     247     df = pd.merge(df_span, df_total, how='inner', on=['Token', 'Tag'])
#     248 if statistic=='pmi':
# --> 249     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=False)
#     250 if statistic=='npmi':
#     251     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tmtoolkit/tokenseq/_metrics.py:62, in pmi(x, y, xy, n_total, logfn, k, alpha, normalize)
#      59 if k > 1 and normalize:
#      60     raise ValueError('normalization is only implemented for standard PMI with `k=1`')
# ---> 62 if x.ndim == 1:
#      63     if y is None or xy is None or x.shape != y.shape or x.shape != xy.shape:
#      64         raise ValueError('if `x` is given as vector, `y` and `xy` must also be given and must have the same length')
#
# AttributeError: 'int' object has no attribute 'ndim'

# %%
collocations_freq_table_POS.query('`Freq Total` > 5 and MI > 3 and Tag.str.startswith("V")').head(10).style.hide(axis='index').format(precision=2)

# %%
collocations_freq_table_POS_npmi = coll_table(
    tok=tp,
    node_word='data',
    node_tag='N',
    statistic='npmi',
    count_by='pos',
    # tag_ignore=True
)
collocations_freq_table_POS_npmi.head(10).style.hide(axis='index').format(precision=2)

# %% [markdown]
# ##### DS tags

# %%
# DS Time!
collocations_freq_table_DS_npmi = coll_table(
    tok=tp,
    node_word='data',
    node_tag='Academic Terms',
    statistic='npmi', 
    count_by='ds'
)
collocations_freq_table_DS_npmi.head(10).style.hide(axis='index').format(precision=2)

# %% [markdown]
# We can also calculate collocations, while ignoring tags completely by setting `tag_ignore` to `True`

# %%
collocations_freq_table_DS_npmi_ignore_tag = coll_table(
    tok=tp,
    # Dial up the span of words to search for
    l_span=6,
    r_span=6,
    node_word='justice',
    tag_ignore=True, 
    statistic='npmi'
)
# Note the sorting method used too
collocations_freq_table_DS_npmi_ignore_tag.sort_values(by=['Freq Total'], ascending=False).head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bd8c1">
#   <thead>
#     <tr>
#       <th id="T_bd8c1_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_bd8c1_level0_col1" class="col_heading level0 col1" >Freq Span</th>
#       <th id="T_bd8c1_level0_col2" class="col_heading level0 col2" >Freq Total</th>
#       <th id="T_bd8c1_level0_col3" class="col_heading level0 col3" >MI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bd8c1_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_bd8c1_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_bd8c1_row0_col2" class="data row0 col2" >23078</td>
#       <td id="T_bd8c1_row0_col3" class="data row0 col3" >0.22</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row1_col0" class="data row1 col0" >of</td>
#       <td id="T_bd8c1_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_bd8c1_row1_col2" class="data row1 col2" >10582</td>
#       <td id="T_bd8c1_row1_col3" class="data row1 col3" >0.28</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row2_col0" class="data row2 col0" >to</td>
#       <td id="T_bd8c1_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_bd8c1_row2_col2" class="data row2 col2" >8717</td>
#       <td id="T_bd8c1_row2_col3" class="data row2 col3" >0.29</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row3_col0" class="data row3 col0" >and</td>
#       <td id="T_bd8c1_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_bd8c1_row3_col2" class="data row3 col2" >8013</td>
#       <td id="T_bd8c1_row3_col3" class="data row3 col3" >0.30</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row4_col0" class="data row4 col0" >that</td>
#       <td id="T_bd8c1_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_bd8c1_row4_col2" class="data row4 col2" >4346</td>
#       <td id="T_bd8c1_row4_col3" class="data row4 col3" >0.35</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row5_col0" class="data row5 col0" >it</td>
#       <td id="T_bd8c1_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_bd8c1_row5_col2" class="data row5 col2" >3140</td>
#       <td id="T_bd8c1_row5_col3" class="data row5 col3" >0.37</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row6_col0" class="data row6 col0" >do</td>
#       <td id="T_bd8c1_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_bd8c1_row6_col2" class="data row6 col2" >972</td>
#       <td id="T_bd8c1_row6_col3" class="data row6 col3" >0.47</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row7_col0" class="data row7 col0" >hope</td>
#       <td id="T_bd8c1_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_bd8c1_row7_col2" class="data row7 col2" >39</td>
#       <td id="T_bd8c1_row7_col3" class="data row7 col3" >0.72</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row8_col0" class="data row8 col0" >concept</td>
#       <td id="T_bd8c1_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_bd8c1_row8_col2" class="data row8 col2" >19</td>
#       <td id="T_bd8c1_row8_col3" class="data row8 col3" >0.77</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row9_col0" class="data row9 col0" >ensembling</td>
#       <td id="T_bd8c1_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_bd8c1_row9_col2" class="data row9 col2" >14</td>
#       <td id="T_bd8c1_row9_col3" class="data row9 col3" >0.79</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4.4 Document-term matrices for tags

# %% [markdown]
# Document-term matrices (DTMs) are basic data structures for text analysis. Each row is a document (observation) and each column is a token (variable). These can be produced by tmtoolkit) using the `dtm` function.
#
# The `docuscopspacy` package allows for the creation of DTMs with (*raw*) tag counts (rather than token counts) as variables.
#
# These are produced by the `tags_dtm` function, which takes a dictionary created by the `convert_corpus` function and a `count_by` argument of either `‘pos’` or `‘ds’`.

# %% [markdown]
# ### 4.4.1 POS DTM

# %%
dtm_POS = tags_dtm(
    tok=tp,
    count_by='pos'
)

# %%
dtm_POS.head(10).style.hide(axis='index').format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6be31">
#   <thead>
#     <tr>
#       <th id="T_6be31_level0_col0" class="col_heading level0 col0" >doc_id</th>
#       <th id="T_6be31_level0_col1" class="col_heading level0 col1" >APPGE</th>
#       <th id="T_6be31_level0_col2" class="col_heading level0 col2" >AT</th>
#       <th id="T_6be31_level0_col3" class="col_heading level0 col3" >AT1</th>
#       <th id="T_6be31_level0_col4" class="col_heading level0 col4" >BCL</th>
#       <th id="T_6be31_level0_col5" class="col_heading level0 col5" >CC</th>
#       <th id="T_6be31_level0_col6" class="col_heading level0 col6" >CCB</th>
#       <th id="T_6be31_level0_col7" class="col_heading level0 col7" >CS</th>
#       <th id="T_6be31_level0_col8" class="col_heading level0 col8" >CSA</th>
#       <th id="T_6be31_level0_col9" class="col_heading level0 col9" >CSN</th>
#       <th id="T_6be31_level0_col10" class="col_heading level0 col10" >CST</th>
#       <th id="T_6be31_level0_col11" class="col_heading level0 col11" >CSW</th>
#       <th id="T_6be31_level0_col12" class="col_heading level0 col12" >DA</th>
#       <th id="T_6be31_level0_col13" class="col_heading level0 col13" >DA1</th>
#       <th id="T_6be31_level0_col14" class="col_heading level0 col14" >DA2</th>
#       <th id="T_6be31_level0_col15" class="col_heading level0 col15" >DAR</th>
#       <th id="T_6be31_level0_col16" class="col_heading level0 col16" >DAT</th>
#       <th id="T_6be31_level0_col17" class="col_heading level0 col17" >DB</th>
#       <th id="T_6be31_level0_col18" class="col_heading level0 col18" >DB2</th>
#       <th id="T_6be31_level0_col19" class="col_heading level0 col19" >DD</th>
#       <th id="T_6be31_level0_col20" class="col_heading level0 col20" >DD1</th>
#       <th id="T_6be31_level0_col21" class="col_heading level0 col21" >DD2</th>
#       <th id="T_6be31_level0_col22" class="col_heading level0 col22" >DDQ</th>
#       <th id="T_6be31_level0_col23" class="col_heading level0 col23" >DDQGE</th>
#       <th id="T_6be31_level0_col24" class="col_heading level0 col24" >DDQV</th>
#       <th id="T_6be31_level0_col25" class="col_heading level0 col25" >EX</th>
#       <th id="T_6be31_level0_col26" class="col_heading level0 col26" >FO</th>
#       <th id="T_6be31_level0_col27" class="col_heading level0 col27" >FW</th>
#       <th id="T_6be31_level0_col28" class="col_heading level0 col28" >GE</th>
#       <th id="T_6be31_level0_col29" class="col_heading level0 col29" >IF</th>
#       <th id="T_6be31_level0_col30" class="col_heading level0 col30" >II</th>
#       <th id="T_6be31_level0_col31" class="col_heading level0 col31" >IO</th>
#       <th id="T_6be31_level0_col32" class="col_heading level0 col32" >IW</th>
#       <th id="T_6be31_level0_col33" class="col_heading level0 col33" >JJ</th>
#       <th id="T_6be31_level0_col34" class="col_heading level0 col34" >JJR</th>
#       <th id="T_6be31_level0_col35" class="col_heading level0 col35" >JJT</th>
#       <th id="T_6be31_level0_col36" class="col_heading level0 col36" >JK</th>
#       <th id="T_6be31_level0_col37" class="col_heading level0 col37" >MC</th>
#       <th id="T_6be31_level0_col38" class="col_heading level0 col38" >MC1</th>
#       <th id="T_6be31_level0_col39" class="col_heading level0 col39" >MC2</th>
#       <th id="T_6be31_level0_col40" class="col_heading level0 col40" >MCMC</th>
#       <th id="T_6be31_level0_col41" class="col_heading level0 col41" >MD</th>
#       <th id="T_6be31_level0_col42" class="col_heading level0 col42" >MF</th>
#       <th id="T_6be31_level0_col43" class="col_heading level0 col43" >ND1</th>
#       <th id="T_6be31_level0_col44" class="col_heading level0 col44" >NN</th>
#       <th id="T_6be31_level0_col45" class="col_heading level0 col45" >NN1</th>
#       <th id="T_6be31_level0_col46" class="col_heading level0 col46" >NN2</th>
#       <th id="T_6be31_level0_col47" class="col_heading level0 col47" >NNA</th>
#       <th id="T_6be31_level0_col48" class="col_heading level0 col48" >NNL1</th>
#       <th id="T_6be31_level0_col49" class="col_heading level0 col49" >NNO</th>
#       <th id="T_6be31_level0_col50" class="col_heading level0 col50" >NNO2</th>
#       <th id="T_6be31_level0_col51" class="col_heading level0 col51" >NNT1</th>
#       <th id="T_6be31_level0_col52" class="col_heading level0 col52" >NNT2</th>
#       <th id="T_6be31_level0_col53" class="col_heading level0 col53" >NNU</th>
#       <th id="T_6be31_level0_col54" class="col_heading level0 col54" >NNU1</th>
#       <th id="T_6be31_level0_col55" class="col_heading level0 col55" >NNU2</th>
#       <th id="T_6be31_level0_col56" class="col_heading level0 col56" >NP</th>
#       <th id="T_6be31_level0_col57" class="col_heading level0 col57" >NP1</th>
#       <th id="T_6be31_level0_col58" class="col_heading level0 col58" >NP2</th>
#       <th id="T_6be31_level0_col59" class="col_heading level0 col59" >NPD1</th>
#       <th id="T_6be31_level0_col60" class="col_heading level0 col60" >NPM1</th>
#       <th id="T_6be31_level0_col61" class="col_heading level0 col61" >PN</th>
#       <th id="T_6be31_level0_col62" class="col_heading level0 col62" >PN1</th>
#       <th id="T_6be31_level0_col63" class="col_heading level0 col63" >PNQO</th>
#       <th id="T_6be31_level0_col64" class="col_heading level0 col64" >PNQS</th>
#       <th id="T_6be31_level0_col65" class="col_heading level0 col65" >PNQV</th>
#       <th id="T_6be31_level0_col66" class="col_heading level0 col66" >PPGE</th>
#       <th id="T_6be31_level0_col67" class="col_heading level0 col67" >PPH1</th>
#       <th id="T_6be31_level0_col68" class="col_heading level0 col68" >PPHO1</th>
#       <th id="T_6be31_level0_col69" class="col_heading level0 col69" >PPHO2</th>
#       <th id="T_6be31_level0_col70" class="col_heading level0 col70" >PPHS1</th>
#       <th id="T_6be31_level0_col71" class="col_heading level0 col71" >PPHS2</th>
#       <th id="T_6be31_level0_col72" class="col_heading level0 col72" >PPIO1</th>
#       <th id="T_6be31_level0_col73" class="col_heading level0 col73" >PPIO2</th>
#       <th id="T_6be31_level0_col74" class="col_heading level0 col74" >PPIS1</th>
#       <th id="T_6be31_level0_col75" class="col_heading level0 col75" >PPIS2</th>
#       <th id="T_6be31_level0_col76" class="col_heading level0 col76" >PPX1</th>
#       <th id="T_6be31_level0_col77" class="col_heading level0 col77" >PPX2</th>
#       <th id="T_6be31_level0_col78" class="col_heading level0 col78" >PPY</th>
#       <th id="T_6be31_level0_col79" class="col_heading level0 col79" >RA</th>
#       <th id="T_6be31_level0_col80" class="col_heading level0 col80" >REX</th>
#       <th id="T_6be31_level0_col81" class="col_heading level0 col81" >RG</th>
#       <th id="T_6be31_level0_col82" class="col_heading level0 col82" >RGQ</th>
#       <th id="T_6be31_level0_col83" class="col_heading level0 col83" >RGQV</th>
#       <th id="T_6be31_level0_col84" class="col_heading level0 col84" >RGR</th>
#       <th id="T_6be31_level0_col85" class="col_heading level0 col85" >RGT</th>
#       <th id="T_6be31_level0_col86" class="col_heading level0 col86" >RL</th>
#       <th id="T_6be31_level0_col87" class="col_heading level0 col87" >RP</th>
#       <th id="T_6be31_level0_col88" class="col_heading level0 col88" >RPK</th>
#       <th id="T_6be31_level0_col89" class="col_heading level0 col89" >RR</th>
#       <th id="T_6be31_level0_col90" class="col_heading level0 col90" >RRQ</th>
#       <th id="T_6be31_level0_col91" class="col_heading level0 col91" >RRQV</th>
#       <th id="T_6be31_level0_col92" class="col_heading level0 col92" >RRR</th>
#       <th id="T_6be31_level0_col93" class="col_heading level0 col93" >RRT</th>
#       <th id="T_6be31_level0_col94" class="col_heading level0 col94" >RT</th>
#       <th id="T_6be31_level0_col95" class="col_heading level0 col95" >TO</th>
#       <th id="T_6be31_level0_col96" class="col_heading level0 col96" >UH</th>
#       <th id="T_6be31_level0_col97" class="col_heading level0 col97" >VB0</th>
#       <th id="T_6be31_level0_col98" class="col_heading level0 col98" >VBDR</th>
#       <th id="T_6be31_level0_col99" class="col_heading level0 col99" >VBDZ</th>
#       <th id="T_6be31_level0_col1

# %% [markdown]
# ### 4.4.2 DS DTM

# %%
dtm_DS = tags_dtm(
    tok=tp,
    count_by='ds'
)
dtm_DS.head(10).style.hide(axis='index').format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0f9eb">
#   <thead>
#     <tr>
#       <th id="T_0f9eb_level0_col0" class="col_heading level0 col0" >doc_id</th>
#       <th id="T_0f9eb_level0_col1" class="col_heading level0 col1" >AcademicTerms</th>
#       <th id="T_0f9eb_level0_col2" class="col_heading level0 col2" >AcademicWritingMoves</th>
#       <th id="T_0f9eb_level0_col3" class="col_heading level0 col3" >Character</th>
#       <th id="T_0f9eb_level0_col4" class="col_heading level0 col4" >Citation</th>
#       <th id="T_0f9eb_level0_col5" class="col_heading level0 col5" >CitationAuthority</th>
#       <th id="T_0f9eb_level0_col6" class="col_heading level0 col6" >CitationHedged</th>
#       <th id="T_0f9eb_level0_col7" class="col_heading level0 col7" >ConfidenceHedged</th>
#       <th id="T_0f9eb_level0_col8" class="col_heading level0 col8" >ConfidenceHigh</th>
#       <th id="T_0f9eb_level0_col9" class="col_heading level0 col9" >ConfidenceLow</th>
#       <th id="T_0f9eb_level0_col10" class="col_heading level0 col10" >Contingent</th>
#       <th id="T_0f9eb_level0_col11" class="col_heading level0 col11" >Description</th>
#       <th id="T_0f9eb_level0_col12" class="col_heading level0 col12" >Facilitate</th>
#       <th id="T_0f9eb_level0_col13" class="col_heading level0 col13" >FirstPerson</th>
#       <th id="T_0f9eb_level0_col14" class="col_heading level0 col14" >ForceStressed</th>
#       <th id="T_0f9eb_level0_col15" class="col_heading level0 col15" >Future</th>
#       <th id="T_0f9eb_level0_col16" class="col_heading level0 col16" >InformationChange</th>
#       <th id="T_0f9eb_level0_col17" class="col_heading level0 col17" >InformationChangeNegative</th>
#       <th id="T_0f9eb_level0_col18" class="col_heading level0 col18" >InformationChangePositive</th>
#       <th id="T_0f9eb_level0_col19" class="col_heading level0 col19" >InformationExposition</th>
#       <th id="T_0f9eb_level0_col20" class="col_heading level0 col20" >InformationPlace</th>
#       <th id="T_0f9eb_level0_col21" class="col_heading level0 col21" >InformationReportVerbs</th>
#       <th id="T_0f9eb_level0_col22" class="col_heading level0 col22" >InformationStates</th>
#       <th id="T_0f9eb_level0_col23" class="col_heading level0 col23" >InformationTopics</th>
#       <th id="T_0f9eb_level0_col24" class="col_heading level0 col24" >Inquiry</th>
#       <th id="T_0f9eb_level0_col25" class="col_heading level0 col25" >Interactive</th>
#       <th id="T_0f9eb_level0_col26" class="col_heading level0 col26" >MetadiscourseCohesive</th>
#       <th id="T_0f9eb_level0_col27" class="col_heading level0 col27" >MetadiscourseInteractive</th>
#       <th id="T_0f9eb_level0_col28" class="col_heading level0 col28" >Narrative</th>
#       <th id="T_0f9eb_level0_col29" class="col_heading level0 col29" >Negative</th>
#       <th id="T_0f9eb_level0_col30" class="col_heading level0 col30" >Positive</th>
#       <th id="T_0f9eb_level0_col31" class="col_heading level0 col31" >PublicTerms</th>
#       <th id="T_0f9eb_level0_col32" class="col_heading level0 col32" >Reasoning</th>
#       <th id="T_0f9eb_level0_col33" class="col_heading level0 col33" >Responsibility</th>
#       <th id="T_0f9eb_level0_col34" class="col_heading level0 col34" >Strategic</th>
#       <th id="T_0f9eb_level0_col35" class="col_heading level0 col35" >Uncertainty</th>
#       <th id="T_0f9eb_level0_col36" class="col_heading level0 col36" >Untagged</th>
#       <th id="T_0f9eb_level0_col37" class="col_heading level0 col37" >Updates</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0f9eb_row0_col0" class="data row0 col0" >kaggle_LAST_THIRD_CELLS_votes_notebooks</td>
#       <td id="T_0f9eb_row0_col1" class="data row0 col1" >7949</td>
#       <td id="T_0f9eb_row0_col2" class="data row0 col2" >575</td>
#       <td id="T_0f9eb_row0_col3" class="data row0 col3" >3542</td>
#       <td id="T_0f9eb_row0_col4" class="data row0 col4" >198</td>
#       <td id="T_0f9eb_row0_col5" class="data row0 col5" >115</td>
#       <td id="T_0f9eb_row0_col6" class="data row0 col6" >21</td>
#       <td id="T_0f9eb_row0_col7" class="data row0 col7" >1009</td>
#       <td id="T_0f9eb_row0_col8" class="data row0 col8" >483</td>
#       <td id="T_0f9eb_row0_col9" class="data row0 col9" >5</td>
#       <td id="T_0f9eb_row0_col10" class="data row0 col10" >615</td>
#       <td id="T_0f9eb_row0_col11" class="data row0 col11" >6213</td>
#       <td id="T_0f9eb_row0_col12" class="data row0 col12" >261</td>
#       <td id="T_0f9eb_row0_col13" class="data row0 col13" >497</td>
#       <td id="T_0f9eb_row0_col14" class="data row0 col14" >1809</td>
#       <td id="T_0f9eb_row0_col15" class="data row0 col15" >552</td>
#       <td id="T_0f9eb_row0_col16" class="data row0 col16" >810</td>
#       <td id="T_0f9eb_row0_col17" class="data row0 col17" >40</td>
#       <td id="T_0f9eb_row0_col18" class="data row0 col18" >196</td>
#       <td id="T_0f9eb_row0_col19" class="data row0 col19" >5284</td>
#       <td id="T_0f9eb_row0_col20" class="data row0 col20" >207</td>
#       <td id="T_0f9eb_row0_col21" class="data row0 col21" >833</td>
#       <td id="T_0f9eb_row0_col22" class="data row0 col22" >1446</td>
#       <td id="T_0f9eb_row0_col23" class="data row0 col23" >2666</td>
#       <td id="T_0f9eb_row0_col24" class="data row0 col24" >876</td>
#       <td id="T_0f9eb_row0_col25" class="data row0 col25" >1476</td>
#       <td id="T_0f9eb_row0_col26" class="data row0 col26" >1546</td>
#       <td id="T_0f9eb_row0_col27" class="data row0 col27" >575</td>
#       <td id="T_0f9eb_row0_col28" class="data row0 col28" >3653</td>
#       <td id="T_0f9eb_row0_col29" class="data row0 col29" >1856</td>
#       <td id="T_0f9eb_row0_col30" class="data row0 col30" >1661</td>
#       <td id="T_0f9eb_row0_col31" class="data row0 col31" >541</td>
#       <td id="T_0f9eb_row0_col32" class="data row0 col32" >1402</td>
#       <td id="T_0f9eb_row0_col33" class="data row0 col33" >82</td>
#       <td id="T_0f9eb_row0_col34" class="data row0 col34" >1347</td>
#       <td id="T_0f9eb_row0_col35" class="data row0 col35" >80</td>
#       <td id="T_0f9eb_row0_col36" class="data row0 col36" >29230</td>
#       <td id="T_0f9eb_row0_col37" class="data row0 col37" >213</td>
#     </tr>
#     <tr>
#       <td id="T_0f9eb_row1_col0" class="data row1 col0" >kaggle_SECOND_THIRD_CELLS_votes_notebooks</td>
#       <td id="T_0f9eb_row1_col1" class="data row1 col1" >8700</td>
#       <td id="T_0f9eb_row1_col2" class="data row1 col2" >573</td>
#       <td id="T_0f9eb_row1_col3" class="data row1 col3" >3773</td>
#       <td id="T_0f9eb_row1_col4" class="data row1 col4" >225</td>
#       <td id="T_0f9eb_row1_col5" class="data row1 col5" >120</td>
#       <td id="T_0f9eb_row1_col6" class="data row1 col6" >13</td>
#       <td id="T_0f9eb_row1_col7" class="data row1 col7" >1234</td>
#       <td id="T_0f9eb_row1_col8" class="data row1 col8" >581</td>
#       <td id="T_0f9eb_row1_col9" class="data row1 col9" >4</td>
#       <td id="T_0f9eb_row1_col10" class="data row1 col10" >598</td>
#       <td id="T_0f9eb_row1_col11" class="data row1 col11" >6711</td>
#       <td id="T_0f9eb_row1_col12" class="data row1 col12" >320</td>
#       <td id="T_0f9eb_row1_col13" class="data row1 col13" >505</td>
#       <td id="T_0f9eb_row1_col14" class="data row1 col14" >1888</td>
#       <td id="T_0f9eb_row1_col15" class="data row1 col15" >593</td>
#       <td id="T_0f9eb_row1_col16" class="data row1 col16" >910</td>
#       <td id="T_0f9eb_row1_col17" class="data row1 col17" >39</td>
#       <td id="T_0f9eb_row1_col18" class="data row1 col18" >146</td>
#       <td id="T_0f9eb_row1_col19" class="data row1 col19" >6245</td>
#       <td id="T_0f9eb_row1_col20" class="data row1 col20" >425</td>
#       <td id="T_0f9eb_row1_col21" class="data row1 col21" >828</td>
#       <td id="T_0f9eb_row1_col22" class="data row1 col22" >1696</td>
#       <td id="T_0f9eb_row1_col23" class="data row1 col23" >2745</td>
#       <td id="T_0f9eb_row1_col24" class="data row1 col24" >1017</td>
#       <td id="T_0f9eb_row1_col25" class="data row1 col25" >1450</td>
#       <td id="T_0f9eb_row1_col26" class="data row1 col26" >1762</td>
#       <td id="T_0f9e

# %% [markdown]
# ### 4.4.3 Count frequencies, then give weight (importance) to document-term counts
#
# We can use the tmtoolkit library to create weighted counts (using its `tf_proportions` function), `tf-idf` values (using the tfidf function), or other types of data structures.

# %%
from temptmtoolkit.bow.bow_stats import tf_proportions, tfidf

# %% [markdown]
# #### 4.4.3.1 Count the document term frequencies (raw counts)

# %%
dtm_POS.set_index('doc_id', inplace=True)
dtm_POS.head(10).style.format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b08f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b08f7_level0_col0" class="col_heading level0 col0" >APPGE</th>
#       <th id="T_b08f7_level0_col1" class="col_heading level0 col1" >AT</th>
#       <th id="T_b08f7_level0_col2" class="col_heading level0 col2" >AT1</th>
#       <th id="T_b08f7_level0_col3" class="col_heading level0 col3" >BCL</th>
#       <th id="T_b08f7_level0_col4" class="col_heading level0 col4" >CC</th>
#       <th id="T_b08f7_level0_col5" class="col_heading level0 col5" >CCB</th>
#       <th id="T_b08f7_level0_col6" class="col_heading level0 col6" >CS</th>
#       <th id="T_b08f7_level0_col7" class="col_heading level0 col7" >CSA</th>
#       <th id="T_b08f7_level0_col8" class="col_heading level0 col8" >CSN</th>
#       <th id="T_b08f7_level0_col9" class="col_heading level0 col9" >CST</th>
#       <th id="T_b08f7_level0_col10" class="col_heading level0 col10" >CSW</th>
#       <th id="T_b08f7_level0_col11" class="col_heading level0 col11" >DA</th>
#       <th id="T_b08f7_level0_col12" class="col_heading level0 col12" >DA1</th>
#       <th id="T_b08f7_level0_col13" class="col_heading level0 col13" >DA2</th>
#       <th id="T_b08f7_level0_col14" class="col_heading level0 col14" >DAR</th>
#       <th id="T_b08f7_level0_col15" class="col_heading level0 col15" >DAT</th>
#       <th id="T_b08f7_level0_col16" class="col_heading level0 col16" >DB</th>
#       <th id="T_b08f7_level0_col17" class="col_heading level0 col17" >DB2</th>
#       <th id="T_b08f7_level0_col18" class="col_heading level0 col18" >DD</th>
#       <th id="T_b08f7_level0_col19" class="col_heading level0 col19" >DD1</th>
#       <th id="T_b08f7_level0_col20" class="col_heading level0 col20" >DD2</th>
#       <th id="T_b08f7_level0_col21" class="col_heading level0 col21" >DDQ</th>
#       <th id="T_b08f7_level0_col22" class="col_heading level0 col22" >DDQGE</th>
#       <th id="T_b08f7_level0_col23" class="col_heading level0 col23" >DDQV</th>
#       <th id="T_b08f7_level0_col24" class="col_heading level0 col24" >EX</th>
#       <th id="T_b08f7_level0_col25" class="col_heading level0 col25" >FO</th>
#       <th id="T_b08f7_level0_col26" class="col_heading level0 col26" >FW</th>
#       <th id="T_b08f7_level0_col27" class="col_heading level0 col27" >GE</th>
#       <th id="T_b08f7_level0_col28" class="col_heading level0 col28" >IF</th>
#       <th id="T_b08f7_level0_col29" class="col_heading level0 col29" >II</th>
#       <th id="T_b08f7_level0_col30" class="col_heading level0 col30" >IO</th>
#       <th id="T_b08f7_level0_col31" class="col_heading level0 col31" >IW</th>
#       <th id="T_b08f7_level0_col32" class="col_heading level0 col32" >JJ</th>
#       <th id="T_b08f7_level0_col33" class="col_heading level0 col33" >JJR</th>
#       <th id="T_b08f7_level0_col34" class="col_heading level0 col34" >JJT</th>
#       <th id="T_b08f7_level0_col35" class="col_heading level0 col35" >JK</th>
#       <th id="T_b08f7_level0_col36" class="col_heading level0 col36" >MC</th>
#       <th id="T_b08f7_level0_col37" class="col_heading level0 col37" >MC1</th>
#       <th id="T_b08f7_level0_col38" class="col_heading level0 col38" >MC2</th>
#       <th id="T_b08f7_level0_col39" class="col_heading level0 col39" >MCMC</th>
#       <th id="T_b08f7_level0_col40" class="col_heading level0 col40" >MD</th>
#       <th id="T_b08f7_level0_col41" class="col_heading level0 col41" >MF</th>
#       <th id="T_b08f7_level0_col42" class="col_heading level0 col42" >ND1</th>
#       <th id="T_b08f7_level0_col43" class="col_heading level0 col43" >NN</th>
#       <th id="T_b08f7_level0_col44" class="col_heading level0 col44" >NN1</th>
#       <th id="T_b08f7_level0_col45" class="col_heading level0 col45" >NN2</th>
#       <th id="T_b08f7_level0_col46" class="col_heading level0 col46" >NNA</th>
#       <th id="T_b08f7_level0_col47" class="col_heading level0 col47" >NNL1</th>
#       <th id="T_b08f7_level0_col48" class="col_heading level0 col48" >NNO</th>
#       <th id="T_b08f7_level0_col49" class="col_heading level0 col49" >NNO2</th>
#       <th id="T_b08f7_level0_col50" class="col_heading level0 col50" >NNT1</th>
#       <th id="T_b08f7_level0_col51" class="col_heading level0 col51" >NNT2</th>
#       <th id="T_b08f7_level0_col52" class="col_heading level0 col52" >NNU</th>
#       <th id="T_b08f7_level0_col53" class="col_heading level0 col53" >NNU1</th>
#       <th id="T_b08f7_level0_col54" class="col_heading level0 col54" >NNU2</th>
#       <th id="T_b08f7_level0_col55" class="col_heading level0 col55" >NP</th>
#       <th id="T_b08f7_level0_col56" class="col_heading level0 col56" >NP1</th>
#       <th id="T_b08f7_level0_col57" class="col_heading level0 col57" >NP2</th>
#       <th id="T_b08f7_level0_col58" class="col_heading level0 col58" >NPD1</th>
#       <th id="T_b08f7_level0_col59" class="col_heading level0 col59" >NPM1</th>
#       <th id="T_b08f7_level0_col60" class="col_heading level0 col60" >PN</th>
#       <th id="T_b08f7_level0_col61" class="col_heading level0 col61" >PN1</th>
#       <th id="T_b08f7_level0_col62" class="col_heading level0 col62" >PNQO</th>
#       <th id="T_b08f7_level0_col63" class="col_heading level0 col63" >PNQS</th>
#       <th id="T_b08f7_level0_col64" class="col_heading level0 col64" >PNQV</th>
#       <th id="T_b08f7_level0_col65" class="col_heading level0 col65" >PPGE</th>
#       <th id="T_b08f7_level0_col66" class="col_heading level0 col66" >PPH1</th>
#       <th id="T_b08f7_level0_col67" class="col_heading level0 col67" >PPHO1</th>
#       <th id="T_b08f7_level0_col68" class="col_heading level0 col68" >PPHO2</th>
#       <th id="T_b08f7_level0_col69" class="col_heading level0 col69" >PPHS1</th>
#       <th id="T_b08f7_level0_col70" class="col_heading level0 col70" >PPHS2</th>
#       <th id="T_b08f7_level0_col71" class="col_heading level0 col71" >PPIO1</th>
#       <th id="T_b08f7_level0_col72" class="col_heading level0 col72" >PPIO2</th>
#       <th id="T_b08f7_level0_col73" class="col_heading level0 col73" >PPIS1</th>
#       <th id="T_b08f7_level0_col74" class="col_heading level0 col74" >PPIS2</th>
#       <th id="T_b08f7_level0_col75" class="col_heading level0 col75" >PPX1</th>
#       <th id="T_b08f7_level0_col76" class="col_heading level0 col76" >PPX2</th>
#       <th id="T_b08f7_level0_col77" class="col_heading level0 col77" >PPY</th>
#       <th id="T_b08f7_level0_col78" class="col_heading level0 col78" >RA</th>
#       <th id="T_b08f7_level0_col79" class="col_heading level0 col79" >REX</th>
#       <th id="T_b08f7_level0_col80" class="col_heading level0 col80" >RG</th>
#       <th id="T_b08f7_level0_col81" class="col_heading level0 col81" >RGQ</th>
#       <th id="T_b08f7_level0_col82" class="col_heading level0 col82" >RGQV</th>
#       <th id="T_b08f7_level0_col83" class="col_heading level0 col83" >RGR</th>
#       <th id="T_b08f7_level0_col84" class="col_heading level0 col84" >RGT</th>
#       <th id="T_b08f7_level0_col85" class="col_heading level0 col85" >RL</th>
#       <th id="T_b08f7_level0_col86" class="col_heading level0 col86" >RP</th>
#       <th id="T_b08f7_level0_col87" class="col_heading level0 col87" >RPK</th>
#       <th id="T_b08f7_level0_col88" class="col_heading level0 col88" >RR</th>
#       <th id="T_b08f7_level0_col89" class="col_heading level0 col89" >RRQ</th>
#       <th id="T_b08f7_level0_col90" class="col_heading level0 col90" >RRQV</th>
#       <th id="T_b08f7_level0_col91" class="col_heading level0 col91" >RRR</th>
#       <th id="T_b08f7_level0_col92" class="col_heading level0 col92" >RRT</th>
#       <th id="T_b08f7_level0_col93" class="col_heading level0 col93" >RT</th>
#       <th id="T_b08f7_level0_col94" class="col_heading level0 col94" >TO</th>
#       <th id="T_b08f7_level0_col95" class="col_heading level0 col95" >UH</th>
#       <th id="T_b08f7_level0_col96" class="col_heading level0 col96" >VB0</th>
#       <th id="T_b08f7_level0_col97" class="col_heading level0 col97" >VBDR</th>
#       <th id="T_b08f7_level0_col98" class="col_heading level0 col98" >VBDZ</th>
#       <th id="T_b08f7_level0_col99" class="col_heading level0 col99" >V

# %%
dtm_DS.set_index('doc_id', inplace=True)
dtm_DS.head(10).style.format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b65b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b65b_level0_col0" class="col_heading level0 col0" >AcademicTerms</th>
#       <th id="T_8b65b_level0_col1" class="col_heading level0 col1" >AcademicWritingMoves</th>
#       <th id="T_8b65b_level0_col2" class="col_heading level0 col2" >Character</th>
#       <th id="T_8b65b_level0_col3" class="col_heading level0 col3" >Citation</th>
#       <th id="T_8b65b_level0_col4" class="col_heading level0 col4" >CitationAuthority</th>
#       <th id="T_8b65b_level0_col5" class="col_heading level0 col5" >CitationHedged</th>
#       <th id="T_8b65b_level0_col6" class="col_heading level0 col6" >ConfidenceHedged</th>
#       <th id="T_8b65b_level0_col7" class="col_heading level0 col7" >ConfidenceHigh</th>
#       <th id="T_8b65b_level0_col8" class="col_heading level0 col8" >ConfidenceLow</th>
#       <th id="T_8b65b_level0_col9" class="col_heading level0 col9" >Contingent</th>
#       <th id="T_8b65b_level0_col10" class="col_heading level0 col10" >Description</th>
#       <th id="T_8b65b_level0_col11" class="col_heading level0 col11" >Facilitate</th>
#       <th id="T_8b65b_level0_col12" class="col_heading level0 col12" >FirstPerson</th>
#       <th id="T_8b65b_level0_col13" class="col_heading level0 col13" >ForceStressed</th>
#       <th id="T_8b65b_level0_col14" class="col_heading level0 col14" >Future</th>
#       <th id="T_8b65b_level0_col15" class="col_heading level0 col15" >InformationChange</th>
#       <th id="T_8b65b_level0_col16" class="col_heading level0 col16" >InformationChangeNegative</th>
#       <th id="T_8b65b_level0_col17" class="col_heading level0 col17" >InformationChangePositive</th>
#       <th id="T_8b65b_level0_col18" class="col_heading level0 col18" >InformationExposition</th>
#       <th id="T_8b65b_level0_col19" class="col_heading level0 col19" >InformationPlace</th>
#       <th id="T_8b65b_level0_col20" class="col_heading level0 col20" >InformationReportVerbs</th>
#       <th id="T_8b65b_level0_col21" class="col_heading level0 col21" >InformationStates</th>
#       <th id="T_8b65b_level0_col22" class="col_heading level0 col22" >InformationTopics</th>
#       <th id="T_8b65b_level0_col23" class="col_heading level0 col23" >Inquiry</th>
#       <th id="T_8b65b_level0_col24" class="col_heading level0 col24" >Interactive</th>
#       <th id="T_8b65b_level0_col25" class="col_heading level0 col25" >MetadiscourseCohesive</th>
#       <th id="T_8b65b_level0_col26" class="col_heading level0 col26" >MetadiscourseInteractive</th>
#       <th id="T_8b65b_level0_col27" class="col_heading level0 col27" >Narrative</th>
#       <th id="T_8b65b_level0_col28" class="col_heading level0 col28" >Negative</th>
#       <th id="T_8b65b_level0_col29" class="col_heading level0 col29" >Positive</th>
#       <th id="T_8b65b_level0_col30" class="col_heading level0 col30" >PublicTerms</th>
#       <th id="T_8b65b_level0_col31" class="col_heading level0 col31" >Reasoning</th>
#       <th id="T_8b65b_level0_col32" class="col_heading level0 col32" >Responsibility</th>
#       <th id="T_8b65b_level0_col33" class="col_heading level0 col33" >Strategic</th>
#       <th id="T_8b65b_level0_col34" class="col_heading level0 col34" >Uncertainty</th>
#       <th id="T_8b65b_level0_col35" class="col_heading level0 col35" >Untagged</th>
#       <th id="T_8b65b_level0_col36" class="col_heading level0 col36" >Updates</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >doc_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b65b_level0_row0" class="row_heading level0 row0" >kaggle_LAST_THIRD_CELLS_votes_notebooks</th>
#       <td id="T_8b65b_row0_col0" class="data row0 col0" >7949</td>
#       <td id="T_8b65b_row0_col1" class="data row0 col1" >575</td>
#       <td id="T_8b65b_row0_col2" class="data row0 col2" >3542</td>
#       <td id="T_8b65b_row0_col3" class="data row0 col3" >198</td>
#       <td id="T_8b65b_row0_col4" class="data row0 col4" >115</td>
#       <td id="T_8b65b_row0_col5" class="data row0 col5" >21</td>
#       <td id="T_8b65b_row0_col6" class="data row0 col6" >1009</td>
#       <td id="T_8b65b_row0_col7" class="data row0 col7" >483</td>
#       <td id="T_8b65b_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_8b65b_row0_col9" class="data row0 col9" >615</td>
#       <td id="T_8b65b_row0_col10" class="data row0 col10" >6213</td>
#       <td id="T_8b65b_row0_col11" class="data row0 col11" >261</td>
#       <td id="T_8b65b_row0_col12" class="data row0 col12" >497</td>
#       <td id="T_8b65b_row0_col13" class="data row0 col13" >1809</td>
#       <td id="T_8b65b_row0_col14" class="data row0 col14" >552</td>
#       <td id="T_8b65b_row0_col15" class="data row0 col15" >810</td>
#       <td id="T_8b65b_row0_col16" class="data row0 col16" >40</td>
#       <td id="T_8b65b_row0_col17" class="data row0 col17" >196</td>
#       <td id="T_8b65b_row0_col18" class="data row0 col18" >5284</td>
#       <td id="T_8b65b_row0_col19" class="data row0 col19" >207</td>
#       <td id="T_8b65b_row0_col20" class="data row0 col20" >833</td>
#       <td id="T_8b65b_row0_col21" class="data row0 col21" >1446</td>
#       <td id="T_8b65b_row0_col22" class="data row0 col22" >2666</td>
#       <td id="T_8b65b_row0_col23" class="data row0 col23" >876</td>
#       <td id="T_8b65b_row0_col24" class="data row0 col24" >1477</td>
#       <td id="T_8b65b_row0_col25" class="data row0 col25" >1546</td>
#       <td id="T_8b65b_row0_col26" class="data row0 col26" >575</td>
#       <td id="T_8b65b_row0_col27" class="data row0 col27" >3653</td>
#       <td id="T_8b65b_row0_col28" class="data row0 col28" >1856</td>
#       <td id="T_8b65b_row0_col29" class="data row0 col29" >1661</td>
#       <td id="T_8b65b_row0_col30" class="data row0 col30" >541</td>
#       <td id="T_8b65b_row0_col31" class="data row0 col31" >1402</td>
#       <td id="T_8b65b_row0_col32" class="data row0 col32" >82</td>
#       <td id="T_8b65b_row0_col33" class="data row0 col33" >1347</td>
#       <td id="T_8b65b_row0_col34" class="data row0 col34" >80</td>
#       <td id="T_8b65b_row0_col35" class="data row0 col35" >29230</td>
#       <td id="T_8b65b_row0_col36" class="data row0 col36" >213</td>
#     </tr>
#     <tr>
#       <th id="T_8b65b_level0_row1" class="row_heading level0 row1" >kaggle_SECOND_THIRD_CELLS_votes_notebooks</th>
#       <td id="T_8b65b_row1_col0" class="data row1 col0" >8701</td>
#       <td id="T_8b65b_row1_col1" class="data row1 col1" >573</td>
#       <td id=

# %% [markdown]
# #### 4.4.3.2 Weigh the document-terms by proportions
#
# Simply take the percentage of the frequencies across the sum across the corpus, e.g., AT () below comes out to roughly 6% of the corpus across the documents.

# %%
tf_proportions(dtm_POS).head(10)
# Out:
#                                               APPGE        AT       AT1  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.005298  0.060252  0.022153
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.006363  0.062831  0.022562
# kaggle_FIRST_THIRD_CELLS_notebooks         0.006683  0.062287  0.022563
#
#                                                 BCL        CC       CCB  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000320  0.024342  0.002959
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000288  0.025278  0.002706
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000397  0.025773  0.002567
#
#                                                  CS       CSA       CSN  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.008769  0.003632  0.002692
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.008023  0.003522  0.002726
# kaggle_FIRST_THIRD_CELLS_notebooks         0.008827  0.003082  0.002476
#
#                                                 CST  ...       VVD       VVG  \
# doc_id                                               ...
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.009378  ...  0.005629  0.017068
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.009347  ...  0.006296  0.015365
# kaggle_FIRST_THIRD_CELLS_notebooks         0.008564  ...  0.005574  0.017831
#
#                                                VVGK       VVI       VVN  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000459  0.028957  0.017677
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000173  0.029299  0.017111
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000343  0.030527  0.017434
#
#                                                VVNK       VVZ        XX  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000000  0.012091  0.005981
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000000  0.011699  0.006248
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000005  0.011496  0.005032
#
#                                                 ZZ1       ZZ2
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.008257  0.000000
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.006871  0.000010
# kaggle_FIRST_THIRD_CELLS_notebooks         0.006828  0.000011
#
# [3 rows x 130 columns]

# %%
tf_proportions(dtm_DS).head(10)
# Out:
#                                            AcademicTerms  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks         0.099530
# kaggle_SECOND_THIRD_CELLS_votes_notebooks       0.097932
# kaggle_FIRST_THIRD_CELLS_notebooks              0.098136
#
#                                            AcademicWritingMoves  Character  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks                0.007200   0.044350
# kaggle_SECOND_THIRD_CELLS_votes_notebooks              0.006449   0.042466
# kaggle_FIRST_THIRD_CELLS_notebooks                     0.008644   0.040035
#
#                                            Citation  CitationAuthority  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.002479           0.001440
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.002532           0.001351
# kaggle_FIRST_THIRD_CELLS_notebooks         0.002329           0.001193
#
#                                            CitationHedged  ConfidenceHedged  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks          0.000263          0.012634
# kaggle_SECOND_THIRD_CELLS_votes_notebooks        0.000146          0.013889
# kaggle_FIRST_THIRD_CELLS_notebooks               0.000094          0.011757
#
#                                            ConfidenceHigh  ConfidenceLow  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks          0.006048       0.000063
# kaggle_SECOND_THIRD_CELLS_votes_notebooks        0.006539       0.000045
# kaggle_FIRST_THIRD_CELLS_notebooks               0.006239       0.000082
#
#                                            Contingent  ...  Narrative  \
# doc_id                                                 ...
# kaggle_LAST_THIRD_CELLS_votes_notebooks      0.007700  ...   0.045740
# kaggle_SECOND_THIRD_CELLS_votes_notebooks    0.006731  ...   0.047948
# kaggle_FIRST_THIRD_CELLS_notebooks           0.006252  ...   0.049771
#
#                                            Negative  Positive  PublicTerms  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.023239  0.020798     0.006774
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.021982  0.020473     0.006382
# kaggle_FIRST_THIRD_CELLS_notebooks         0.020545  0.020834     0.008706
#
#                                            Reasoning  Responsibility  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks     0.017555        0.001027
# kaggle_SECOND_THIRD_CELLS_votes_notebooks   0.017637        0.000754
# kaggle_FIRST_THIRD_CELLS_notebooks          0.017626        0.001067
#
#                                            Strategic  Uncertainty  Untagged  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks     0.016866     0.001002  0.365993
# kaggle_SECOND_THIRD_CELLS_votes_notebooks   0.015802     0.001418  0.373586
# kaggle_FIRST_THIRD_CELLS_notebooks          0.017036     0.001174  0.373984
#
#                                             Updates
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.002667
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.002566
# kaggle_FIRST_THIRD_CELLS_notebooks         0.002869
#
# [3 rows x 37 columns]

# %% [markdown]
# #### 4.4.3.3 Weigh document terms by Term Frequencies in relation to Inverse Document Frequency (TF-IDF)

# %% [markdown]
# What's TF-IDF? It solves the raw-count problem, where all terms are treated equally. For instance, we would expect a corpus about pets to include high frequencies of terms like the nouns of pets: *cat*, *dog*, etc. Those raw counts aren't necessarily helpful in many cases, so one way to weigh the importance of terms to derive more targeted meaning from the corpus is by calculating either TF, IDF (Inverse Document Frequency), or TF-IDF.
#
# - TF: Relative frequency of a term within document by taking the sum of the term and dividing it by the sum total of all words in the document.
# - IDF: Calculation that diminishes the weight of terms that occur very frequently in the document set and increases the weight of terms that occur rarely. Hence, the IDF of a rare term is high, whereas the IDF of a frequent term is likely to be low.
#
# TF-IDF is the composite measure of TF and IDF. The tf-idf weighting scheme considers each document in a corpus as a vector, so it assigns to term $t$ a weight in document $d$. The end result? Each term can be considered in the following ways:
#
# 1. highest when $t$ occurs many times within a small number of documents (thus lending high discriminating power to those documents);
# 2. lower when the term occurs fewer times in a document, or occurs in many documents (thus offering a less pronounced relevance signal);
# 3. lowest when the term occurs in virtually all documents.
#
# <p style="background-color:#FFCCCB;color:black;margin:1rem;padding:1rem;font-size:0.9rem"><strong>NOTE</strong>: IDF should be based on a decently large corpora and should be representative of texts you would be using to extract keywords. Several articles on the web compute the IDF using only a handful of documents, so just be aware of this requirement.<br><br>To understand why IDF should be based on a fairly large collection, please read this <a href="./readings/IDF-explainer.pdf" target"_blank" rel="noopenner noreferrer">page from Standford's IR book</a> (<a href="https://nlp.stanford.edu/IR-book/html/htmledition/inverse-document-frequency-1.html" target"_blank" rel="noopenner noreferrer">original src</a>).</p>
#
# **Factoid**: Approximately 83% of digital libraries use text-based recommender systems that employ TF-IDF. (See Breitinger, Corinna; Gipp, Bela; Langer, Stefan (2015). Research-paper recommender systems: A literature survey. *International Journal on Digital Libraries*, 17(4), 305–338. doi:10.1007/s00799-015-0156-0.)

# %%
tfidf(dtm_POS).head(10)
# Out:
#                                               APPGE        AT       AT1  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.002965  0.033718  0.012397
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.003561  0.035161  0.012626
# kaggle_FIRST_THIRD_CELLS_notebooks         0.003740  0.034857  0.012627
#
#                                                 BCL        CC       CCB  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000179  0.013622  0.001656
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000161  0.014146  0.001515
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000222  0.014423  0.001437
#
#                                                  CS       CSA       CSN  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.004907  0.002032  0.001506
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.004490  0.001971  0.001525
# kaggle_FIRST_THIRD_CELLS_notebooks         0.004940  0.001725  0.001386
#
#                                                 CST  ...       VVD       VVG  \
# doc_id                                               ...
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.005248  ...  0.003150  0.009552
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.005231  ...  0.003523  0.008598
# kaggle_FIRST_THIRD_CELLS_notebooks         0.004793  ...  0.003119  0.009978
#
#                                                VVGK       VVI       VVN  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000257  0.016205  0.009892
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000097  0.016396  0.009576
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000192  0.017083  0.009756
#
#                                                VVNK       VVZ        XX  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000000  0.006766  0.003347
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000000  0.006547  0.003496
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000005  0.006433  0.002816
#
#                                                 ZZ1       ZZ2
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.004620  0.000000
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.003845  0.000007
# kaggle_FIRST_THIRD_CELLS_notebooks         0.003821  0.000007
#
# [3 rows x 130 columns]

# %%
tfidf(dtm_DS).head(10)
# Out:
#                                            AcademicTerms  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks         0.055699
# kaggle_SECOND_THIRD_CELLS_votes_notebooks       0.054805
# kaggle_FIRST_THIRD_CELLS_notebooks              0.054919
#
#                                            AcademicWritingMoves  Character  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks                0.004029   0.024819
# kaggle_SECOND_THIRD_CELLS_votes_notebooks              0.003609   0.023765
# kaggle_FIRST_THIRD_CELLS_notebooks                     0.004837   0.022404
#
#                                            Citation  CitationAuthority  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.001387           0.000806
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.001417           0.000756
# kaggle_FIRST_THIRD_CELLS_notebooks         0.001303           0.000667
#
#                                            CitationHedged  ConfidenceHedged  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks          0.000147          0.007070
# kaggle_SECOND_THIRD_CELLS_votes_notebooks        0.000082          0.007773
# kaggle_FIRST_THIRD_CELLS_notebooks               0.000053          0.006579
#
#                                            ConfidenceHigh  ConfidenceLow  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks          0.003384       0.000035
# kaggle_SECOND_THIRD_CELLS_votes_notebooks        0.003660       0.000025
# kaggle_FIRST_THIRD_CELLS_notebooks               0.003492       0.000046
#
#                                            Contingent  ...  Narrative  \
# doc_id                                                 ...
# kaggle_LAST_THIRD_CELLS_votes_notebooks      0.004309  ...   0.025597
# kaggle_SECOND_THIRD_CELLS_votes_notebooks    0.003767  ...   0.026832
# kaggle_FIRST_THIRD_CELLS_notebooks           0.003499  ...   0.027853
#
#                                            Negative  Positive  PublicTerms  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.013005  0.011639     0.003791
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.012301  0.011457     0.003571
# kaggle_FIRST_THIRD_CELLS_notebooks         0.011497  0.011659     0.004872
#
#                                            Reasoning  Responsibility  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks     0.009824        0.000575
# kaggle_SECOND_THIRD_CELLS_votes_notebooks   0.009870        0.000422
# kaggle_FIRST_THIRD_CELLS_notebooks          0.009864        0.000597
#
#                                            Strategic  Uncertainty  Untagged  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks     0.009438     0.000561  0.204815
# kaggle_SECOND_THIRD_CELLS_votes_notebooks   0.008843     0.000794  0.209065
# kaggle_FIRST_THIRD_CELLS_notebooks          0.009534     0.000657  0.209287
#
#                                             Updates
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.001492
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.001436
# kaggle_FIRST_THIRD_CELLS_notebooks         0.001605
#
# [3 rows x 37 columns]

# %% [markdown]
# ## 4.5 Application: Your turn to explore the data

# %% [markdown]
# Go back through the sections above. Explore the words and tags of your own interest. Consider importing a different dataset in the following folder `../data/04-textual-analysis`:
#
# Recall how this notebook uses data that I collected for a study on Kaggle notebooks. This NB uses data that I processed by sampling markdown cells by the position in which it occurs in the NB: the first third, second third, and last third ('../data/04-textual-analysis/kaggle-nb-examples/by-position'). Feel free to import the following other datasets and explore them.
#
# - **Kaggle NBs divded by distribution of their total votes**: `../data/04-textual-analysis/kaggle-nb-examples/by-votes`
# - **Amazon "Video Game" reviews by product ratings (1-5)** ([src](https://cseweb.ucsd.edu/~jmcauley/datasets/amazon_v2/)): `../data/04-textual-analysis/amazon`
# - **Jeopardy questions**: `../data/04-textual-analysis/jeopardy`

# %% [markdown]
# ## 4.6 Other Codebits

# %%
samp = """Who knew language and media were so tangled up with code, data, and computation?!"""
demo_doc = nlp_web_sm(samp)
options = {"compact": True, "distance": 50, "color": "yellow", "bg": "black", "font": "Gill Sans"}
displacy.render(demo_doc, style="dep", options=options)
